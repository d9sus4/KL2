# %% [markdown]
# # KL2 Data Processing & Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1 Relabeling

# %% [markdown]
# ### 1.1 Features Renaming & Preliminary Relabeling
#
# The folder "Data Preprocessing" defines some rules to rename features as well as some preliminary relabeling of feature values.
#
# This section load these rules and process the data as a first step.

# %%
# libraries, utility functions

import sys
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob

def load_lookup_table(folder_path):
    '''
    "Data Preprocessing" folder contains a bunch of .xlsx's, each coming with one or multiple sheets.
    Each sheet is expected to have only 2 column.
    The first row is a mapping from original column name in collected data, to a more refined (?) variation.
    The rest of the rows are a mapping from field values on the questionnaire to an interpretable label, usually a string.
    If for some row there's no value at the second column, that means we are not interested in those feature values.
    '''
    column_map = {}
    lookup_table = {'columns': column_map} # `column_map`: map old column in original

    excel_paths = glob(os.path.join(folder_path, "*.xlsx"))
    for path in excel_paths:    # read each excel files
        xls = pd.ExcelFile(path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(path, sheet_name=sheet_name, header=None)    # one df per sheet
            if df.shape[1] >= 2:  # Ensure at least two columns exist
                old_col_name, new_col_name = df.iloc[0, :2].str.strip()
                if pd.isna(old_col_name):
                    continue
                if pd.isna(new_col_name):
                    new_col_name = old_col_name
                column_map[old_col_name] = new_col_name
                relabel_map = dict(df.iloc[1:, :2].itertuples(index=False))
                lookup_table[new_col_name] = relabel_map
    # more: add two new feature names: 'diagnosis_b' and 'diagnosis_c'
    lookup_table['columns']['diagnosisb'] = 'diagnosis_b'
    lookup_table['columns']['diagnosisc'] = 'diagnosis_c'
    # set the mapping to the same as 'diagnosis'
    lookup_table['diagnosis_b'] = lookup_table['diagnosis']
    lookup_table['diagnosis_c'] = lookup_table['diagnosis']
        
    return lookup_table

def format_data(raw_data_path, lookup_table, keep_columns=True):
    df = pd.read_csv(raw_data_path, delimiter='|', low_memory=False)[:-1] # drop last row: summarizing # rows of the table
    df.iloc[:, 0] = df.iloc[:, 0].astype(float) # first column is coerced to int due to error caused by last special row 
    df.rename(columns=lookup_table['columns'], inplace=True)
    df.replace(lookup_table, inplace=True)
    if not keep_columns:
        columns = df.columns.intersection(lookup_table['columns'].values())
        df = df[columns]

    return df

# # Usage
# folder_path = "../data/Data Preprocessing/"
# raw_data_path = '../data/Original files/Cogan_eRD_RIC1_request.txt'  # Update this to your raw data file path
# output_path = '/path/to/output/renamed_data.xlsx'  # Update this to your desired output file path

# data_dict = load_data_dictionary(folder_path)
# relabeled_data = rename_columns(raw_data_path, data_dict, keep_columns=True)  # Set keep_columns to False if you want to drop columns not in the data dictionary

# %%
# load folder "Data Preprocessing" as a lookup table

folder_path = "./data/Data Preprocessing/"
raw_data_path = './data/Original files/Cogan_eRD_RIC1_request.txt'
lookup_table = load_lookup_table(folder_path)

lookup_table['columns']

# %%
# preprocess data with lookup table

df = format_data(raw_data_path, lookup_table, keep_columns=True)

df

# %%
# have a look at unique diagnosis
print("# of unique diagnosis:", df['diagnosis'].unique().size)
df['diagnosis'].unique()

# %%
# save preprocessed data

df.to_csv('./data/Cleaned files/Cogan_1_1.csv', index=False)

# %%
# save lookup table
import pickle

with open("./data/Cleaned files/lookup_table.pkl", 'wb') as f:
    pickle.dump(lookup_table, f)

# %% [markdown]
# #### Examine some features of interest here

# %%
lookup_table['language']

# %% [markdown]
# ### 1.2 Add Aggregated Outcomes

# %%
# load formated dataframe and see all feature names

import pandas as pd
import pickle
from tabulate import tabulate

# always start from loading the CSV file from previous section
df = pd.read_csv('./data/Cleaned files/Cogan_1_1.csv', low_memory=False)
with open("./data/Cleaned files/lookup_table.pkl", 'rb') as f:
    lookup_table = pickle.load(f)

feature_names = [*df.head()]
print("total # of features:", len(feature_names))

print(tabulate(enumerate(feature_names), headers=["Index", "Name"], tablefmt="grid"))

# %%
# define outcome features
selfcare_items = [
    "eating",
    "oral",
    "toileting",
    "bathe",
    "dress_upper",
    "dress_lower",
    "footwear",
]
mobility_items = [
    "roll_lr",
    "sit_lying",
    "lying_sit",
    "sit_stand",
    "bed_chair",
    "toilet_trans",
    "car_trans",
    "walk10ft",
    "walk50ft",
    "walk150ft",
    "walk10ft_uneven",
    "walk1step",
    "walk4step",
    "walk12step",
    "pickup"
]
print("# of selfcare items:", len(selfcare_items))
print("# of mobility items:", len(mobility_items))

# %%
# define ordinal sum to measure mapping
selfcare_table = {
    7: 19.65,
    8: 24.7,
    9: 27.64,
    10: 29.69,
    11: 31.44,
    12: 33.02,
    13: 34.46,
    14: 35.78,
    15: 36.97,
    16: 38.04,
    17: 38.98,
    18: 39.84,
    19: 40.62,
    20: 41.35,
    21: 42.05,
    22: 42.73,
    23: 43.39,
    24: 44.07,
    25: 44.77,
    26: 45.52,
    27: 46.33,
    28: 47.25,
    29: 48.33,
    30: 49.64,
    31: 51.28,
    32: 53.37,
    33: 56.1,
    34: 59.86,
    35: 65.47,
    36: 71.86,
    37: 76.96,
    38: 81.08,
    39: 84.76,
    40: 88.57,
    41: 93.54,
    42: 100.64,
}
mobility_table = {
    15: 4.86,
    16: 11.07,
    17: 14.3,
    18: 16.1,
    19: 17.35,
    20: 18.34,
    21: 19.16,
    22: 19.89,
    23: 20.54,
    24: 21.14,
    25: 21.71,
    26: 22.26,
    27: 22.79,
    28: 23.3,
    29: 23.81,
    30: 24.31,
    31: 24.81,
    32: 25.31,
    33: 25.82,
    34: 26.32,
    35: 26.82,
    36: 27.32,
    37: 27.83,
    38: 28.33,
    39: 28.82,
    40: 29.32,
    41: 29.81,
    42: 30.29,
    43: 30.77,
    44: 31.25,
    45: 31.72,
    46: 32.18,
    47: 32.65,
    48: 33.11,
    49: 33.57,
    50: 34.02,
    51: 34.48,
    52: 34.93,
    53: 35.39,
    54: 35.85,
    55: 36.32,
    56: 36.88,
    57: 37.28,
    58: 37.77,
    59: 38.28,
    60: 38.81,
    61: 39.36,
    62: 39.94,
    63: 40.56,
    64: 41.21,
    65: 41.92,
    66: 42.68,
    67: 43.52,
    68: 44.46,
    69: 45.53,
    70: 46.75,
    71: 48.17,
    72: 49.83,
    73: 51.76,
    74: 53.98,
    75: 56.42,
    76: 58.93,
    77: 61.36,
    78: 63.64,
    79: 65.73,
    80: 67.83,
    81: 69.82,
    82: 71.78,
    83: 73.76,
    84: 75.79,
    85: 77.91,
    86: 80.21,
    87: 82.62,
    88: 86.36,
    89: 90.90,
    90: 98.38
}

# %%
# safe buffer
last_df = df

# %%
# for outcome features, replace invalid responses as nan and count invalid samples
df = last_df.copy()
selfcare_columns = [item + '_adm' for item in selfcare_items] + [item + '_dc' for item in selfcare_items]
mobility_columns = [item + '_adm' for item in mobility_items] + [item + '_dc' for item in mobility_items]

subset_columns = [item + '_adm' for item in selfcare_items+mobility_items]
subset_columns += [item + '_dc' for item in selfcare_items+mobility_items]
df.loc[:, subset_columns] = df.loc[:, subset_columns].replace({
    'Refused': np.nan,
    'Not_applicable': np.nan,
    'Not_attempted': np.nan,
    'Safety': np.nan
})
print(df[subset_columns].isna().sum(axis=0))
# df = df.dropna(subset=selfcare_columns)
# df = df.dropna(subset=subset_columns)
# print("# of valid patients changed from", len(last_df), "to", len(df))

# %%
# calculate 4 measures
inverse_lookup = {v:k for k,v in lookup_table[selfcare_items[0]+'_adm'].items()}
print(inverse_lookup)

selfcare_sum_adm = df[[item + '_adm' for item in selfcare_items]].replace(inverse_lookup).sum(axis=1, skipna=False)
# print(selfcare_sum_adm[:10])
selfcare_sum_dc = df[[item + '_dc' for item in selfcare_items]].replace(inverse_lookup).sum(axis=1, skipna=False)
print("selfcare sum adm nan count:", np.sum(np.isnan(selfcare_sum_adm)))
print("selfcare sum dc nan count:", np.sum(np.isnan(selfcare_sum_dc)))

selfcare_measure_adm = selfcare_sum_adm.map(selfcare_table)
# print(selfcare_measure_adm[:10])
selfcare_measure_dc = selfcare_sum_dc.map(selfcare_table)
print("selfcare measure adm nan count:", np.sum(pd.isna(selfcare_measure_adm).to_numpy()))
print("selfcare measure dc nan count:", np.sum(pd.isna(selfcare_measure_dc).to_numpy()))

mobility_sum_adm = df[[item + '_adm' for item in mobility_items]].replace(inverse_lookup).sum(axis=1, skipna=False)
mobility_sum_dc = df[[item + '_dc' for item in mobility_items]].replace(inverse_lookup).sum(axis=1, skipna=False)
print("mobility sum adm nan count:", np.sum(np.isnan(mobility_sum_adm)))
print("mobility sum dc nan count:", np.sum(np.isnan(mobility_sum_dc)))
mobility_measure_adm = mobility_sum_adm.map(mobility_table)
mobility_measure_dc = mobility_sum_dc.map(mobility_table)
print("mobility measure adm nan count:", np.sum(pd.isna(mobility_measure_adm).to_numpy()))
print("mobility measure dc nan count:", np.sum(pd.isna(mobility_measure_dc).to_numpy()))

# %%
# add outcome measure columns to the df
df['selfcare_measure_adm'] = selfcare_measure_adm
df['selfcare_measure_dc'] = selfcare_measure_dc
df['mobility_measure_adm'] = mobility_measure_adm
df['mobility_measure_dc'] = mobility_measure_dc

# add two delta measure columns, just for quick filtering out valid samples (measures @adm&dc are both valid)
df['selfcare_measure_delta'] = (selfcare_measure_dc - selfcare_measure_adm).round(2)
df['mobility_measure_delta'] = (mobility_measure_dc - mobility_measure_adm).round(2)
print("# of invalid samples for selfcare:", np.isnan(df['selfcare_measure_delta']).sum(), " out of", len(df))
print("# of invalid samples for mobility:", np.isnan(df['mobility_measure_delta']).sum(), " out of", len(df))

# %%
# save processed data with 6 extra columns

df.to_csv('./data/Cleaned files/Cogan_1_2.csv', index=False)

# %% [markdown]
# ### 1.3 Relabel & Precess Features

# %%
# total # of features and a list of all feature names

import pandas as pd
import pickle
import numpy as np
from tabulate import tabulate

# always start from loading the CSV file from previous section
df = pd.read_csv('./data/Cleaned files/Cogan_1_2.csv', low_memory=False)
with open("./data/Cleaned files/lookup_table.pkl", 'rb') as f:
    lookup_table = pickle.load(f)

feature_names = [*df.head()]
feature_dtypes = df.dtypes
print("total # of features:", len(feature_names))

print(tabulate([(index, name, feature_dtypes[name]) for index, name in enumerate(feature_names)], headers=["Index", "Name", "Dtype"], tablefmt="grid"))
categorical_feature_set = set()
numeric_feature_set = set()
ranked_int_feature_set = set()
binary_feature_set = set()
# Out:
# total # of features: 455
# +---------+--------------------------------+---------+
# |   Index | Name                           | Dtype   |
# +=========+================================+=========+
# |       0 | sex                            | object  |
# +---------+--------------------------------+---------+
# |       1 | marital_status                 | object  |
# +---------+--------------------------------+---------+
# |       2 | admityear                      | float64 |
# +---------+--------------------------------+---------+
# |       3 | admitclass                     | float64 |
# +---------+--------------------------------+---------+
# |       4 | admit_from                     | object  |
# +---------+--------------------------------+---------+
# |       5 | prehospital_living             | object  |
# +---------+--------------------------------+---------+
# |       6 | prehospital_living_with        | object  |
# +---------+--------------------------------+---------+
# |       7 | payor_primary                  | object  |
# +---------+--------------------------------+---------+
# |       8 | payor_secondary                | object  |
# +---------+--------------------------------+---------+
# |       9 | impgroupadmit                  | float64 |
# +---------+--------------------------------+---------+
# |      10 | impgroupdisch                  | float64 |
# +---------+--------------------------------+---------+
# |      11 | diagnosis                      | object  |
# +---------+--------------------------------+---------+
# |      12 | diagnosis_b                    | object  |
# +---------+--------------------------------+---------+
# |      13 | diagnosis_c                    | object  |
# +---------+--------------------------------+---------+
# |      14 | comorbidity0                   | object  |
# +---------+--------------------------------+---------+
# |      15 | comorbidity1                   | object  |
# +---------+--------------------------------+---------+
# |      16 | comorbidity2                   | object  |
# +---------+--------------------------------+---------+
# |      17 | comorbidity3                   | object  |
# +---------+--------------------------------+---------+
# |      18 | comorbidity4                   | object  |
# +---------+--------------------------------+---------+
# |      19 | comorbidity5                   | object  |
# +---------+--------------------------------+---------+
# |      20 | comorbidity6                   | object  |
# +---------+--------------------------------+---------+
# |      21 | comorbidity7                   | object  |
# +---------+--------------------------------+---------+
# |      22 | comorbidity8                   | object  |
# +---------+--------------------------------+---------+
# |      23 | comorbidity9                   | object  |
# +---------+--------------------------------+---------+
# |      24 | comorbidity10                  | object  |
# +---------+--------------------------------+---------+
# |      25 | comorbidity11                  | object  |
# +---------+--------------------------------+---------+
# |      26 | comorbidity12                  | object  |
# +---------+--------------------------------+---------+
# |      27 | comorbidity13                  | object  |
# +---------+--------------------------------+---------+
# |      28 | comorbidity14                  | object  |
# +---------+--------------------------------+---------+
# |      29 | comorbidity15                  | object  |
# +---------+--------------------------------+---------+
# |      30 | comorbidity16                  | object  |
# +---------+--------------------------------+---------+
# |      31 | comorbidity17                  | object  |
# +---------+--------------------------------+---------+
# |      32 | comorbidity18                  | object  |
# +---------+--------------------------------+---------+
# |      33 | comorbidity19                  | object  |
# +---------+--------------------------------+---------+
# |      34 | comorbidity20                  | object  |
# +---------+--------------------------------+---------+
# |      35 | comorbidity21                  | object  |
# +---------+--------------------------------+---------+
# |      36 | comorbidity22                  | object  |
# +---------+--------------------------------+---------+
# |      37 | comorbidity23                  | object  |
# +---------+--------------------------------+---------+
# |      38 | comorbidity24                  | object  |
# +---------+--------------------------------+---------+
# |      39 | arthritis                      | object  |
# +---------+--------------------------------+---------+
# |      40 | heightinches                   | float64 |
# +---------+--------------------------------+---------+
# |      41 | weightpounds                   | float64 |
# +---------+--------------------------------+---------+
# |      42 | dischargeyear                  | float64 |
# +---------+--------------------------------+---------+
# |      43 | discharge_ama                  | object  |
# +---------+--------------------------------+---------+
# |      44 | interruptions                  | object  |
# +---------+--------------------------------+---------+
# |      45 | discharged_alive               | object  |
# +---------+--------------------------------+---------+
# |      46 | discharge_living               | object  |
# +---------+--------------------------------+---------+
# |      47 | discharge_living_with          | object  |
# +---------+--------------------------------+---------+
# |      48 | transferdiagnosis              | object  |
# +---------+--------------------------------+---------+
# |      49 | complication0                  | object  |
# +---------+--------------------------------+---------+
# |      50 | complication1                  | object  |
# +---------+--------------------------------+---------+
# |      51 | complication2                  | object  |
# +---------+--------------------------------+---------+
# |      52 | complication3                  | object  |
# +---------+--------------------------------+---------+
# |      53 | complication4                  | object  |
# +---------+--------------------------------+---------+
# |      54 | complication5                  | object  |
# +---------+--------------------------------+---------+
# |      55 | ptindweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      56 | ptconweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      57 | ptgrpweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      58 | ptcoweek1                      | float64 |
# +---------+--------------------------------+---------+
# |      59 | otindweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      60 | otconweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      61 | otgrpweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      62 | otcoweek1                      | float64 |
# +---------+--------------------------------+---------+
# |      63 | slpindweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      64 | slpconweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      65 | slpgrpweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      66 | slpcoweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      67 | ptindweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      68 | ptconweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      69 | ptgrpweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      70 | ptcoweek2                      | float64 |
# +---------+--------------------------------+---------+
# |      71 | otindweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      72 | otconweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      73 | otgrpweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      74 | otcoweek2                      | float64 |
# +---------+--------------------------------+---------+
# |      75 | slpindweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      76 | slpconweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      77 | slpgrpweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      78 | slpcoweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      79 | hispanic                       | object  |
# +---------+--------------------------------+---------+
# |      80 | hispanic_mexican               | object  |
# +---------+--------------------------------+---------+
# |      81 | hispanic_puertorican           | object  |
# +---------+--------------------------------+---------+
# |      82 | hispanic_cuban                 | object  |
# +---------+--------------------------------+---------+
# |      83 | hispanic_other                 | object  |
# +---------+--------------------------------+---------+
# |      84 | hispanic_unable                | object  |
# +---------+--------------------------------+---------+
# |      85 | hispanic_declined              | object  |
# +---------+--------------------------------+---------+
# |      86 | race_white                     | object  |
# +---------+--------------------------------+---------+
# |      87 | race_black                     | object  |
# +---------+--------------------------------+---------+
# |      88 | race_alaskan                   | object  |
# +---------+--------------------------------+---------+
# |      89 | race_asianindian               | object  |
# +---------+--------------------------------+---------+
# |      90 | race_chinese                   | object  |
# +---------+--------------------------------+---------+
# |      91 | race_filipino                  | object  |
# +---------+--------------------------------+---------+
# |      92 | race_japanese                  | object  |
# +---------+--------------------------------+---------+
# |      93 | race_korean                    | object  |
# +---------+--------------------------------+---------+
# |      94 | race_vietnamese                | object  |
# +---------+--------------------------------+---------+
# |      95 | race_asianother                | object  |
# +---------+--------------------------------+---------+
# |      96 | race_hawaiian                  | object  |
# +---------+--------------------------------+---------+
# |      97 | race_guam                      | object  |
# +---------+--------------------------------+---------+
# |      98 | race_samoan                    | object  |
# +---------+--------------------------------+---------+
# |      99 | race_pacificislander_other     | object  |
# +---------+--------------------------------+---------+
# |     100 | race_unable                    | object  |
# +---------+--------------------------------+---------+
# |     101 | race_declined                  | object  |
# +---------+--------------------------------+---------+
# |     102 | race_noneoftheabove            | object  |
# +---------+--------------------------------+---------+
# |     103 | language                       | object  |
# +---------+--------------------------------+---------+
# |     104 | interpreter                    | object  |
# +---------+--------------------------------+---------+
# |     105 | transport_lack_med             | object  |
# +---------+--------------------------------+---------+
# |     106 | transport_lack_nonmed          | object  |
# +---------+--------------------------------+---------+
# |     107 | transport_lack                 | object  |
# +---------+--------------------------------+---------+
# |     108 | transport_lack_unable          | object  |
# +---------+--------------------------------+---------+
# |     109 | transport_lack_declined        | object  |
# +---------+--------------------------------+---------+
# |     110 | hearing_adm                    | object  |
# +---------+--------------------------------+---------+
# |     111 | vision_adm                     | object  |
# +---------+--------------------------------+---------+
# |     112 | health_lit_adm                 | object  |
# +---------+--------------------------------+---------+
# |     113 | expression_adm                 | object  |
# +---------+--------------------------------+---------+
# |     114 | understand_verbal_adm          | object  |
# +---------+--------------------------------+---------+
# |     115 | conduct_bims                   | object  |
# +---------+--------------------------------+---------+
# |     116 | bims_3words                    | object  |
# +---------+--------------------------------+---------+
# |     117 | bims_year                      | object  |
# +---------+--------------------------------+---------+
# |     118 | bims_month                     | object  |
# +---------+--------------------------------+---------+
# |     119 | bims_day                       | object  |
# +---------+--------------------------------+---------+
# |     120 | bims_recall_sock               | object  |
# +---------+--------------------------------+---------+
# |     121 | bims_recall_blue               | object  |
# +---------+--------------------------------+---------+
# |     122 | bims_recall_bed                | object  |
# +---------+--------------------------------+---------+
# |     123 | bims_total                     | object  |
# +---------+--------------------------------+---------+
# |     124 | conduct_sams                   | object  |
# +---------+--------------------------------+---------+
# |     125 | sams_season                    | object  |
# +---------+--------------------------------+---------+
# |     126 | sams_room                      | object  |
# +---------+--------------------------------+---------+
# |     127 | sams_names                     | object  |
# +---------+--------------------------------+---------+
# |     128 | sams_hosp                      | object  |
# +---------+--------------------------------+---------+
# |     129 | sams_none_above                | object  |
# +---------+--------------------------------+---------+
# |     130 | acute_mental_change            | object  |
# +---------+--------------------------------+---------+
# |     131 | inattention_adm                | object  |
# +---------+--------------------------------+---------+
# |     132 | disorganized_adm               | object  |
# +---------+--------------------------------+---------+
# |     133 | altered_adm                    | object  |
# +---------+--------------------------------+---------+
# |     134 | low_interest_adm               | object  |
# +---------+--------------------------------+---------+
# |     135 | low_interest_freq_adm          | object  |
# +---------+--------------------------------+---------+
# |     136 | depressed_adm                  | object  |
# +---------+--------------------------------+---------+
# |     137 | depressed_freq_adm             | object  |
# +---------+--------------------------------+---------+
# |     138 | sleep_trouble_adm              | object  |
# +---------+--------------------------------+---------+
# |     139 | sleep_trouble_freq_adm         | object  |
# +---------+--------------------------------+---------+
# |     140 | tired_adm                      | object  |
# +---------+--------------------------------+---------+
# |     141 | tired_freq_adm                 | object  |
# +---------+--------------------------------+---------+
# |     142 | appetite_adm                   | object  |
# +---------+--------------------------------+---------+
# |     143 | appetite_freq_adm              | object  |
# +---------+--------------------------------+---------+
# |     144 | feel_bad_adm                   | object  |
# +---------+--------------------------------+---------+
# |     145 | feel_bad_freq_adm              | object  |
# +---------+--------------------------------+---------+
# |     146 | concentrate_adm                | object  |
# +---------+--------------------------------+---------+
# |     147 | concentrate_freq_adm           | object  |
# +---------+--------------------------------+---------+
# |     148 | slowfast_adm                   | object  |
# +---------+--------------------------------+---------+
# |     149 | slowfast_freq_adm              | object  |
# +---------+--------------------------------+---------+
# |     150 | selfharm_adm                   | object  |
# +---------+--------------------------------+---------+
# |     151 | selfharm_freq_adm              | object  |
# +---------+--------------------------------+---------+
# |     152 | mood_total_adm                 | object  |
# +---------+--------------------------------+---------+
# |     153 | socisolation_adm               | object  |
# +---------+--------------------------------+---------+
# |     154 | selfcare_prior                 | object  |
# +---------+--------------------------------+---------+
# |     155 | mobility_prior                 | object  |
# +---------+--------------------------------+---------+
# |     156 | stairs_prior                   | object  |
# +---------+--------------------------------+---------+
# |     157 | func_cog_prior                 | object  |
# +---------+--------------------------------+---------+
# |     158 | wc_manual_prior                | object  |
# +---------+--------------------------------+---------+
# |     159 | wc_motor_prior                 | object  |
# +---------+--------------------------------+---------+
# |     160 | mechlift_prior                 | object  |
# +---------+--------------------------------+---------+
# |     161 | walker_prior                   | object  |
# +---------+--------------------------------+---------+
# |     162 | orth_pros_prior                | object  |
# +---------+--------------------------------+---------+
# |     163 | no_device_prior                | object  |
# +---------+--------------------------------+---------+
# |     164 | eating_adm                     | object  |
# +---------+--------------------------------+---------+
# |     165 | eating_goal                    | object  |
# +---------+--------------------------------+---------+
# |     166 | oral_adm                       | object  |
# +---------+--------------------------------+---------+
# |     167 | oral_goal                      | object  |
# +---------+--------------------------------+---------+
# |     168 | toileting_adm                  | object  |
# +---------+--------------------------------+---------+
# |     169 | toileting_goal                 | object  |
# +---------+--------------------------------+---------+
# |     170 | bathe_adm                      | object  |
# +---------+--------------------------------+---------+
# |     171 | bathe_goal                     | object  |
# +---------+--------------------------------+---------+
# |     172 | dress_upper_adm                | object  |
# +---------+--------------------------------+---------+
# |     173 | dress_upper_goal               | object  |
# +---------+--------------------------------+---------+
# |     174 | dress_lower_adm                | object  |
# +---------+--------------------------------+---------+
# |     175 | dress_lower_goal               | object  |
# +---------+--------------------------------+---------+
# |     176 | footwear_adm                   | object  |
# +---------+--------------------------------+---------+
# |     177 | footwear_goal                  | object  |
# +---------+--------------------------------+---------+
# |     178 | roll_lr_adm                    | object  |
# +---------+--------------------------------+---------+
# |     179 | roll_lr_goal                   | object  |
# +---------+--------------------------------+---------+
# |     180 | sit_lying_adm                  | object  |
# +---------+--------------------------------+---------+
# |     181 | sit_lying_goal                 | object  |
# +---------+--------------------------------+---------+
# |     182 | lying_sit_adm                  | object  |
# +---------+--------------------------------+---------+
# |     183 | lying_sit_goal                 | object  |
# +---------+--------------------------------+---------+
# |     184 | sit_stand_adm                  | object  |
# +---------+--------------------------------+---------+
# |     185 | sit_stand_goal                 | object  |
# +---------+--------------------------------+---------+
# |     186 | bed_chair_adm                  | object  |
# +---------+--------------------------------+---------+
# |     187 | bed_chair_goal                 | object  |
# +---------+--------------------------------+---------+
# |     188 | toilet_trans_adm               | object  |
# +---------+--------------------------------+---------+
# |     189 | toilet_trans_goal              | object  |
# +---------+--------------------------------+---------+
# |     190 | car_trans_adm                  | object  |
# +---------+--------------------------------+---------+
# |     191 | car_trans_goal                 | object  |
# +---------+--------------------------------+---------+
# |     192 | walk10ft_adm                   | object  |
# +---------+--------------------------------+---------+
# |     193 | walk10ft_goal                  | object  |
# +---------+--------------------------------+---------+
# |     194 | walk50ft_adm                   | object  |
# +---------+--------------------------------+---------+
# |     195 | walk50ft_goal                  | object  |
# +---------+--------------------------------+---------+
# |     196 | walk150ft_adm                  | object  |
# +---------+--------------------------------+---------+
# |     197 | walk150ft_goal                 | object  |
# +---------+--------------------------------+---------+
# |     198 | walk10ft_uneven_adm            | object  |
# +---------+--------------------------------+---------+
# |     199 | walk10ft_uneven_goal           | object  |
# +---------+--------------------------------+---------+
# |     200 | walk1step_adm                  | object  |
# +---------+--------------------------------+---------+
# |     201 | walk1step_goal                 | object  |
# +---------+--------------------------------+---------+
# |     202 | walk4step_adm                  | object  |
# +---------+--------------------------------+---------+
# |     203 | walk4step_goal                 | object  |
# +---------+--------------------------------+---------+
# |     204 | walk12step_adm                 | object  |
# +---------+--------------------------------+---------+
# |     205 | walk12step_goal                | object  |
# +---------+--------------------------------+---------+
# |     206 | pickup_adm                     | object  |
# +---------+--------------------------------+---------+
# |     207 | pickup_goal                    | object  |
# +---------+--------------------------------+---------+
# |     208 | wc_user                        | object  |
# +---------+--------------------------------+---------+
# |     209 | wheel50ft_adm                  | object  |
# +---------+--------------------------------+---------+
# |     210 | wheel50ft_goal                 | object  |
# +---------+--------------------------------+---------+
# |     211 | wc50_type                      | object  |
# +---------+--------------------------------+---------+
# |     212 | wheel150ft_adm                 | object  |
# +---------+--------------------------------+---------+
# |     213 | wheel150ft_goal                | object  |
# +---------+--------------------------------+---------+
# |     214 | wc150_type                     | object  |
# +---------+--------------------------------+---------+
# |     215 | bladder_incontinence           | object  |
# +---------+--------------------------------+---------+
# |     216 | bowel_incontinence             | object  |
# +---------+--------------------------------+---------+
# |     217 | pvd_comorbid                   | object  |
# +---------+--------------------------------+---------+
# |     218 | diabetes_comorbid              | object  |
# +---------+--------------------------------+---------+
# |     219 | no_comorbidities               | object  |
# +---------+--------------------------------+---------+
# |     220 | pain_sleep_adm                 | object  |
# +---------+--------------------------------+---------+
# |     221 | pain_therapy_adm               | object  |
# +---------+--------------------------------+---------+
# |     222 | pain_activities_adm            | object  |
# +---------+--------------------------------+---------+
# |     223 | falls_hx                       | object  |
# +---------+--------------------------------+---------+
# |     224 | prior_surgery                  | object  |
# +---------+--------------------------------+---------+
# |     225 | nutrition_parenteral_adm       | object  |
# +---------+--------------------------------+---------+
# |     226 | nutrition_tube_adm             | object  |
# +---------+--------------------------------+---------+
# |     227 | nutrition_mech_diet_adm        | object  |
# +---------+--------------------------------+---------+
# |     228 | nutrition_ther_diet_adm        | object  |
# +---------+--------------------------------+---------+
# |     229 | nutrition_none_adm             | object  |
# +---------+--------------------------------+---------+
# |     230 | pressure_ulcer_adm             | object  |
# +---------+--------------------------------+---------+
# |     231 | stage1_pu_adm                  | float64 |
# +---------+--------------------------------+---------+
# |     232 | stage2_pu_adm                  | float64 |
# +---------+--------------------------------+---------+
# |     233 | stage3_pu_adm                  | float64 |
# +---------+--------------------------------+---------+
# |     234 | stage4_pu_adm                  | float64 |
# +---------+--------------------------------+---------+
# |     235 | unstageable_dressing_pu_adm    | float64 |
# +---------+--------------------------------+---------+
# |     236 | unstageable_slough_pu_adm      | float64 |
# +---------+--------------------------------+---------+
# |     237 | unstageable_deep_pu_adm        | float64 |
# +---------+--------------------------------+---------+
# |     238 | antipsychotic_taking_adm       | object  |
# +---------+--------------------------------+---------+
# |     239 | antipsychotic_ind_adm          | object  |
# +---------+--------------------------------+---------+
# |     240 | anticoagulant_taking_adm       | object  |
# +---------+--------------------------------+---------+
# |     241 | anticoagulant_ind_adm          | object  |
# +---------+--------------------------------+---------+
# |     242 | antibiotic_taking_adm          | object  |
# +---------+--------------------------------+---------+
# |     243 | antibiotic_ind_adm             | object  |
# +---------+--------------------------------+---------+
# |     244 | opioid_taking_adm              | object  |
# +---------+--------------------------------+---------+
# |     245 | opioid_ind_adm                 | object  |
# +---------+--------------------------------+---------+
# |     246 | antiplatelet_taking_adm        | object  |
# +---------+--------------------------------+---------+
# |     247 | antiplatelet_ind_adm           | object  |
# +---------+--------------------------------+---------+
# |     248 | hypoglycemic_taking_adm        | object  |
# +---------+--------------------------------+---------+
# |     249 | hypoglycemic_ind_adm           | object  |
# +---------+--------------------------------+---------+
# |     250 | med_highrisk_none              | object  |
# +---------+--------------------------------+---------+
# |     251 | drug_regimen_review            | object  |
# +---------+--------------------------------+---------+
# |     252 | med_follow_up                  | object  |
# +---------+--------------------------------+---------+
# |     253 | chemo_adm                      | object  |
# +---------+--------------------------------+---------+
# |     254 | chemo_iv_adm                   | object  |
# +---------+--------------------------------+---------+
# |     255 | chemo_oral_adm                 | object  |
# +---------+--------------------------------+---------+
# |     256 | chemo_other_adm                | object  |
# +---------+--------------------------------+---------+
# |     257 | radiation_adm                  | object  |
# +---------+--------------------------------+---------+
# |     258 | oxygen_adm                     | object  |
# +---------+--------------------------------+---------+
# |     259 | oxygen_cont_adm                | object  |
# +---------+--------------------------------+---------+
# |     260 | oxygen_int_adm                 | object  |
# +---------+--------------------------------+---------+
# |     261 | oxygen_high_adm                | object  |
# +---------+--------------------------------+---------+
# |     262 | suctioning_adm                 | object  |
# +---------+--------------------------------+---------+
# |     263 | suctioning_sched_adm           | object  |
# +---------+--------------------------------+---------+
# |     264 | suctioning_asneeded_adm        | object  |
# +---------+--------------------------------+---------+
# |     265 | trach_adm                      | object  |
# +---------+--------------------------------+---------+
# |     266 | vent_invasive_adm              | object  |
# +---------+--------------------------------+---------+
# |     267 | vent_noninvasive_adm           | object  |
# +---------+--------------------------------+---------+
# |     268 | vent_bipap_adm                 | object  |
# +---------+--------------------------------+---------+
# |     269 | vent_cpap_adm                  | object  |
# +---------+--------------------------------+---------+
# |     270 | meds_iv_adm                    | object  |
# +---------+--------------------------------+---------+
# |     271 | meds_iv_vasoactive_adm         | object  |
# +---------+--------------------------------+---------+
# |     272 | meds_iv_antibiotic_adm         | object  |
# +---------+--------------------------------+---------+
# |     273 | meds_iv_anticoagulant_adm      | object  |
# +---------+--------------------------------+---------+
# |     274 | meds_iv_other_adm              | object  |
# +---------+--------------------------------+---------+
# |     275 | transfusions_adm               | object  |
# +---------+--------------------------------+---------+
# |     276 | dialysis_adm                   | object  |
# +---------+--------------------------------+---------+
# |     277 | hemodialysis_adm               | object  |
# +---------+--------------------------------+---------+
# |     278 | peritoneal_dialysis_adm        | object  |
# +---------+--------------------------------+---------+
# |     279 | iv_access_adm                  | object  |
# +---------+--------------------------------+---------+
# |     280 | iv_access_periph_adm           | object  |
# +---------+--------------------------------+---------+
# |     281 | iv_access_mid_adm              | object  |
# +---------+--------------------------------+---------+
# |     282 | iv_access_cent_adm             | object  |
# +---------+--------------------------------+---------+
# |     283 | tx_none_adm                    | object  |
# +---------+--------------------------------+---------+
# |     284 | transport_lack_med_dc          | object  |
# +---------+--------------------------------+---------+
# |     285 | transport_lack_nonmed_dc       | object  |
# +---------+--------------------------------+---------+
# |     286 | transport_lack_dc              | object  |
# +---------+--------------------------------+---------+
# |     287 | transport_lack_unable_dc       | object  |
# +---------+--------------------------------+---------+
# |     288 | transport_lack_declined_dc     | object  |
# +---------+--------------------------------+---------+
# |     289 | med_list_to_provider           | object  |
# +---------+--------------------------------+---------+
# |     290 | med_list_transmit_ehr          | object  |
# +---------+--------------------------------+---------+
# |     291 | med_list_transmit_hie          | object  |
# +---------+--------------------------------+---------+
# |     292 | med_list_transmit_verbal       | object  |
# +---------+--------------------------------+---------+
# |     293 | med_list_transmit_paper        | object  |
# +---------+--------------------------------+---------+
# |     294 | med_list_transmit_other        | object  |
# +---------+--------------------------------+---------+
# |     295 | med_list_to_patient            | object  |
# +---------+--------------------------------+---------+
# |     296 | med_list_pt_ehr                | object  |
# +---------+--------------------------------+---------+
# |     297 | med_list_pt_hie                | object  |
# +---------+--------------------------------+---------+
# |     298 | med_list_pt_verbal             | object  |
# +---------+--------------------------------+---------+
# |     299 | med_list_pt_paper              | object  |
# +---------+--------------------------------+---------+
# |     300 | med_list_pt_other              | object  |
# +---------+--------------------------------+---------+
# |     301 | health_lit_dc                  | object  |
# +---------+--------------------------------+---------+
# |     302 | conduct_bims_dc                | object  |
# +---------+--------------------------------+---------+
# |     303 | bims_3words_dc                 | object  |
# +---------+--------------------------------+---------+
# |     304 | bims_year_dc                   | object  |
# +---------+--------------------------------+---------+
# |     305 | bims_month_dc                  | object  |
# +---------+--------------------------------+---------+
# |     306 | bims_day_dc                    | object  |
# +---------+--------------------------------+---------+
# |     307 | bims_recall_sock_dc            | object  |
# +---------+--------------------------------+---------+
# |     308 | bims_recall_blue_dc            | object  |
# +---------+--------------------------------+---------+
# |     309 | bims_recall_bed_dc             | object  |
# +---------+--------------------------------+---------+
# |     310 | bims_total_dc                  | object  |
# +---------+--------------------------------+---------+
# |     311 | acute_mental_change_dc         | object  |
# +---------+--------------------------------+---------+
# |     312 | inattention_dc                 | object  |
# +---------+--------------------------------+---------+
# |     313 | disorganized_dc                | object  |
# +---------+--------------------------------+---------+
# |     314 | altered_dc                     | object  |
# +---------+--------------------------------+---------+
# |     315 | low_interest_dc                | object  |
# +---------+--------------------------------+---------+
# |     316 | low_interest_freq_dc           | object  |
# +---------+--------------------------------+---------+
# |     317 | depressed_dc                   | object  |
# +---------+--------------------------------+---------+
# |     318 | depressed_freq_dc              | object  |
# +---------+--------------------------------+---------+
# |     319 | sleep_trouble_dc               | object  |
# +---------+--------------------------------+---------+
# |     320 | sleep_trouble_freq_dc          | object  |
# +---------+--------------------------------+---------+
# |     321 | tired_dc                       | object  |
# +---------+--------------------------------+---------+
# |     322 | tired_freq_dc                  | object  |
# +---------+--------------------------------+---------+
# |     323 | appetite_dc                    | object  |
# +---------+--------------------------------+---------+
# |     324 | appetite_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     325 | feel_bad_dc                    | object  |
# +---------+--------------------------------+---------+
# |     326 | feel_bad_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     327 | concentrate_dc                 | object  |
# +---------+--------------------------------+---------+
# |     328 | concentrate_freq_dc            | object  |
# +---------+--------------------------------+---------+
# |     329 | slowfast_dc                    | object  |
# +---------+--------------------------------+---------+
# |     330 | slowfast_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     331 | selfharm_dc                    | object  |
# +---------+--------------------------------+---------+
# |     332 | selfharm_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     333 | mood_total_dc                  | object  |
# +---------+--------------------------------+---------+
# |     334 | socisolation_dc                | object  |
# +---------+--------------------------------+---------+
# |     335 | eating_dc                      | object  |
# +---------+--------------------------------+---------+
# |     336 | oral_dc                        | object  |
# +---------+--------------------------------+---------+
# |     337 | toileting_dc                   | object  |
# +---------+--------------------------------+---------+
# |     338 | bathe_dc                       | object  |
# +---------+--------------------------------+---------+
# |     339 | dress_upper_dc                 | object  |
# +---------+--------------------------------+---------+
# |     340 | dress_lower_dc                 | object  |
# +---------+--------------------------------+---------+
# |     341 | footwear_dc                    | object  |
# +---------+--------------------------------+---------+
# |     342 | roll_lr_dc                     | object  |
# +---------+--------------------------------+---------+
# |     343 | sit_lying_dc                   | object  |
# +---------+--------------------------------+---------+
# |     344 | lying_sit_dc                   | object  |
# +---------+--------------------------------+---------+
# |     345 | sit_stand_dc                   | object  |
# +---------+--------------------------------+---------+
# |     346 | bed_chair_dc                   | object  |
# +---------+--------------------------------+---------+
# |     347 | toilet_trans_dc                | object  |
# +---------+--------------------------------+---------+
# |     348 | car_trans_dc                   | object  |
# +---------+--------------------------------+---------+
# |     349 | walk10ft_dc                    | object  |
# +---------+--------------------------------+---------+
# |     350 | walk50ft_dc                    | object  |
# +---------+--------------------------------+---------+
# |     351 | walk150ft_dc                   | object  |
# +---------+--------------------------------+---------+
# |     352 | walk10ft_uneven_dc             | object  |
# +---------+--------------------------------+---------+
# |     353 | walk1step_dc                   | object  |
# +---------+--------------------------------+---------+
# |     354 | walk4step_dc                   | object  |
# +---------+--------------------------------+---------+
# |     355 | walk12step_dc                  | object  |
# +---------+--------------------------------+---------+
# |     356 | pickup_dc                      | object  |
# +---------+--------------------------------+---------+
# |     357 | wc_user_dc                     | object  |
# +---------+--------------------------------+---------+
# |     358 | wheel50ft_dc                   | object  |
# +---------+--------------------------------+---------+
# |     359 | wc50_type_dc                   | object  |
# +---------+--------------------------------+---------+
# |     360 | wheel150ft_dc                  | object  |
# +---------+--------------------------------+---------+
# |     361 | wc150_type_dc                  | object  |
# +---------+--------------------------------+---------+
# |     362 | pain_sleep_dc                  | object  |
# +---------+--------------------------------+---------+
# |     363 | pain_therapy_dc                | object  |
# +---------+--------------------------------+---------+
# |     364 | pain_activities_dc             | object  |
# +---------+--------------------------------+---------+
# |     365 | falls_since_adm                | object  |
# +---------+--------------------------------+---------+
# |     366 | falls_no_injury                | object  |
# +---------+--------------------------------+---------+
# |     367 | falls_minor_injury             | object  |
# +---------+--------------------------------+---------+
# |     368 | falls_major_injury             | object  |
# +---------+--------------------------------+---------+
# |     369 | nutrition_parenteral_last7days | object  |
# +---------+--------------------------------+---------+
# |     370 | nutrition_parenteral_dc        | object  |
# +---------+--------------------------------+---------+
# |     371 | nutrition_tube_last7days       | object  |
# +---------+--------------------------------+---------+
# |     372 | nutrition_tube_dc              | object  |
# +---------+--------------------------------+---------+
# |     373 | nutrition_mech_diet_last7days  | object  |
# +---------+--------------------------------+---------+
# |     374 | nutrition_mech_diet_dc         | object  |
# +---------+--------------------------------+---------+
# |     375 | nutrition_ther_diet_last7days  | object  |
# +---------+--------------------------------+---------+
# |     376 | nutrition_ther_diet_dc         | object  |
# +---------+--------------------------------+---------+
# |     377 | nutrition_none_last7days       | object  |
# +---------+--------------------------------+---------+
# |     378 | nutrition_none_dc              | object  |
# +---------+--------------------------------+---------+
# |     379 | pressure_ulcer_dc              | object  |
# +---------+--------------------------------+---------+
# |     380 | stage1_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     381 | stage2_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     382 | stage2_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     383 | stage3_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     384 | stage3_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     385 | stage4_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     386 | stage4_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     387 | unstageable_dressing_pu_dc     | float64 |
# +---------+--------------------------------+---------+
# |     388 | unstageable_dressing_pu_remain | float64 |
# +---------+--------------------------------+---------+
# |     389 | unstageable_slough_pu_dc       | float64 |
# +---------+--------------------------------+---------+
# |     390 | unstageable_slough_pu_remain   | float64 |
# +---------+--------------------------------+---------+
# |     391 | unstageable_deep_pu_dc         | float64 |
# +---------+--------------------------------+---------+
# |     392 | unstageable_deep_pu_remain     | float64 |
# +---------+--------------------------------+---------+
# |     393 | antipsychotic_taking_dc        | object  |
# +---------+--------------------------------+---------+
# |     394 | antipsychotic_ind_dc           | object  |
# +---------+--------------------------------+---------+
# |     395 | anticoagulant_taking_dc        | object  |
# +---------+--------------------------------+---------+
# |     396 | anticoagulant_ind_dc           | object  |
# +---------+--------------------------------+---------+
# |     397 | antibiotic_taking_dc           | object  |
# +---------+--------------------------------+---------+
# |     398 | antibiotic_ind_dc              | object  |
# +---------+--------------------------------+---------+
# |     399 | opioid_taking_dc               | object  |
# +---------+--------------------------------+---------+
# |     400 | opioid_ind_dc                  | object  |
# +---------+--------------------------------+---------+
# |     401 | antiplatelet_taking_dc         | object  |
# +---------+--------------------------------+---------+
# |     402 | antiplatelet_ind_dc            | object  |
# +---------+--------------------------------+---------+
# |     403 | hypoglycemic_taking_dc         | object  |
# +---------+--------------------------------+---------+
# |     404 | hypoglycemic_ind_dc            | object  |
# +---------+--------------------------------+---------+
# |     405 | med_highrisk_none_dc           | object  |
# +---------+--------------------------------+---------+
# |     406 | med_intervention               | object  |
# +---------+--------------------------------+---------+
# |     407 | chemo_dc                       | object  |
# +---------+--------------------------------+---------+
# |     408 | chemo_iv_dc                    | object  |
# +---------+--------------------------------+---------+
# |     409 | chemo_oral_dc                  | object  |
# +---------+--------------------------------+---------+
# |     410 | chemo_other_dc                 | object  |
# +---------+--------------------------------+---------+
# |     411 | radiation_dc                   | object  |
# +---------+--------------------------------+---------+
# |     412 | oxygen_dc                      | object  |
# +---------+--------------------------------+---------+
# |     413 | oxygen_cont_dc                 | object  |
# +---------+--------------------------------+---------+
# |     414 | oxygen_int_dc                  | object  |
# +---------+--------------------------------+---------+
# |     415 | oxygen_high_dc                 | object  |
# +---------+--------------------------------+---------+
# |     416 | suctioning_dc                  | object  |
# +---------+--------------------------------+---------+
# |     417 | suctioning_sched_dc            | object  |
# +---------+--------------------------------+---------+
# |     418 | suctioning_asneeded_dc         | object  |
# +---------+--------------------------------+---------+
# |     419 | trach_dc                       | object  |
# +---------+--------------------------------+---------+
# |     420 | vent_invasive_dc               | object  |
# +---------+--------------------------------+---------+
# |     421 | vent_noninvasive_dc            | object  |
# +---------+--------------------------------+---------+
# |     422 | vent_bipap_dc                  | object  |
# +---------+--------------------------------+---------+
# |     423 | vent_cpap_dc                   | object  |
# +---------+--------------------------------+---------+
# |     424 | meds_iv_dc                     | object  |
# +---------+--------------------------------+---------+
# |     425 | meds_iv_vasoactive_dc          | object  |
# +---------+--------------------------------+---------+
# |     426 | meds_iv_antibiotic_dc          | object  |
# +---------+--------------------------------+---------+
# |     427 | meds_iv_anticoagulant_dc       | object  |
# +---------+--------------------------------+---------+
# |     428 | meds_iv_other_dc               | object  |
# +---------+--------------------------------+---------+
# |     429 | transfusions_dc                | object  |
# +---------+--------------------------------+---------+
# |     430 | dialysis_dc                    | object  |
# +---------+--------------------------------+---------+
# |     431 | hemodialysis_dc                | object  |
# +---------+--------------------------------+---------+
# |     432 | peritoneal_dialysis_dc         | object  |
# +---------+--------------------------------+---------+
# |     433 | iv_access_dc                   | object  |
# +---------+--------------------------------+---------+
# |     434 | iv_access_periph_dc            | object  |
# +---------+--------------------------------+---------+
# |     435 | iv_access_mid_dc               | object  |
# +---------+--------------------------------+---------+
# |     436 | iv_access_cent_dc              | object  |
# +---------+--------------------------------+---------+
# |     437 | tx_none_dc                     | object  |
# +---------+--------------------------------+---------+
# |     438 | age_at_admit                   | float64 |
# +---------+--------------------------------+---------+
# |     439 | los                            | float64 |
# +---------+--------------------------------+---------+
# |     440 | ric                            | float64 |
# +---------+--------------------------------+---------+
# |     441 | cmg                            | float64 |
# +---------+--------------------------------+---------+
# |     442 | tier                           | float64 |
# +---------+--------------------------------+---------+
# |     443 | shortstayexpired               | object  |
# +---------+--------------------------------+---------+
# |     444 | shortstaycmg                   | float64 |
# +---------+--------------------------------+---------+
# |     445 | transferpatient                | object  |
# +---------+--------------------------------+---------+
# |     446 | incompletestay                 | object  |
# +---------+--------------------------------+---------+
# |     447 | unplanned_discharge            | float64 |
# +---------+--------------------------------+---------+
# |     448 | id                             | float64 |
# +---------+--------------------------------+---------+
# |     449 | selfcare_measure_adm           | float64 |
# +---------+--------------------------------+---------+
# |     450 | selfcare_measure_dc            | float64 |
# +---------+--------------------------------+---------+
# |     451 | mobility_measure_adm           | float64 |
# +---------+--------------------------------+---------+
# |     452 | mobility_measure_dc            | float64 |
# +---------+--------------------------------+---------+
# |     453 | selfcare_measure_delta         | float64 |
# +---------+--------------------------------+---------+
# |     454 | mobility_measure_delta         | float64 |
# +---------+--------------------------------+---------+

# %%
# set column 'id' as index
df['id'] = df['id'].astype(int)

df.set_index('id', inplace=True)
print(df)
# Out:
#           sex marital_status  admityear  admitclass  \
# id
# 1      female        Married     2023.0         1.0
# 2        male        Married     2023.0         1.0
# 3        male        Married     2023.0         1.0
# 4      female        Widowed     2022.0         1.0
# 5      female            NaN     2023.0         1.0
# ...       ...            ...        ...         ...
# 43741  female        Widowed     2022.0         1.0
# 43742  female  Never married     2022.0         NaN
# 43743  female        Married     2022.0         1.0
# 43744    male        Married     2022.0         1.0
# 43745  female        Widowed     2023.0         1.0
#
#                         admit_from prehospital_living prehospital_living_with  \
# id
# 1      Short-term general hospital               Home                  Family
# 2      Short-term general hospital               Home                  Family
# 3      Short-term general hospital               Home                  Family
# 4      Short-term general hospital               Home                  Family
# 5      Short-term general hospital               Home                   Alone
# ...                            ...                ...                     ...
# 43741  Short-term general hospital               Home                  Family
# 43742      Long-term care hospital               Home                   Alone
# 43743  Short-term general hospital               Home               Attendant
# 43744  Short-term general hospital               Home                  Family
# 43745  Short-term general hospital  Intermediate care                     NaN
#
#             payor_primary payor_secondary  impgroupadmit  ...  shortstaycmg  \
# id                                                        ...
# 1            Medicare FFS      Not listed            1.2  ...           NaN
# 2      Medicare Advantage      Not listed            1.2  ...           NaN
# 3      Medicare Advantage      Not listed            1.2  ...           NaN
# 4            Medicare FFS      Not listed            1.1  ...           NaN
# 5              Not listed      Not listed            1.3  ...           NaN
# ...                   ...             ...            ...  ...           ...
# 43741        Medicare FFS      Not listed            1.3  ...           NaN
# 43742        Medicare FFS      Not listed            1.1  ...           NaN
# 43743        Medicare FFS      Not listed            1.2  ...           NaN
# 43744  Medicare Advantage      Not listed            1.1  ...           NaN
# 43745        Medicare FFS      Not listed            1.2  ...           NaN
#
#       transferpatient incompletestay unplanned_discharge selfcare_measure_adm  \
# id
# 1                   f              f                 NaN                42.05
# 2                   f              f                 NaN                48.33
# 3                   f              f                 NaN                45.52
# 4                   f              f                 NaN                49.64
# 5                   t              f                 NaN                  NaN
# ...               ...            ...                 ...                  ...
# 43741               f              f                 NaN                  NaN
# 43742               t              t                 NaN                35.78
# 43743               f              f                 NaN                  NaN
# 43744               t              f                 NaN                  NaN
# 43745               t              f                 NaN                27.64
#
#       selfcare_measure_dc mobility_measure_adm mobility_measure_dc  \
# id
# 1                   48.33                  NaN               40.56
# 2                   59.86                  NaN               71.78
# 3                  100.64                  NaN               44.46
# 4                   93.54                  NaN                 NaN
# 5                     NaN                  NaN                 NaN
# ...                   ...                  ...                 ...
# 43741              100.64                  NaN               86.36
# 43742                 NaN                  NaN                 NaN
# 43743               48.33                  NaN               46.75
# 43744               43.39                  NaN                 NaN
# 43745               29.69                  NaN                 NaN
#
#       selfcare_measure_delta mobility_measure_delta
# id
# 1                       6.28                    NaN
# 2                      11.53                    NaN
# 3                      55.12                    NaN
# 4                      43.90                    NaN
# 5                        NaN                    NaN
# ...                      ...                    ...
# 43741                    NaN                    NaN
# 43742                    NaN                    NaN
# 43743                    NaN                    NaN
# 43744                    NaN                    NaN
# 43745                   2.05                    NaN
#
# [43745 rows x 454 columns]

# %% [markdown]
# #### Column: "language"

# %%
# safe buffer
last_df = df

# %%
# process column "language": English or Non-English
df = last_df.copy() # always work on a fresh copy of last step's output

categorical_feature_set.add('language')

print(df['language'].unique())
df['language'] = df['language'].str.contains('eng|enlish', case=False, na=False)
df['language'] = df['language'].map({True: 'English', False: 'Non-English'})
print(df['language'].unique())
# Out:
# ['English' 'ENGLISH' 'Spanish' 'Other' 'eng' 'english' 'spanish' 'SPANISH'
#  'Vietnamese' 'Unknown' 'Polish' 'English and Spanish' 'Creole' 'Eng'
#  'MANDARIN' 'Cambodia' 'Chinese' 'Korean' 'Englissh' 'HINDI' 'Enlglish'
#  'POLISH' 'Sindhi/Urdu then English' 'French' 'Farsi' 'Panjabi' 'Mandarin'
#  'Japanese' 'Malayalam' 'Ghana' 'Cambodian' 'ENLGISH' 'Indonesian'
#  'tagalog' 'Swahili' 'Estonian' 'Portuguese' 'Cantonese'
#  'Chinese, Mandarin' 'gujarati' 'German' 'other' 'Hmong' 'English/Spanish'
#  'Russian' 'Englsih' 'Karen' 'Arabic' 'CREOLE' 'Undetermined' 'Gujarati'
#  'Urdu' 'BANGLADESH' 'Hindi' 'Tagalog' 'TOISAN' 'Spanish and English'
#  'Chinese - Canto' 'korean' 'creole' 'ASL' 'WHITE' 'Italian'
#  'ENGLISH/TURKISH' 'Haitian' 'TAGALOG' 'en' 'CANTONESE' 'ENglish'
#  'CHINESE' 'Serbian' 'Ukrainian' 'Persian' 'Swedish' 'English, Spanish'
#  'Enbglish' 'Bosnian' 'Albanian' 'LAO' 'chinese' 'Chinese - Manda'
#  'Slovak' 'French Creole' 'English, Other' 'ukranian' 'ENGLSIH' 'Enlish'
#  'Chuukese' 'VIETNAMESE' 'Afrikaans' 'Punjabi' 'Romanian' 'ARMENIAN'
#  'Spanish/English' 'asl' 'Greek' 'KOREAN' 'Navajo' 'Passa Africa' 'Somali'
#  'Armenian' 'Lao' 'mandarin' 'English, Urdu' 'THAI' 'french'
#  'Sudanese Arabic' 'Zomi' 'Indian' 'Nepali' 'Mon-Khmer Languaes'
#  'Mandarin Chines' 'Catonese' 'Haitian Creole' 'English/ Spanish'
#  'Sign Language/English' 'cantonese' 'Bengali'
#  'Chinese, English, Japanese, La'
#  'Karenni or Kayah, understands Burmese but is not fluent' 'Croatian'
#  'vietnamese' 'RUSSIAN' 'Basque' 'Burmese' 'Czech' 'JAPANESE' 'Assyrian'
#  'Montagnard Jarai' 'Yemeni' 'eenglish' 'language' 'English, French'
#  'Arobic/English' 'BURMESE' 'Mandarin (Chine' 'MANDERIN' 'Kannada'
#  'Amharic' 'Toishanese' 'Sign Language' 'Engliish' 'panjabi'
#  'Spanish or Engl' 'amharic' 'Ukranian' 'Jarai' 'Sinhalese'
#  'Unable to Answer/ English' 'VIETNAMESE/ CHIU CHOU' 'Toisanese' 'BAPTIST'
#  'Kinyarwanda' 'AMERICAN ENGLISH' 'UKRAINIAN' 'ENGILSH' 'Khmer'
#  'spanish/english' 'Bangole' 'Hebrew/Kpelli' 'Japenese' 'ENGLSH' 'Enlgish'
#  'Bangladesh' 'GREEK' 'TAIWANESE' 'Engilsh' 'Other Native No' 'Telugu'
#  'Twi' 'Turkish' 'CAMBODIAN' 'spanish. Unders' 'CANTONESE/ VIETNAMESE'
#  'Spanish / English' 'eniglish' 'ENGISH' 'ENG' 'punjabi' 'PUNJABI' 'ALS'
#  'Hebrew' 'Northern Khmer' 'English Kiowa' 'English/French'
#  'Punjabi/Hindi/English' 'Siberian' 'Vietamese' 'serbian'
#  'English/Burmese' 'English/Creole' 'Ehglish' 'Canton-Chinese' 'Declined'
#  'Engish' 'Englis' 'eNGLISH' 'SPANISH AND ENGLISH'
#  'CREOLE/ENGLISH SPEAKING' 'English/ Cambodian- Bilingual' 'es' 'SERBIAN'
#  'English, Polish' 'Vietnamese & Chinese' 'Spanish/ English'
#  'Ilicano / Tagalog' 'Bisaya/English' 'English, italia' "English'"
#  'Farsi refusing' 'italian']
# ['English' 'Non-English']

# %% [markdown]
# #### Column: "hispanic"

# %%
# safe buffer
last_df = df

# %%
# process column "hispanic" (ethnicity): English or Non-English
df = last_df.copy() # always work on a fresh copy of last step's output

categorical_feature_set.add('hispanic')
print("nan count before:", pd.isna(df['hispanic']).sum())

# 1. fill 'Yes' where any of the hispanic subcategories are 'Yes'
hispanic_yes_cols = ['hispanic_mexican', 'hispanic_puertorican', 'hispanic_cuban', 'hispanic_other']
df.loc[df['hispanic'].isna() & (df[hispanic_yes_cols] == 'Yes').any(axis=1), 'hispanic'] = 'Yes'

# 2. fill 'No' where hispanic_unable or hispanic_declined are 'Yes'
hispanic_no_cols = ['hispanic_unable', 'hispanic_declined']
df.loc[df['hispanic'].isna() & (df[hispanic_no_cols] == 'Yes').any(axis=1), 'hispanic'] = 'No'

# 3. for rows where 'hispanic' is still NaN, fill it with 'No'
df['hispanic'].fillna('No', inplace=True)

print("nan count after:", pd.isna(df['hispanic']).sum())
print(df['hispanic'].unique())
# Out:
# nan count before: 4514
# nan count after: 0
# ['No' 'Yes']

# %% [markdown]
# #### Column: "race"

# %%
# safe buffer
last_df = df

# %%
# process column "race"
df = last_df.copy() # always work on a fresh copy of last step's output

categorical_feature_set.add('race')

# grouping east asians (chinese, japanese, korean)
race_is_east_asian = df[['race_chinese', 'race_japanese', 'race_korean']].eq('Yes').any(axis=1) # bool column

# grouping other asians (filipino, vietnamese, asian other)
race_is_asian_other = df[['race_filipino', 'race_vietnamese', 'race_asianother']].eq('Yes').any(axis=1)

# grouping pacific islanders (hawaiian, guam, samoan, pacific islander other)
race_is_pacific_islander = df[['race_hawaiian', 'race_guam', 'race_samoan', 'race_pacificislander_other']].eq('Yes').any(axis=1)

# asian indian mapping
race_is_asian_indian = df['race_asianindian'].eq('Yes')

# grouping unknown (unable, declined, none of the above)
race_is_unknown = df[['race_unable', 'race_declined', 'race_noneoftheabove']].eq('Yes').any(axis=1)

# keeping the original race columns (race_white, race_black, race_alaskan) as is but casting them to binary
race_is_white = df['race_white'].eq('Yes')
race_is_black = df['race_black'].eq('Yes')
race_is_alaskan = df['race_alaskan'].eq('Yes')

df['race'] = np.nan
df['race'] = df['race'].astype('object')

df.loc[race_is_white, 'race'] = 'White'
df.loc[race_is_black, 'race'] = 'Black'
df.loc[race_is_alaskan, 'race'] = 'Alaskan'
df.loc[race_is_asian_indian, 'race'] = 'Asian_Indian'
df.loc[race_is_east_asian, 'race'] = 'East_Asian'
df.loc[race_is_asian_other, 'race'] = 'Southeast_Asian'
df.loc[race_is_pacific_islander, 'race'] = 'Pacific_islander'
df.loc[race_is_unknown, 'race'] = 'Unknown'

# fill any remaining NaNs with 'Unknown' if no condition matched
df['race'].fillna('Unknown', inplace=True)

print("nan count after:", pd.isna(df['race']).sum())
print(df['race'].unique())
# Out:
# nan count after: 0
# ['White' 'Black' 'Unknown' 'Southeast_Asian' 'Alaskan' 'Asian_Indian'
#  'East_Asian' 'Pacific_islander']

# %% [markdown]
# #### Column: all bool features
# **NaNs**: There shouldn't be any NaN left after processing.

# %%
# safe buffer
last_df = df

# %%
# bool features are generally recorded as "Yes" / "No" in raw data; covert to 0 / 1
df = last_df.copy() # always work on a fresh copy of last step's output

binary_features = [
    "transport_lack_med",
    "transport_lack_nonmed",
    "conduct_bims",
    "conduct_sams",
    "sams_season",
    "sams_room",
    "sams_names",
    "sams_hosp",
    "sams_none_above",
    "acute_mental_change",
    "wc_manual_prior",
    "wc_motor_prior",
    "mechlift_prior",
    "walker_prior",
    "orth_pros_prior",
    "no_device_prior",
    "wc_user",
    "pvd_comorbid",
    "diabetes_comorbid",
    "nutrition_parenteral_adm",
    "nutrition_tube_adm",
    "nutrition_mech_diet_adm",
    "nutrition_ther_diet_adm",
    "antipsychotic_taking_adm",
    "antipsychotic_ind_adm",
    "anticoagulant_taking_adm",
    "anticoagulant_ind_adm",
    "antibiotic_taking_adm",
    "antibiotic_ind_adm",
    "opioid_taking_adm",
    "opioid_ind_adm",
    "antiplatelet_taking_adm",
    "antiplatelet_ind_adm",
    "hypoglycemic_taking_adm",
    "hypoglycemic_ind_adm",
    "chemo_adm",
    "chemo_iv_adm",
    "chemo_oral_adm",
    "chemo_other_adm",
    "radiation_adm",
    "oxygen_adm",
    "oxygen_cont_adm",
    "oxygen_int_adm",
    "oxygen_high_adm",
    "suctioning_adm",
    "suctioning_sched_adm",
    "suctioning_asneeded_adm",
    "trach_adm",
    "vent_invasive_adm",
    "vent_noninvasive_adm",
    "vent_bipap_adm",
    "vent_cpap_adm",
    "meds_iv_adm",
    "meds_iv_vasoactive_adm",
    "meds_iv_antibiotic_adm",
    "meds_iv_anticoagulant_adm",
    "meds_iv_other_adm",
    "transfusions_adm",
    "dialysis_adm",
    "hemodialysis_adm",
    "peritoneal_dialysis_adm",
    "iv_access_adm",
    "iv_access_periph_adm",
    "iv_access_mid_adm",
    "iv_access_cent_adm",
]
for name in binary_features:
    binary_feature_set.add(name)
    print(f"----------working on: {name}----------")
    df[name] = df[name].apply(lambda x: x.lower() if isinstance(x, str) else x) # lower-casify first
    uniques = set(df[name].unique())
    print("uniques before:", uniques)
    print("dtype before:", df[name].dtype)
    print("nan count before:", pd.isna(df[name]).sum())
    if uniques == {0, 1}: # already processed
        continue
    if name == "conduct_sams":
        df[name].fillna("yes", inplace=True)
        df[name].replace({
            "yes": 1,
            "no": 0,
        }, inplace=True)
    elif name in {"sams_season","sams_room","sams_names","sams_hosp"}: # default: yes for all those completed BIMS
        df[name].replace({
            "no": 0,
            "yes": 1,
            np.nan: 1,
        }, inplace=True)
        df[name] = df[name].astype('int64')
    elif name == "sams_none_above":
        df[name].replace({
            "no": 0,
            "yes": 1,
            np.nan: 0,
        }, inplace=True)
        df[name] = df[name].astype('int64')
    elif '_ind_' in name:
        df[name].replace({
            "no": 0,
            "yes": 1,
            np.nan: 0,
        }, inplace=True)
        df[name] = df[name].astype('int64')
    else: # default behavior
        if uniques == {np.nan, "yes"}:
            df[name].fillna("no", inplace=True)
        elif uniques == {np.nan, "no"}:
            df[name].fillna("yes", inplace=True)
        elif uniques != {"yes", "no"}:
            raise Exception(f"{name} is not a binary feature")
        df[name].replace({
            "yes": 1,
            "no": 0,
        }, inplace=True)
    print("uniques after:", df[name].unique())
    if set(df[name].unique()) != {0, 1}:
        raise Exception(f"{name} is not well-formated, double check!")
    print("dtype after:", df[name].dtype)
    print("nan count after:", pd.isna(df[name]).sum())
# Out:
# ----------working on: transport_lack_med----------
# uniques before: {'yes', nan}
# dtype before: object
# nan count before: 42493
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: transport_lack_nonmed----------
# uniques before: {'yes', nan}
# dtype before: object
# nan count before: 42725
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: conduct_bims----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: conduct_sams----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 3896
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: sams_season----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 39019
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: sams_room----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 39019
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: sams_names----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 39019
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: sams_hosp----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 39019
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: sams_none_above----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 39019
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: acute_mental_change----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: wc_manual_prior----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: wc_motor_prior----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: mechlift_prior----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: walker_prior----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: orth_pros_prior----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: no_device_prior----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: wc_user----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: pvd_comorbid----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: diabetes_comorbid----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: nutrition_parenteral_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: nutrition_tube_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: nutrition_mech_diet_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: nutrition_ther_diet_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: antipsychotic_taking_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: antipsychotic_ind_adm----------
# uniques before: {'yes', nan, 'no'}
# dtype before: object
# nan count before: 39831
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: anticoagulant_taking_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: anticoagulant_ind_adm----------
# uniques before: {'no', nan, 'yes'}
# dtype before: object
# nan count before: 11964
# uniques after: [1 0]
# dtype after: int64
# nan count after: 0
# ----------working on: antibiotic_taking_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: antibiotic_ind_adm----------
# uniques before: {'yes', nan, 'no'}
# dtype before: object
# nan count before: 36626
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: opioid_taking_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: opioid_ind_adm----------
# uniques before: {'yes', nan, 'no'}
# dtype before: object
# nan count before: 34451
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: antiplatelet_taking_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: antiplatelet_ind_adm----------
# uniques before: {'yes', nan, 'no'}
# dtype before: object
# nan count before: 14862
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: hypoglycemic_taking_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: hypoglycemic_ind_adm----------
# uniques before: {'yes', nan, 'no'}
# dtype before: object
# nan count before: 26605
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: chemo_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: chemo_iv_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: chemo_oral_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: chemo_other_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: radiation_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: oxygen_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: oxygen_cont_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: oxygen_int_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: oxygen_high_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: suctioning_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: suctioning_sched_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: suctioning_asneeded_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: trach_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: vent_invasive_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: vent_noninvasive_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: vent_bipap_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: vent_cpap_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: meds_iv_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: meds_iv_vasoactive_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: meds_iv_antibiotic_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: meds_iv_anticoagulant_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: meds_iv_other_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: transfusions_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: dialysis_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: hemodialysis_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: peritoneal_dialysis_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: iv_access_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: iv_access_periph_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: iv_access_mid_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0
# ----------working on: iv_access_cent_adm----------
# uniques before: {'no', 'yes'}
# dtype before: object
# nan count before: 0
# uniques after: [0 1]
# dtype after: int64
# nan count after: 0

# %% [markdown]
# #### Column: all ranked integer features
# **NaNs**: Leave them alone. Different imputation strategies can be applied later.

# %%
# safe buffer
last_df = df

# %%
# each case may need separate handling
df = last_df.copy() # always work on a fresh copy of last step's output

ranked_int_features = [
    "admityear",
    "hearing_adm",
    "vision_adm",
    "health_lit_adm",
    "expression_adm",
    "understand_verbal_adm",
    "bims_3words",
    "bims_year",
    "bims_month",
    "bims_day",
    "bims_recall_sock",
    "bims_recall_blue",
    "bims_recall_bed",
    "bims_total",
    "low_interest_adm",
    "low_interest_freq_adm",
    "depressed_adm",
    "depressed_freq_adm",
    "sleep_trouble_adm",
    "sleep_trouble_freq_adm",
    "tired_adm",
    "tired_freq_adm",
    "appetite_adm",
    "appetite_freq_adm",
    "feel_bad_adm",
    "feel_bad_freq_adm",
    "concentrate_adm",
    "concentrate_freq_adm",
    "slowfast_adm",
    "slowfast_freq_adm",
    "selfharm_adm",
    "selfharm_freq_adm",
    "mood_total_adm",
    "socisolation_adm",
    "selfcare_prior",
    "mobility_prior",
    "stairs_prior",
    "func_cog_prior",
    "eating_adm",
    "oral_adm",
    "toileting_adm",
    "bathe_adm",
    "dress_upper_adm",
    "dress_lower_adm",
    "footwear_adm",
    "roll_lr_adm",
    "sit_lying_adm",
    "lying_sit_adm",
    "sit_stand_adm",
    "bed_chair_adm",
    "toilet_trans_adm",
    "car_trans_adm",
    "walk10ft_adm",
    "walk50ft_adm",
    "walk150ft_adm",
    "walk10ft_uneven_adm",
    "walk1step_adm",
    "walk4step_adm",
    "walk12step_adm",
    "pickup_adm",
    "wheel50ft_adm",
    "wheel150ft_adm",
    "bladder_incontinence",
    "bowel_incontinence",
    "pain_sleep_adm",
    "pain_therapy_adm",
    "pain_activities_adm",
    "stage1_pu_adm",
    "stage2_pu_adm",
    "stage3_pu_adm",
    "stage4_pu_adm",
    "unstageable_dressing_pu_adm",
    "unstageable_slough_pu_adm",
    "unstageable_deep_pu_adm",
    "med_follow_up",
]

for name in ranked_int_features:
    ranked_int_feature_set.add(name)
    print(f"----------working on: {name}----------")
    print("uniques before:", df[name].unique())
    print("dtype before:", df[name].dtype)
    print("nan count before:", pd.isna(df[name]).sum())
    if name == "admityear": # simply replace float as int
        df[name] = df[name].apply(lambda x: int(x))
    elif name == "health_lit_adm":
        inverse_lookup = {v:k for k, v in lookup_table[name].items()}
        possible_nan_keys = ["Decline", "Unable", "Refuse"]
        for k in possible_nan_keys:
            inverse_lookup[k] = np.nan
        df[name].replace(inverse_lookup, inplace=True)
        df[name] = df[name].apply(lambda x: int(x) if pd.notna(x) else pd.NA).astype('Int64')
    elif name == "bims_total":
        df[name].replace({'unable_to_complete': pd.NA,
                          np.nan: pd.NA}, inplace=True)
        df[name] = df[name].apply(lambda x: int(float(x)) if pd.notna(x) else pd.NA).astype('Int64')
    else: # default behavior
        inverse_lookup = {v:k for k, v in lookup_table[name].items()}
        possible_nan_keys = [
            "Decline",
            "Unable", "unable"
            "Refuse",
            "No_response",
            "Unknown",
            "Not_applicable",
            "Not_attempted",
            "Safety",
            "Not_rated",
            ]
        for k in possible_nan_keys:
            inverse_lookup[k] = np.nan
        df[name].replace(inverse_lookup, inplace=True)
        df[name] = df[name].apply(lambda x: int(float(x)) if pd.notna(x) else pd.NA).astype('Int64')
    print("uniques after:", df[name].unique())
    print("dtype after:", df[name].dtype)
    print("nan count after:", pd.isna(df[name]).sum())
# Out:
# ----------working on: admityear----------
# uniques before: [2023. 2022.]
# dtype before: float64
# nan count before: 0
# uniques after: [2023 2022]
# dtype after: int64
# nan count after: 0
# ----------working on: hearing_adm----------
# uniques before: ['Adequate' 'Mod_difficulty' 'Min_difficulty' 'Highly_impaired']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, 2, 1, 3]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 0
# ----------working on: vision_adm----------
# uniques before: ['Adequate' 'Impaired' 'Mod_impaired' 'Highly_impaired'
#  'Severely_impaired']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, 1, 2, 3, 4]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 0
# ----------working on: health_lit_adm----------
# uniques before: ['Never' 'Rarely' 'Unable' 'Often' 'Sometimes' 'Always' 'Decline']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, 1, <NA>, 3, 2, 4]
# Length: 6, dtype: Int64
# dtype after: Int64
# nan count after: 3501
# ----------working on: expression_adm----------
# uniques before: ['Freq_difficulty' 'No_difficulty' 'Never_expresses' 'Some_difficulty']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [2, 4, 1, 3]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 0
# ----------working on: understand_verbal_adm----------
# uniques before: ['sometimes_understands' 'Understands' 'Rarely_understands'
#  'Usually_understands']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [2, 4, 1, 3]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 0
# ----------working on: bims_3words----------
# uniques before: ['Zero' 'Three' nan 'Two' 'One']
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 3, <NA>, 2, 1]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_year----------
# uniques before: ['5_years_off' 'Correct' nan '2_5_years_off' '1_year_off']
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 3, <NA>, 1, 2]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_month----------
# uniques before: ['1_month_off' 'Correct' nan '6_days_off']
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 2, <NA>, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_day----------
# uniques before: ['Incorrect' 'Correct' nan]
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 1, <NA>]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_recall_sock----------
# uniques before: ['No' 'Cued' 'Recall' nan]
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 1, 2, <NA>]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_recall_blue----------
# uniques before: ['No' 'Cued' 'Recall' nan]
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 1, 2, <NA>]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_recall_bed----------
# uniques before: ['No' 'Recall' nan 'Cued']
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [0, 2, <NA>, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 3896
# ----------working on: bims_total----------
# uniques before: ['unable_to_complete' '13.0' '15.0' nan '6.0' '14.0' '7.0' '11.0' '5.0'
#  '3.0' '4.0' '12.0' '9.0' '10.0' '8.0' '0.0' '2.0' '1.0']
# dtype before: object
# nan count before: 3896
# uniques after: <IntegerArray>
# [<NA>, 13, 15, 6, 14, 7, 11, 5, 3, 4, 12, 9, 10, 8, 0, 2, 1]
# Length: 17, dtype: Int64
# dtype after: Int64
# nan count after: 4726
# ----------working on: low_interest_adm----------
# uniques before: ['No' 'No_response' 'Yes']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, <NA>, 1]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 4636
# ----------working on: low_interest_freq_adm----------
# uniques before: ['Never' nan '2_6_days' '7_11_days' '12_14_days']
# dtype before: object
# nan count before: 4636
# uniques after: <IntegerArray>
# [0, <NA>, 1, 2, 3]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 4636
# ----------working on: depressed_adm----------
# uniques before: ['No' 'Yes' 'No_response']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, 1, <NA>]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 4700
# ----------working on: depressed_freq_adm----------
# uniques before: ['Never' nan '2_6_days' '7_11_days' '12_14_days']
# dtype before: object
# nan count before: 4700
# uniques after: <IntegerArray>
# [0, <NA>, 1, 2, 3]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 4700
# ----------working on: sleep_trouble_adm----------
# uniques before: [nan 'No_response' 'Yes' 'No']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41933
# ----------working on: sleep_trouble_freq_adm----------
# uniques before: [nan '7_11_days' '12_14_days' 'Never' '2_6_days']
# dtype before: object
# nan count before: 41933
# uniques after: <IntegerArray>
# [<NA>, 2, 3, 0, 1]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41933
# ----------working on: tired_adm----------
# uniques before: [nan 'No_response' 'Yes' 'No']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41931
# ----------working on: tired_freq_adm----------
# uniques before: [nan '7_11_days' '12_14_days' 'Never' '2_6_days']
# dtype before: object
# nan count before: 41931
# uniques after: <IntegerArray>
# [<NA>, 2, 3, 0, 1]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41931
# ----------working on: appetite_adm----------
# uniques before: [nan 'No_response' 'Yes' 'No']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41944
# ----------working on: appetite_freq_adm----------
# uniques before: [nan '7_11_days' 'Never' '2_6_days' '12_14_days']
# dtype before: object
# nan count before: 41944
# uniques after: <IntegerArray>
# [<NA>, 2, 0, 1, 3]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41944
# ----------working on: feel_bad_adm----------
# uniques before: [nan 'No_response' 'Yes' 'No']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41944
# ----------working on: feel_bad_freq_adm----------
# uniques before: [nan '2_6_days' 'Never' '12_14_days' '7_11_days']
# dtype before: object
# nan count before: 41944
# uniques after: <IntegerArray>
# [<NA>, 1, 0, 3, 2]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41944
# ----------working on: concentrate_adm----------
# uniques before: [nan 'No_response' 'Yes' 'No']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41934
# ----------working on: concentrate_freq_adm----------
# uniques before: [nan '7_11_days' '12_14_days' 'Never' '2_6_days']
# dtype before: object
# nan count before: 41934
# uniques after: <IntegerArray>
# [<NA>, 2, 3, 0, 1]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41934
# ----------working on: slowfast_adm----------
# uniques before: [nan 'No_response' 'Yes' 'No']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41947
# ----------working on: slowfast_freq_adm----------
# uniques before: [nan '7_11_days' '12_14_days' '2_6_days' 'Never']
# dtype before: object
# nan count before: 41947
# uniques after: <IntegerArray>
# [<NA>, 2, 3, 1, 0]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41947
# ----------working on: selfharm_adm----------
# uniques before: [nan 'No_response' 'No' 'Yes']
# dtype before: object
# nan count before: 41851
# uniques after: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 41972
# ----------working on: selfharm_freq_adm----------
# uniques before: [nan 'Never' '12_14_days' '7_11_days' '2_6_days']
# dtype before: object
# nan count before: 41972
# uniques after: <IntegerArray>
# [<NA>, 0, 3, 2, 1]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 41972
# ----------working on: mood_total_adm----------
# uniques before: ['0.0' nan '2.0' '1.0' 'Unable' '15.0' '20.0' '13.0' '14.0' '4.0' '10.0'
#  '5.0' '17.0' '8.0' '22.0' '3.0' '9.0' '16.0' '6.0' '12.0' '11.0' '18.0'
#  '21.0' '7.0' '23.0' '24.0' '19.0' '26.0' '27.0' '25.0']
# dtype before: object
# nan count before: 4588
# uniques after: <IntegerArray>
# [   0, <NA>,    2,    1,   15,   20,   13,   14,    4,   10,    5,   17,    8,
#    22,    3,    9,   16,    6,   12,   11,   18,   21,    7,   23,   24,   19,
#    26,   27,   25]
# Length: 29, dtype: Int64
# dtype after: Int64
# nan count after: 4682
# ----------working on: socisolation_adm----------
# uniques before: ['Never' 'Unable' 'Sometimes' 'Rarely' 'Often' 'Always' 'Decline']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, <NA>, 2, 1, 3, 4]
# Length: 6, dtype: Int64
# dtype after: Int64
# nan count after: 4198
# ----------working on: selfcare_prior----------
# uniques before: ['Independent' 'Unknown' 'Help' 'Dependent' 'Not_applicable']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [3, <NA>, 2, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 279
# ----------working on: mobility_prior----------
# uniques before: ['Independent' 'Unknown' 'Help' 'Dependent' 'Not_applicable']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [3, <NA>, 2, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 638
# ----------working on: stairs_prior----------
# uniques before: ['Independent' 'Unknown' 'Help' 'Not_applicable' 'Dependent']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [3, <NA>, 2, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 4069
# ----------working on: func_cog_prior----------
# uniques before: ['Independent' 'Unknown' 'Help' 'Dependent' 'Not_applicable']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [3, <NA>, 2, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 638
# ----------working on: eating_adm----------
# uniques before: ['Supervised' 'Setup' 'Independent' nan 'Max_assist' 'Mod_assist'
#  'Dependent']
# dtype before: object
# nan count before: 2474
# uniques after: <IntegerArray>
# [4, 5, 6, <NA>, 2, 3, 1]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 2474
# ----------working on: oral_adm----------
# uniques before: ['Supervised' 'Setup' 'Mod_assist' 'Dependent' nan 'Independent'
#  'Max_assist']
# dtype before: object
# nan count before: 1387
# uniques after: <IntegerArray>
# [4, 5, 3, 1, <NA>, 6, 2]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 1387
# ----------working on: toileting_adm----------
# uniques before: ['Max_assist' 'Supervised' 'Mod_assist' 'Dependent' nan 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 984
# uniques after: <IntegerArray>
# [2, 4, 3, 1, <NA>, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 984
# ----------working on: bathe_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Dependent' nan 'Max_assist' 'Setup'
#  'Independent']
# dtype before: object
# nan count before: 4420
# uniques after: <IntegerArray>
# [3, 4, 1, <NA>, 2, 5, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 4420
# ----------working on: dress_upper_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Dependent' 'Setup' nan 'Max_assist'
#  'Independent']
# dtype before: object
# nan count before: 1750
# uniques after: <IntegerArray>
# [3, 4, 1, 5, <NA>, 2, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 1750
# ----------working on: dress_lower_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Dependent' 'Max_assist' nan 'Setup'
#  'Independent']
# dtype before: object
# nan count before: 1343
# uniques after: <IntegerArray>
# [3, 4, 1, 2, <NA>, 5, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 1343
# ----------working on: footwear_adm----------
# uniques before: ['Max_assist' 'Mod_assist' 'Setup' 'Supervised' 'Dependent' nan
#  'Independent']
# dtype before: object
# nan count before: 958
# uniques after: <IntegerArray>
# [2, 3, 5, 4, 1, <NA>, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 958
# ----------working on: roll_lr_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Independent' nan 'Setup' 'Dependent'
#  'Max_assist']
# dtype before: object
# nan count before: 1229
# uniques after: <IntegerArray>
# [3, 4, 6, <NA>, 5, 1, 2]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 1229
# ----------working on: sit_lying_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Max_assist' 'Independent' 'Dependent' nan
#  'Setup']
# dtype before: object
# nan count before: 1430
# uniques after: <IntegerArray>
# [3, 4, 2, 6, 1, <NA>, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 1430
# ----------working on: lying_sit_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Max_assist' 'Independent' nan 'Dependent'
#  'Setup']
# dtype before: object
# nan count before: 1433
# uniques after: <IntegerArray>
# [3, 4, 2, 6, <NA>, 1, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 1433
# ----------working on: sit_stand_adm----------
# uniques before: ['Mod_assist' 'Dependent' 'Supervised' 'Max_assist' nan 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 3711
# uniques after: <IntegerArray>
# [3, 1, 4, 2, <NA>, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 3711
# ----------working on: bed_chair_adm----------
# uniques before: ['Mod_assist' 'Dependent' 'Supervised' 'Max_assist' nan 'Setup'
#  'Independent']
# dtype before: object
# nan count before: 2403
# uniques after: <IntegerArray>
# [3, 1, 4, 2, <NA>, 5, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 2403
# ----------working on: toilet_trans_adm----------
# uniques before: ['Mod_assist' 'Supervised' 'Dependent' nan 'Max_assist' 'Setup'
#  'Independent']
# dtype before: object
# nan count before: 5618
# uniques after: <IntegerArray>
# [3, 4, 1, <NA>, 2, 5, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 5618
# ----------working on: car_trans_adm----------
# uniques before: [nan 'Supervised' 'Max_assist' 'Mod_assist' 'Dependent' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 24704
# uniques after: <IntegerArray>
# [<NA>, 4, 2, 3, 1, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 24704
# ----------working on: walk10ft_adm----------
# uniques before: ['Mod_assist' 'Supervised' nan 'Dependent' 'Max_assist' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 15365
# uniques after: <IntegerArray>
# [3, 4, <NA>, 1, 2, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 15365
# ----------working on: walk50ft_adm----------
# uniques before: ['Mod_assist' nan 'Supervised' 'Dependent' 'Max_assist' 'Setup'
#  'Independent']
# dtype before: object
# nan count before: 24103
# uniques after: <IntegerArray>
# [3, <NA>, 4, 1, 2, 5, 6]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 24103
# ----------working on: walk150ft_adm----------
# uniques before: [nan 'Mod_assist' 'Supervised' 'Dependent' 'Max_assist' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 32291
# uniques after: <IntegerArray>
# [<NA>, 3, 4, 1, 2, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 32291
# ----------working on: walk10ft_uneven_adm----------
# uniques before: [nan 'Supervised' 'Mod_assist' 'Max_assist' 'Dependent' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 31558
# uniques after: <IntegerArray>
# [<NA>, 4, 3, 2, 1, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 31558
# ----------working on: walk1step_adm----------
# uniques before: [nan 'Mod_assist' 'Max_assist' 'Supervised' 'Dependent' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 25778
# uniques after: <IntegerArray>
# [<NA>, 3, 2, 4, 1, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 25778
# ----------working on: walk4step_adm----------
# uniques before: [nan 'Supervised' 'Mod_assist' 'Max_assist' 'Dependent' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 29097
# uniques after: <IntegerArray>
# [<NA>, 4, 3, 2, 1, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 29097
# ----------working on: walk12step_adm----------
# uniques before: [nan 'Supervised' 'Dependent' 'Max_assist' 'Mod_assist' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 37282
# uniques after: <IntegerArray>
# [<NA>, 4, 1, 2, 3, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 37282
# ----------working on: pickup_adm----------
# uniques before: [nan 'Supervised' 'Mod_assist' 'Dependent' 'Max_assist' 'Independent'
#  'Setup']
# dtype before: object
# nan count before: 29537
# uniques after: <IntegerArray>
# [<NA>, 4, 3, 1, 2, 6, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 29537
# ----------working on: wheel50ft_adm----------
# uniques before: [nan 'Independent' 'Supervised' 'Dependent' 'Max_assist' 'Mod_assist'
#  'Safety' 'Setup' 'Refused' 'Not_attempted' 'Not_applicable']
# dtype before: object
# nan count before: 12902
# uniques after: <IntegerArray>
# [<NA>, 6, 4, 1, 2, 3, 5, 7]
# Length: 8, dtype: Int64
# dtype after: Int64
# nan count after: 18416
# ----------working on: wheel150ft_adm----------
# uniques before: [nan 'Safety' 'Dependent' 'Supervised' 'Mod_assist' 'Independent'
#  'Max_assist' 'Refused' 'Not_attempted' 'Not_applicable' 'Setup']
# dtype before: object
# nan count before: 12902
# uniques after: <IntegerArray>
# [<NA>, 1, 4, 3, 6, 2, 7, 5]
# Length: 8, dtype: Int64
# dtype after: Int64
# nan count after: 21491
# ----------working on: bladder_incontinence----------
# uniques before: ['Continent' 'Incontinent' 'Incont_weekly' 'Not_applicable' 'Incont_daily'
#  'Stress_incont' 'No_output']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, 4, 2, <NA>, 3, 1, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 2558
# ----------working on: bowel_incontinence----------
# uniques before: ['Freq_incont' 'Continent' 'Incontinent' 'Not_rated' 'Occ_incont']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [2, 0, 3, <NA>, 1]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 5931
# ----------working on: pain_sleep_adm----------
# uniques before: ['does_not_apply' 'Rarely' 'unable' 'occasionally' 'frequently'
#  'constantly']
# dtype before: object
# nan count before: 0
# uniques after: <IntegerArray>
# [0, 1, 8, 2, 3, 4]
# Length: 6, dtype: Int64
# dtype after: Int64
# nan count after: 0
# ----------working on: pain_therapy_adm----------
# uniques before: [nan 'Rarely' 'unable' 'occasionally' 'does_not_apply' 'frequently'
#  'constantly']
# dtype before: object
# nan count before: 12474
# uniques after: <IntegerArray>
# [<NA>, 1, 8, 2, 0, 3, 4]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 12474
# ----------working on: pain_activities_adm----------
# uniques before: [nan 'Rarely' 'unable' 'occasionally' 'constantly' 'frequently']
# dtype before: object
# nan count before: 12474
# uniques after: <IntegerArray>
# [<NA>, 1, 8, 2, 4, 3]
# Length: 6, dtype: Int64
# dtype after: Int64
# nan count after: 12474
# ----------working on: stage1_pu_adm----------
# uniques before: [nan  0.  1.  4.  2.  3.  5.]
# dtype before: float64
# nan count before: 39068
# uniques after: <IntegerArray>
# [<NA>, 0, 1, 4, 2, 3, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 39068
# ----------working on: stage2_pu_adm----------
# uniques before: [nan  0.  2.  1.  3.  5.  4.  6.]
# dtype before: float64
# nan count before: 39066
# uniques after: <IntegerArray>
# [<NA>, 0, 2, 1, 3, 5, 4, 6]
# Length: 8, dtype: Int64
# dtype after: Int64
# nan count after: 39066
# ----------working on: stage3_pu_adm----------
# uniques before: [nan  1.  0.  2.  3.  4.  5.]
# dtype before: float64
# nan count before: 39066
# uniques after: <IntegerArray>
# [<NA>, 1, 0, 2, 3, 4, 5]
# Length: 7, dtype: Int64
# dtype after: Int64
# nan count after: 39066
# ----------working on: stage4_pu_adm----------
# uniques before: [nan  0.  1.  2.  3.]
# dtype before: float64
# nan count before: 39066
# uniques after: <IntegerArray>
# [<NA>, 0, 1, 2, 3]
# Length: 5, dtype: Int64
# dtype after: Int64
# nan count after: 39066
# ----------working on: unstageable_dressing_pu_adm----------
# uniques before: [nan  0.  2.  1.]
# dtype before: float64
# nan count before: 39066
# uniques after: <IntegerArray>
# [<NA>, 0, 2, 1]
# Length: 4, dtype: Int64
# dtype after: Int64
# nan count after: 39066
# ----------working on: unstageable_slough_pu_adm----------
# uniques before: [nan  1.  0.  2.  4.  6.  3.  9.  5.]
# dtype before: float64
# nan count before: 39066
# uniques after: <IntegerArray>
# [<NA>, 1, 0, 2, 4, 6, 3, 9, 5]
# Length: 9, dtype: Int64
# dtype after: Int64
# nan count after: 39066
# ----------working on: unstageable_deep_pu_adm----------
# uniques before: [nan  8.  1.  0.  2.  3.  4.  5.  6.  9.  7.]
# dtype before: float64
# nan count before: 39066
# uniques after: <IntegerArray>
# [<NA>, 8, 1, 0, 2, 3, 4, 5, 6, 9, 7]
# Length: 11, dtype: Int64
# dtype after: Int64
# nan count after: 39066
# ----------working on: med_follow_up----------
# uniques before: [nan 'Yes' 'No']
# dtype before: object
# nan count before: 39175
# uniques after: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
# dtype after: Int64
# nan count after: 39175

# %% [markdown]
# #### Column: all numeric columns
# **NaNs**: Leave them alone. Different imputation strategies can be applied later.

# %%
# safe buffer
last_df = df

# %%
# replace nan with "Unknown", replace spaces with underscores
df = last_df.copy() # always work on a fresh copy of last step's output

numeric_features = [
    "heightinches",
    "weightpounds",
    "ptindweek1",
    "ptconweek1",
    "ptgrpweek1",
    "ptcoweek1",
    "otindweek1",
    "otconweek1",
    "otgrpweek1",
    "otcoweek1",
    "slpindweek1",
    "slpconweek1",
    "slpgrpweek1",
    "slpcoweek1",
    "ptindweek2",
    "ptconweek2",
    "ptgrpweek2",
    "ptcoweek2",
    "otindweek2",
    "otconweek2",
    "otgrpweek2",
    "otcoweek2",
    "slpindweek2",
    "slpconweek2",
    "slpgrpweek2",
    "slpcoweek2",
    "age_at_admit",
    "los",
    "ric",
    "cmg",
    "selfcare_measure_adm",
    "mobility_measure_adm"
]
# TODO

for name in numeric_features:
    numeric_feature_set.add(name)

# %% [markdown]
# #### Column: all categorical columns
#
# **NaNs**: Simply set as "Unknwon". Later if imputation is needed you can still do so.

# %%
# safe buffer
last_df = df

# %%
# replace nan with "Unknown", replace spaces with underscores
df = last_df.copy() # always work on a fresh copy of last step's output

categorical_features = [
    "sex",
    "marital_status",
    "admitclass",
    "admit_from",
    "prehospital_living",
    "payor_primary",
    "arthritis",
    "inattention_adm",
    "disorganized_adm",
    "altered_adm",
    "wc50_type",
    "wc150_type",
    "falls_hx",
    "prior_surgery",
    "drug_regimen_review",
    "tier",
]   

for name in categorical_features:
    categorical_feature_set.add(name)
    print(f"----------working on: {name}----------")
    print("uniques before:", df[name].unique())
    print("dtype before:", df[name].dtype)
    print("nan count before:", pd.isna(df[name]).sum())
    if name in {"admitclass", "tier"}: # categorical but labels are integers
        df[name] = df[name].apply(lambda x: str(int(float(x))) if pd.notna(x) else "Unknown").astype(str)
    
    else: # default behavior
        df[name] = df[name].apply(lambda x: str(x).replace(' ', '_') if pd.notna(x) else "Unknown").astype(str)
    print("uniques after:", df[name].unique())
    print("dtype after:", df[name].dtype)
    print("nan count after:", pd.isna(df[name]).sum())
# Out:
# ----------working on: sex----------
# uniques before: ['female' 'male']
# dtype before: object
# nan count before: 0
# uniques after: ['female' 'male']
# dtype after: object
# nan count after: 0
# ----------working on: marital_status----------
# uniques before: ['Married' 'Widowed' nan 'Divorced' 'Separated' 'Never married']
# dtype before: object
# nan count before: 2533
# uniques after: ['Married' 'Widowed' 'Unknown' 'Divorced' 'Separated' 'Never_married']
# dtype after: object
# nan count after: 0
# ----------working on: admitclass----------
# uniques before: [ 1.  4.  3. nan  5.  2.]
# dtype before: float64
# nan count before: 3861
# uniques after: ['1' '4' '3' 'Unknown' '5' '2']
# dtype after: object
# nan count after: 0
# ----------working on: admit_from----------
# uniques before: ['Short-term general hospital' 'Home' 'Skilled nursing facility'
#  'Home health service' 'Long-term care hospital' 'Not listed'
#  'Another IRF' 'Intermediate care' 'Critical access hospital'
#  'Medicaid nursing facility' 'Inpatient psychiatric facility' 'Swing bed'
#  'Hospice (home)' 'Hospice (facility)']
# dtype before: object
# nan count before: 0
# uniques after: ['Short-term_general_hospital' 'Home' 'Skilled_nursing_facility'
#  'Home_health_service' 'Long-term_care_hospital' 'Not_listed'
#  'Another_IRF' 'Intermediate_care' 'Critical_access_hospital'
#  'Medicaid_nursing_facility' 'Inpatient_psychiatric_facility' 'Swing_bed'
#  'Hospice_(home)' 'Hospice_(facility)']
# dtype after: object
# nan count after: 0
# ----------working on: prehospital_living----------
# uniques before: ['Home' 'Inpatient psychiatric facility' 'Home health service'
#  'Intermediate care' 'Skilled nursing facility'
#  'Medicaid nursing facility' 'Short-term general hospital' 'Not listed'
#  'Long-term care hospital' 'Another IRF']
# dtype before: object
# nan count before: 0
# uniques after: ['Home' 'Inpatient_psychiatric_facility' 'Home_health_service'
#  'Intermediate_care' 'Skilled_nursing_facility'
#  'Medicaid_nursing_facility' 'Short-term_general_hospital' 'Not_listed'
#  'Long-term_care_hospital' 'Another_IRF']
# dtype after: object
# nan count after: 0
# ----------working on: payor_primary----------
# uniques before: ['Medicare FFS' 'Medicare Advantage' 'Not listed']
# dtype before: object
# nan count before: 0
# uniques after: ['Medicare_FFS' 'Medicare_Advantage' 'Not_listed']
# dtype after: object
# nan count after: 0
# ----------working on: arthritis----------
# uniques before: ['No' 'Yes']
# dtype before: object
# nan count before: 0
# uniques after: ['No' 'Yes']
# dtype after: object
# nan count after: 0
# ----------working on: inattention_adm----------
# uniques before: ['Not_present' 'Continuous' 'Fluctuates']
# dtype before: object
# nan count before: 0
# uniques after: ['Not_present' 'Continuous' 'Fluctuates']
# dtype after: object
# nan count after: 0
# ----------working on: disorganized_adm----------
# uniques before: ['Not_present' 'Fluctuates' 'Continuous']
# dtype before: object
# nan count before: 0
# uniques after: ['Not_present' 'Fluctuates' 'Continuous']
# dtype after: object
# nan count after: 0
# ----------working on: altered_adm----------
# uniques before: ['Not_present' 'Fluctuates' 'Continuous']
# dtype before: object
# nan count before: 0
# uniques after: ['Not_present' 'Fluctuates' 'Continuous']
# dtype after: object
# nan count after: 0
# ----------working on: wc50_type----------
# uniques before: [nan 'manual' 'motorized']
# dtype before: object
# nan count before: 12902
# uniques after: ['Unknown' 'manual' 'motorized']
# dtype after: object
# nan count after: 0
# ----------working on: wc150_type----------
# uniques before: [nan 'manual' 'motorized']
# dtype before: object
# nan count before: 12902
# uniques after: ['Unknown' 'manual' 'motorized']
# dtype after: object
# nan count after: 0
# ----------working on: falls_hx----------
# uniques before: ['No' 'Yes' 'Unknown']
# dtype before: object
# nan count before: 0
# uniques after: ['No' 'Yes' 'Unknown']
# dtype after: object
# nan count after: 0
# ----------working on: prior_surgery----------
# uniques before: ['No' 'Yes' 'Unknown']
# dtype before: object
# nan count before: 0
# uniques after: ['No' 'Yes' 'Unknown']
# dtype after: object
# nan count after: 0
# ----------working on: drug_regimen_review----------
# uniques before: ['No' 'Yes' 'Not_applicable']
# dtype before: object
# nan count before: 0
# uniques after: ['No' 'Yes' 'Not_applicable']
# dtype after: object
# nan count after: 0
# ----------working on: tier----------
# uniques before: [ 3. nan  2.  1.]
# dtype before: float64
# nan count before: 17819
# uniques after: ['3' 'Unknown' '2' '1']
# dtype after: object
# nan count after: 0

# %% [markdown]
# #### Save

# %%
# show processed features
feature_names = [*df.head()]
processed_feature_dtypes = df.dtypes
print("total # of features:", len(feature_names))
print(tabulate([(index, name, processed_feature_dtypes[name]) for index, name in enumerate(feature_names)], headers=["Index", "Name", "Dtype"], tablefmt="grid"))
# Out:
# total # of features: 455
# +---------+--------------------------------+---------+
# |   Index | Name                           | Dtype   |
# +=========+================================+=========+
# |       0 | sex                            | object  |
# +---------+--------------------------------+---------+
# |       1 | marital_status                 | object  |
# +---------+--------------------------------+---------+
# |       2 | admityear                      | int64   |
# +---------+--------------------------------+---------+
# |       3 | admitclass                     | object  |
# +---------+--------------------------------+---------+
# |       4 | admit_from                     | object  |
# +---------+--------------------------------+---------+
# |       5 | prehospital_living             | object  |
# +---------+--------------------------------+---------+
# |       6 | prehospital_living_with        | object  |
# +---------+--------------------------------+---------+
# |       7 | payor_primary                  | object  |
# +---------+--------------------------------+---------+
# |       8 | payor_secondary                | object  |
# +---------+--------------------------------+---------+
# |       9 | impgroupadmit                  | float64 |
# +---------+--------------------------------+---------+
# |      10 | impgroupdisch                  | float64 |
# +---------+--------------------------------+---------+
# |      11 | diagnosis                      | object  |
# +---------+--------------------------------+---------+
# |      12 | diagnosis_b                    | object  |
# +---------+--------------------------------+---------+
# |      13 | diagnosis_c                    | object  |
# +---------+--------------------------------+---------+
# |      14 | comorbidity0                   | object  |
# +---------+--------------------------------+---------+
# |      15 | comorbidity1                   | object  |
# +---------+--------------------------------+---------+
# |      16 | comorbidity2                   | object  |
# +---------+--------------------------------+---------+
# |      17 | comorbidity3                   | object  |
# +---------+--------------------------------+---------+
# |      18 | comorbidity4                   | object  |
# +---------+--------------------------------+---------+
# |      19 | comorbidity5                   | object  |
# +---------+--------------------------------+---------+
# |      20 | comorbidity6                   | object  |
# +---------+--------------------------------+---------+
# |      21 | comorbidity7                   | object  |
# +---------+--------------------------------+---------+
# |      22 | comorbidity8                   | object  |
# +---------+--------------------------------+---------+
# |      23 | comorbidity9                   | object  |
# +---------+--------------------------------+---------+
# |      24 | comorbidity10                  | object  |
# +---------+--------------------------------+---------+
# |      25 | comorbidity11                  | object  |
# +---------+--------------------------------+---------+
# |      26 | comorbidity12                  | object  |
# +---------+--------------------------------+---------+
# |      27 | comorbidity13                  | object  |
# +---------+--------------------------------+---------+
# |      28 | comorbidity14                  | object  |
# +---------+--------------------------------+---------+
# |      29 | comorbidity15                  | object  |
# +---------+--------------------------------+---------+
# |      30 | comorbidity16                  | object  |
# +---------+--------------------------------+---------+
# |      31 | comorbidity17                  | object  |
# +---------+--------------------------------+---------+
# |      32 | comorbidity18                  | object  |
# +---------+--------------------------------+---------+
# |      33 | comorbidity19                  | object  |
# +---------+--------------------------------+---------+
# |      34 | comorbidity20                  | object  |
# +---------+--------------------------------+---------+
# |      35 | comorbidity21                  | object  |
# +---------+--------------------------------+---------+
# |      36 | comorbidity22                  | object  |
# +---------+--------------------------------+---------+
# |      37 | comorbidity23                  | object  |
# +---------+--------------------------------+---------+
# |      38 | comorbidity24                  | object  |
# +---------+--------------------------------+---------+
# |      39 | arthritis                      | object  |
# +---------+--------------------------------+---------+
# |      40 | heightinches                   | float64 |
# +---------+--------------------------------+---------+
# |      41 | weightpounds                   | float64 |
# +---------+--------------------------------+---------+
# |      42 | dischargeyear                  | float64 |
# +---------+--------------------------------+---------+
# |      43 | discharge_ama                  | object  |
# +---------+--------------------------------+---------+
# |      44 | interruptions                  | object  |
# +---------+--------------------------------+---------+
# |      45 | discharged_alive               | object  |
# +---------+--------------------------------+---------+
# |      46 | discharge_living               | object  |
# +---------+--------------------------------+---------+
# |      47 | discharge_living_with          | object  |
# +---------+--------------------------------+---------+
# |      48 | transferdiagnosis              | object  |
# +---------+--------------------------------+---------+
# |      49 | complication0                  | object  |
# +---------+--------------------------------+---------+
# |      50 | complication1                  | object  |
# +---------+--------------------------------+---------+
# |      51 | complication2                  | object  |
# +---------+--------------------------------+---------+
# |      52 | complication3                  | object  |
# +---------+--------------------------------+---------+
# |      53 | complication4                  | object  |
# +---------+--------------------------------+---------+
# |      54 | complication5                  | object  |
# +---------+--------------------------------+---------+
# |      55 | ptindweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      56 | ptconweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      57 | ptgrpweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      58 | ptcoweek1                      | float64 |
# +---------+--------------------------------+---------+
# |      59 | otindweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      60 | otconweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      61 | otgrpweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      62 | otcoweek1                      | float64 |
# +---------+--------------------------------+---------+
# |      63 | slpindweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      64 | slpconweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      65 | slpgrpweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      66 | slpcoweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      67 | ptindweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      68 | ptconweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      69 | ptgrpweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      70 | ptcoweek2                      | float64 |
# +---------+--------------------------------+---------+
# |      71 | otindweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      72 | otconweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      73 | otgrpweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      74 | otcoweek2                      | float64 |
# +---------+--------------------------------+---------+
# |      75 | slpindweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      76 | slpconweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      77 | slpgrpweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      78 | slpcoweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      79 | hispanic                       | object  |
# +---------+--------------------------------+---------+
# |      80 | hispanic_mexican               | object  |
# +---------+--------------------------------+---------+
# |      81 | hispanic_puertorican           | object  |
# +---------+--------------------------------+---------+
# |      82 | hispanic_cuban                 | object  |
# +---------+--------------------------------+---------+
# |      83 | hispanic_other                 | object  |
# +---------+--------------------------------+---------+
# |      84 | hispanic_unable                | object  |
# +---------+--------------------------------+---------+
# |      85 | hispanic_declined              | object  |
# +---------+--------------------------------+---------+
# |      86 | race_white                     | object  |
# +---------+--------------------------------+---------+
# |      87 | race_black                     | object  |
# +---------+--------------------------------+---------+
# |      88 | race_alaskan                   | object  |
# +---------+--------------------------------+---------+
# |      89 | race_asianindian               | object  |
# +---------+--------------------------------+---------+
# |      90 | race_chinese                   | object  |
# +---------+--------------------------------+---------+
# |      91 | race_filipino                  | object  |
# +---------+--------------------------------+---------+
# |      92 | race_japanese                  | object  |
# +---------+--------------------------------+---------+
# |      93 | race_korean                    | object  |
# +---------+--------------------------------+---------+
# |      94 | race_vietnamese                | object  |
# +---------+--------------------------------+---------+
# |      95 | race_asianother                | object  |
# +---------+--------------------------------+---------+
# |      96 | race_hawaiian                  | object  |
# +---------+--------------------------------+---------+
# |      97 | race_guam                      | object  |
# +---------+--------------------------------+---------+
# |      98 | race_samoan                    | object  |
# +---------+--------------------------------+---------+
# |      99 | race_pacificislander_other     | object  |
# +---------+--------------------------------+---------+
# |     100 | race_unable                    | object  |
# +---------+--------------------------------+---------+
# |     101 | race_declined                  | object  |
# +---------+--------------------------------+---------+
# |     102 | race_noneoftheabove            | object  |
# +---------+--------------------------------+---------+
# |     103 | language                       | object  |
# +---------+--------------------------------+---------+
# |     104 | interpreter                    | object  |
# +---------+--------------------------------+---------+
# |     105 | transport_lack_med             | int64   |
# +---------+--------------------------------+---------+
# |     106 | transport_lack_nonmed          | int64   |
# +---------+--------------------------------+---------+
# |     107 | transport_lack                 | object  |
# +---------+--------------------------------+---------+
# |     108 | transport_lack_unable          | object  |
# +---------+--------------------------------+---------+
# |     109 | transport_lack_declined        | object  |
# +---------+--------------------------------+---------+
# |     110 | hearing_adm                    | Int64   |
# +---------+--------------------------------+---------+
# |     111 | vision_adm                     | Int64   |
# +---------+--------------------------------+---------+
# |     112 | health_lit_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     113 | expression_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     114 | understand_verbal_adm          | Int64   |
# +---------+--------------------------------+---------+
# |     115 | conduct_bims                   | int64   |
# +---------+--------------------------------+---------+
# |     116 | bims_3words                    | Int64   |
# +---------+--------------------------------+---------+
# |     117 | bims_year                      | Int64   |
# +---------+--------------------------------+---------+
# |     118 | bims_month                     | Int64   |
# +---------+--------------------------------+---------+
# |     119 | bims_day                       | Int64   |
# +---------+--------------------------------+---------+
# |     120 | bims_recall_sock               | Int64   |
# +---------+--------------------------------+---------+
# |     121 | bims_recall_blue               | Int64   |
# +---------+--------------------------------+---------+
# |     122 | bims_recall_bed                | Int64   |
# +---------+--------------------------------+---------+
# |     123 | bims_total                     | Int64   |
# +---------+--------------------------------+---------+
# |     124 | conduct_sams                   | int64   |
# +---------+--------------------------------+---------+
# |     125 | sams_season                    | int64   |
# +---------+--------------------------------+---------+
# |     126 | sams_room                      | int64   |
# +---------+--------------------------------+---------+
# |     127 | sams_names                     | int64   |
# +---------+--------------------------------+---------+
# |     128 | sams_hosp                      | int64   |
# +---------+--------------------------------+---------+
# |     129 | sams_none_above                | int64   |
# +---------+--------------------------------+---------+
# |     130 | acute_mental_change            | int64   |
# +---------+--------------------------------+---------+
# |     131 | inattention_adm                | object  |
# +---------+--------------------------------+---------+
# |     132 | disorganized_adm               | object  |
# +---------+--------------------------------+---------+
# |     133 | altered_adm                    | object  |
# +---------+--------------------------------+---------+
# |     134 | low_interest_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     135 | low_interest_freq_adm          | Int64   |
# +---------+--------------------------------+---------+
# |     136 | depressed_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     137 | depressed_freq_adm             | Int64   |
# +---------+--------------------------------+---------+
# |     138 | sleep_trouble_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     139 | sleep_trouble_freq_adm         | Int64   |
# +---------+--------------------------------+---------+
# |     140 | tired_adm                      | Int64   |
# +---------+--------------------------------+---------+
# |     141 | tired_freq_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     142 | appetite_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     143 | appetite_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     144 | feel_bad_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     145 | feel_bad_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     146 | concentrate_adm                | Int64   |
# +---------+--------------------------------+---------+
# |     147 | concentrate_freq_adm           | Int64   |
# +---------+--------------------------------+---------+
# |     148 | slowfast_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     149 | slowfast_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     150 | selfharm_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     151 | selfharm_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     152 | mood_total_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     153 | socisolation_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     154 | selfcare_prior                 | Int64   |
# +---------+--------------------------------+---------+
# |     155 | mobility_prior                 | Int64   |
# +---------+--------------------------------+---------+
# |     156 | stairs_prior                   | Int64   |
# +---------+--------------------------------+---------+
# |     157 | func_cog_prior                 | Int64   |
# +---------+--------------------------------+---------+
# |     158 | wc_manual_prior                | int64   |
# +---------+--------------------------------+---------+
# |     159 | wc_motor_prior                 | int64   |
# +---------+--------------------------------+---------+
# |     160 | mechlift_prior                 | int64   |
# +---------+--------------------------------+---------+
# |     161 | walker_prior                   | int64   |
# +---------+--------------------------------+---------+
# |     162 | orth_pros_prior                | int64   |
# +---------+--------------------------------+---------+
# |     163 | no_device_prior                | int64   |
# +---------+--------------------------------+---------+
# |     164 | eating_adm                     | Int64   |
# +---------+--------------------------------+---------+
# |     165 | eating_goal                    | object  |
# +---------+--------------------------------+---------+
# |     166 | oral_adm                       | Int64   |
# +---------+--------------------------------+---------+
# |     167 | oral_goal                      | object  |
# +---------+--------------------------------+---------+
# |     168 | toileting_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     169 | toileting_goal                 | object  |
# +---------+--------------------------------+---------+
# |     170 | bathe_adm                      | Int64   |
# +---------+--------------------------------+---------+
# |     171 | bathe_goal                     | object  |
# +---------+--------------------------------+---------+
# |     172 | dress_upper_adm                | Int64   |
# +---------+--------------------------------+---------+
# |     173 | dress_upper_goal               | object  |
# +---------+--------------------------------+---------+
# |     174 | dress_lower_adm                | Int64   |
# +---------+--------------------------------+---------+
# |     175 | dress_lower_goal               | object  |
# +---------+--------------------------------+---------+
# |     176 | footwear_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     177 | footwear_goal                  | object  |
# +---------+--------------------------------+---------+
# |     178 | roll_lr_adm                    | Int64   |
# +---------+--------------------------------+---------+
# |     179 | roll_lr_goal                   | object  |
# +---------+--------------------------------+---------+
# |     180 | sit_lying_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     181 | sit_lying_goal                 | object  |
# +---------+--------------------------------+---------+
# |     182 | lying_sit_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     183 | lying_sit_goal                 | object  |
# +---------+--------------------------------+---------+
# |     184 | sit_stand_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     185 | sit_stand_goal                 | object  |
# +---------+--------------------------------+---------+
# |     186 | bed_chair_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     187 | bed_chair_goal                 | object  |
# +---------+--------------------------------+---------+
# |     188 | toilet_trans_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     189 | toilet_trans_goal              | object  |
# +---------+--------------------------------+---------+
# |     190 | car_trans_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     191 | car_trans_goal                 | object  |
# +---------+--------------------------------+---------+
# |     192 | walk10ft_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     193 | walk10ft_goal                  | object  |
# +---------+--------------------------------+---------+
# |     194 | walk50ft_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     195 | walk50ft_goal                  | object  |
# +---------+--------------------------------+---------+
# |     196 | walk150ft_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     197 | walk150ft_goal                 | object  |
# +---------+--------------------------------+---------+
# |     198 | walk10ft_uneven_adm            | Int64   |
# +---------+--------------------------------+---------+
# |     199 | walk10ft_uneven_goal           | object  |
# +---------+--------------------------------+---------+
# |     200 | walk1step_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     201 | walk1step_goal                 | object  |
# +---------+--------------------------------+---------+
# |     202 | walk4step_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     203 | walk4step_goal                 | object  |
# +---------+--------------------------------+---------+
# |     204 | walk12step_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     205 | walk12step_goal                | object  |
# +---------+--------------------------------+---------+
# |     206 | pickup_adm                     | Int64   |
# +---------+--------------------------------+---------+
# |     207 | pickup_goal                    | object  |
# +---------+--------------------------------+---------+
# |     208 | wc_user                        | int64   |
# +---------+--------------------------------+---------+
# |     209 | wheel50ft_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     210 | wheel50ft_goal                 | object  |
# +---------+--------------------------------+---------+
# |     211 | wc50_type                      | object  |
# +---------+--------------------------------+---------+
# |     212 | wheel150ft_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     213 | wheel150ft_goal                | object  |
# +---------+--------------------------------+---------+
# |     214 | wc150_type                     | object  |
# +---------+--------------------------------+---------+
# |     215 | bladder_incontinence           | Int64   |
# +---------+--------------------------------+---------+
# |     216 | bowel_incontinence             | Int64   |
# +---------+--------------------------------+---------+
# |     217 | pvd_comorbid                   | int64   |
# +---------+--------------------------------+---------+
# |     218 | diabetes_comorbid              | int64   |
# +---------+--------------------------------+---------+
# |     219 | no_comorbidities               | object  |
# +---------+--------------------------------+---------+
# |     220 | pain_sleep_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     221 | pain_therapy_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     222 | pain_activities_adm            | Int64   |
# +---------+--------------------------------+---------+
# |     223 | falls_hx                       | object  |
# +---------+--------------------------------+---------+
# |     224 | prior_surgery                  | object  |
# +---------+--------------------------------+---------+
# |     225 | nutrition_parenteral_adm       | int64   |
# +---------+--------------------------------+---------+
# |     226 | nutrition_tube_adm             | int64   |
# +---------+--------------------------------+---------+
# |     227 | nutrition_mech_diet_adm        | int64   |
# +---------+--------------------------------+---------+
# |     228 | nutrition_ther_diet_adm        | int64   |
# +---------+--------------------------------+---------+
# |     229 | nutrition_none_adm             | object  |
# +---------+--------------------------------+---------+
# |     230 | pressure_ulcer_adm             | object  |
# +---------+--------------------------------+---------+
# |     231 | stage1_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     232 | stage2_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     233 | stage3_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     234 | stage4_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     235 | unstageable_dressing_pu_adm    | Int64   |
# +---------+--------------------------------+---------+
# |     236 | unstageable_slough_pu_adm      | Int64   |
# +---------+--------------------------------+---------+
# |     237 | unstageable_deep_pu_adm        | Int64   |
# +---------+--------------------------------+---------+
# |     238 | antipsychotic_taking_adm       | int64   |
# +---------+--------------------------------+---------+
# |     239 | antipsychotic_ind_adm          | int64   |
# +---------+--------------------------------+---------+
# |     240 | anticoagulant_taking_adm       | int64   |
# +---------+--------------------------------+---------+
# |     241 | anticoagulant_ind_adm          | int64   |
# +---------+--------------------------------+---------+
# |     242 | antibiotic_taking_adm          | int64   |
# +---------+--------------------------------+---------+
# |     243 | antibiotic_ind_adm             | int64   |
# +---------+--------------------------------+---------+
# |     244 | opioid_taking_adm              | int64   |
# +---------+--------------------------------+---------+
# |     245 | opioid_ind_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     246 | antiplatelet_taking_adm        | int64   |
# +---------+--------------------------------+---------+
# |     247 | antiplatelet_ind_adm           | int64   |
# +---------+--------------------------------+---------+
# |     248 | hypoglycemic_taking_adm        | int64   |
# +---------+--------------------------------+---------+
# |     249 | hypoglycemic_ind_adm           | int64   |
# +---------+--------------------------------+---------+
# |     250 | med_highrisk_none              | object  |
# +---------+--------------------------------+---------+
# |     251 | drug_regimen_review            | object  |
# +---------+--------------------------------+---------+
# |     252 | med_follow_up                  | Int64   |
# +---------+--------------------------------+---------+
# |     253 | chemo_adm                      | int64   |
# +---------+--------------------------------+---------+
# |     254 | chemo_iv_adm                   | int64   |
# +---------+--------------------------------+---------+
# |     255 | chemo_oral_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     256 | chemo_other_adm                | int64   |
# +---------+--------------------------------+---------+
# |     257 | radiation_adm                  | int64   |
# +---------+--------------------------------+---------+
# |     258 | oxygen_adm                     | int64   |
# +---------+--------------------------------+---------+
# |     259 | oxygen_cont_adm                | int64   |
# +---------+--------------------------------+---------+
# |     260 | oxygen_int_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     261 | oxygen_high_adm                | int64   |
# +---------+--------------------------------+---------+
# |     262 | suctioning_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     263 | suctioning_sched_adm           | int64   |
# +---------+--------------------------------+---------+
# |     264 | suctioning_asneeded_adm        | int64   |
# +---------+--------------------------------+---------+
# |     265 | trach_adm                      | int64   |
# +---------+--------------------------------+---------+
# |     266 | vent_invasive_adm              | int64   |
# +---------+--------------------------------+---------+
# |     267 | vent_noninvasive_adm           | int64   |
# +---------+--------------------------------+---------+
# |     268 | vent_bipap_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     269 | vent_cpap_adm                  | int64   |
# +---------+--------------------------------+---------+
# |     270 | meds_iv_adm                    | int64   |
# +---------+--------------------------------+---------+
# |     271 | meds_iv_vasoactive_adm         | int64   |
# +---------+--------------------------------+---------+
# |     272 | meds_iv_antibiotic_adm         | int64   |
# +---------+--------------------------------+---------+
# |     273 | meds_iv_anticoagulant_adm      | int64   |
# +---------+--------------------------------+---------+
# |     274 | meds_iv_other_adm              | int64   |
# +---------+--------------------------------+---------+
# |     275 | transfusions_adm               | int64   |
# +---------+--------------------------------+---------+
# |     276 | dialysis_adm                   | int64   |
# +---------+--------------------------------+---------+
# |     277 | hemodialysis_adm               | int64   |
# +---------+--------------------------------+---------+
# |     278 | peritoneal_dialysis_adm        | int64   |
# +---------+--------------------------------+---------+
# |     279 | iv_access_adm                  | int64   |
# +---------+--------------------------------+---------+
# |     280 | iv_access_periph_adm           | int64   |
# +---------+--------------------------------+---------+
# |     281 | iv_access_mid_adm              | int64   |
# +---------+--------------------------------+---------+
# |     282 | iv_access_cent_adm             | int64   |
# +---------+--------------------------------+---------+
# |     283 | tx_none_adm                    | object  |
# +---------+--------------------------------+---------+
# |     284 | transport_lack_med_dc          | object  |
# +---------+--------------------------------+---------+
# |     285 | transport_lack_nonmed_dc       | object  |
# +---------+--------------------------------+---------+
# |     286 | transport_lack_dc              | object  |
# +---------+--------------------------------+---------+
# |     287 | transport_lack_unable_dc       | object  |
# +---------+--------------------------------+---------+
# |     288 | transport_lack_declined_dc     | object  |
# +---------+--------------------------------+---------+
# |     289 | med_list_to_provider           | object  |
# +---------+--------------------------------+---------+
# |     290 | med_list_transmit_ehr          | object  |
# +---------+--------------------------------+---------+
# |     291 | med_list_transmit_hie          | object  |
# +---------+--------------------------------+---------+
# |     292 | med_list_transmit_verbal       | object  |
# +---------+--------------------------------+---------+
# |     293 | med_list_transmit_paper        | object  |
# +---------+--------------------------------+---------+
# |     294 | med_list_transmit_other        | object  |
# +---------+--------------------------------+---------+
# |     295 | med_list_to_patient            | object  |
# +---------+--------------------------------+---------+
# |     296 | med_list_pt_ehr                | object  |
# +---------+--------------------------------+---------+
# |     297 | med_list_pt_hie                | object  |
# +---------+--------------------------------+---------+
# |     298 | med_list_pt_verbal             | object  |
# +---------+--------------------------------+---------+
# |     299 | med_list_pt_paper              | object  |
# +---------+--------------------------------+---------+
# |     300 | med_list_pt_other              | object  |
# +---------+--------------------------------+---------+
# |     301 | health_lit_dc                  | object  |
# +---------+--------------------------------+---------+
# |     302 | conduct_bims_dc                | object  |
# +---------+--------------------------------+---------+
# |     303 | bims_3words_dc                 | object  |
# +---------+--------------------------------+---------+
# |     304 | bims_year_dc                   | object  |
# +---------+--------------------------------+---------+
# |     305 | bims_month_dc                  | object  |
# +---------+--------------------------------+---------+
# |     306 | bims_day_dc                    | object  |
# +---------+--------------------------------+---------+
# |     307 | bims_recall_sock_dc            | object  |
# +---------+--------------------------------+---------+
# |     308 | bims_recall_blue_dc            | object  |
# +---------+--------------------------------+---------+
# |     309 | bims_recall_bed_dc             | object  |
# +---------+--------------------------------+---------+
# |     310 | bims_total_dc                  | object  |
# +---------+--------------------------------+---------+
# |     311 | acute_mental_change_dc         | object  |
# +---------+--------------------------------+---------+
# |     312 | inattention_dc                 | object  |
# +---------+--------------------------------+---------+
# |     313 | disorganized_dc                | object  |
# +---------+--------------------------------+---------+
# |     314 | altered_dc                     | object  |
# +---------+--------------------------------+---------+
# |     315 | low_interest_dc                | object  |
# +---------+--------------------------------+---------+
# |     316 | low_interest_freq_dc           | object  |
# +---------+--------------------------------+---------+
# |     317 | depressed_dc                   | object  |
# +---------+--------------------------------+---------+
# |     318 | depressed_freq_dc              | object  |
# +---------+--------------------------------+---------+
# |     319 | sleep_trouble_dc               | object  |
# +---------+--------------------------------+---------+
# |     320 | sleep_trouble_freq_dc          | object  |
# +---------+--------------------------------+---------+
# |     321 | tired_dc                       | object  |
# +---------+--------------------------------+---------+
# |     322 | tired_freq_dc                  | object  |
# +---------+--------------------------------+---------+
# |     323 | appetite_dc                    | object  |
# +---------+--------------------------------+---------+
# |     324 | appetite_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     325 | feel_bad_dc                    | object  |
# +---------+--------------------------------+---------+
# |     326 | feel_bad_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     327 | concentrate_dc                 | object  |
# +---------+--------------------------------+---------+
# |     328 | concentrate_freq_dc            | object  |
# +---------+--------------------------------+---------+
# |     329 | slowfast_dc                    | object  |
# +---------+--------------------------------+---------+
# |     330 | slowfast_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     331 | selfharm_dc                    | object  |
# +---------+--------------------------------+---------+
# |     332 | selfharm_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     333 | mood_total_dc                  | object  |
# +---------+--------------------------------+---------+
# |     334 | socisolation_dc                | object  |
# +---------+--------------------------------+---------+
# |     335 | eating_dc                      | object  |
# +---------+--------------------------------+---------+
# |     336 | oral_dc                        | object  |
# +---------+--------------------------------+---------+
# |     337 | toileting_dc                   | object  |
# +---------+--------------------------------+---------+
# |     338 | bathe_dc                       | object  |
# +---------+--------------------------------+---------+
# |     339 | dress_upper_dc                 | object  |
# +---------+--------------------------------+---------+
# |     340 | dress_lower_dc                 | object  |
# +---------+--------------------------------+---------+
# |     341 | footwear_dc                    | object  |
# +---------+--------------------------------+---------+
# |     342 | roll_lr_dc                     | object  |
# +---------+--------------------------------+---------+
# |     343 | sit_lying_dc                   | object  |
# +---------+--------------------------------+---------+
# |     344 | lying_sit_dc                   | object  |
# +---------+--------------------------------+---------+
# |     345 | sit_stand_dc                   | object  |
# +---------+--------------------------------+---------+
# |     346 | bed_chair_dc                   | object  |
# +---------+--------------------------------+---------+
# |     347 | toilet_trans_dc                | object  |
# +---------+--------------------------------+---------+
# |     348 | car_trans_dc                   | object  |
# +---------+--------------------------------+---------+
# |     349 | walk10ft_dc                    | object  |
# +---------+--------------------------------+---------+
# |     350 | walk50ft_dc                    | object  |
# +---------+--------------------------------+---------+
# |     351 | walk150ft_dc                   | object  |
# +---------+--------------------------------+---------+
# |     352 | walk10ft_uneven_dc             | object  |
# +---------+--------------------------------+---------+
# |     353 | walk1step_dc                   | object  |
# +---------+--------------------------------+---------+
# |     354 | walk4step_dc                   | object  |
# +---------+--------------------------------+---------+
# |     355 | walk12step_dc                  | object  |
# +---------+--------------------------------+---------+
# |     356 | pickup_dc                      | object  |
# +---------+--------------------------------+---------+
# |     357 | wc_user_dc                     | object  |
# +---------+--------------------------------+---------+
# |     358 | wheel50ft_dc                   | object  |
# +---------+--------------------------------+---------+
# |     359 | wc50_type_dc                   | object  |
# +---------+--------------------------------+---------+
# |     360 | wheel150ft_dc                  | object  |
# +---------+--------------------------------+---------+
# |     361 | wc150_type_dc                  | object  |
# +---------+--------------------------------+---------+
# |     362 | pain_sleep_dc                  | object  |
# +---------+--------------------------------+---------+
# |     363 | pain_therapy_dc                | object  |
# +---------+--------------------------------+---------+
# |     364 | pain_activities_dc             | object  |
# +---------+--------------------------------+---------+
# |     365 | falls_since_adm                | object  |
# +---------+--------------------------------+---------+
# |     366 | falls_no_injury                | object  |
# +---------+--------------------------------+---------+
# |     367 | falls_minor_injury             | object  |
# +---------+--------------------------------+---------+
# |     368 | falls_major_injury             | object  |
# +---------+--------------------------------+---------+
# |     369 | nutrition_parenteral_last7days | object  |
# +---------+--------------------------------+---------+
# |     370 | nutrition_parenteral_dc        | object  |
# +---------+--------------------------------+---------+
# |     371 | nutrition_tube_last7days       | object  |
# +---------+--------------------------------+---------+
# |     372 | nutrition_tube_dc              | object  |
# +---------+--------------------------------+---------+
# |     373 | nutrition_mech_diet_last7days  | object  |
# +---------+--------------------------------+---------+
# |     374 | nutrition_mech_diet_dc         | object  |
# +---------+--------------------------------+---------+
# |     375 | nutrition_ther_diet_last7days  | object  |
# +---------+--------------------------------+---------+
# |     376 | nutrition_ther_diet_dc         | object  |
# +---------+--------------------------------+---------+
# |     377 | nutrition_none_last7days       | object  |
# +---------+--------------------------------+---------+
# |     378 | nutrition_none_dc              | object  |
# +---------+--------------------------------+---------+
# |     379 | pressure_ulcer_dc              | object  |
# +---------+--------------------------------+---------+
# |     380 | stage1_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     381 | stage2_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     382 | stage2_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     383 | stage3_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     384 | stage3_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     385 | stage4_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     386 | stage4_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     387 | unstageable_dressing_pu_dc     | float64 |
# +---------+--------------------------------+---------+
# |     388 | unstageable_dressing_pu_remain | float64 |
# +---------+--------------------------------+---------+
# |     389 | unstageable_slough_pu_dc       | float64 |
# +---------+--------------------------------+---------+
# |     390 | unstageable_slough_pu_remain   | float64 |
# +---------+--------------------------------+---------+
# |     391 | unstageable_deep_pu_dc         | float64 |
# +---------+--------------------------------+---------+
# |     392 | unstageable_deep_pu_remain     | float64 |
# +---------+--------------------------------+---------+
# |     393 | antipsychotic_taking_dc        | object  |
# +---------+--------------------------------+---------+
# |     394 | antipsychotic_ind_dc           | object  |
# +---------+--------------------------------+---------+
# |     395 | anticoagulant_taking_dc        | object  |
# +---------+--------------------------------+---------+
# |     396 | anticoagulant_ind_dc           | object  |
# +---------+--------------------------------+---------+
# |     397 | antibiotic_taking_dc           | object  |
# +---------+--------------------------------+---------+
# |     398 | antibiotic_ind_dc              | object  |
# +---------+--------------------------------+---------+
# |     399 | opioid_taking_dc               | object  |
# +---------+--------------------------------+---------+
# |     400 | opioid_ind_dc                  | object  |
# +---------+--------------------------------+---------+
# |     401 | antiplatelet_taking_dc         | object  |
# +---------+--------------------------------+---------+
# |     402 | antiplatelet_ind_dc            | object  |
# +---------+--------------------------------+---------+
# |     403 | hypoglycemic_taking_dc         | object  |
# +---------+--------------------------------+---------+
# |     404 | hypoglycemic_ind_dc            | object  |
# +---------+--------------------------------+---------+
# |     405 | med_highrisk_none_dc           | object  |
# +---------+--------------------------------+---------+
# |     406 | med_intervention               | object  |
# +---------+--------------------------------+---------+
# |     407 | chemo_dc                       | object  |
# +---------+--------------------------------+---------+
# |     408 | chemo_iv_dc                    | object  |
# +---------+--------------------------------+---------+
# |     409 | chemo_oral_dc                  | object  |
# +---------+--------------------------------+---------+
# |     410 | chemo_other_dc                 | object  |
# +---------+--------------------------------+---------+
# |     411 | radiation_dc                   | object  |
# +---------+--------------------------------+---------+
# |     412 | oxygen_dc                      | object  |
# +---------+--------------------------------+---------+
# |     413 | oxygen_cont_dc                 | object  |
# +---------+--------------------------------+---------+
# |     414 | oxygen_int_dc                  | object  |
# +---------+--------------------------------+---------+
# |     415 | oxygen_high_dc                 | object  |
# +---------+--------------------------------+---------+
# |     416 | suctioning_dc                  | object  |
# +---------+--------------------------------+---------+
# |     417 | suctioning_sched_dc            | object  |
# +---------+--------------------------------+---------+
# |     418 | suctioning_asneeded_dc         | object  |
# +---------+--------------------------------+---------+
# |     419 | trach_dc                       | object  |
# +---------+--------------------------------+---------+
# |     420 | vent_invasive_dc               | object  |
# +---------+--------------------------------+---------+
# |     421 | vent_noninvasive_dc            | object  |
# +---------+--------------------------------+---------+
# |     422 | vent_bipap_dc                  | object  |
# +---------+--------------------------------+---------+
# |     423 | vent_cpap_dc                   | object  |
# +---------+--------------------------------+---------+
# |     424 | meds_iv_dc                     | object  |
# +---------+--------------------------------+---------+
# |     425 | meds_iv_vasoactive_dc          | object  |
# +---------+--------------------------------+---------+
# |     426 | meds_iv_antibiotic_dc          | object  |
# +---------+--------------------------------+---------+
# |     427 | meds_iv_anticoagulant_dc       | object  |
# +---------+--------------------------------+---------+
# |     428 | meds_iv_other_dc               | object  |
# +---------+--------------------------------+---------+
# |     429 | transfusions_dc                | object  |
# +---------+--------------------------------+---------+
# |     430 | dialysis_dc                    | object  |
# +---------+--------------------------------+---------+
# |     431 | hemodialysis_dc                | object  |
# +---------+--------------------------------+---------+
# |     432 | peritoneal_dialysis_dc         | object  |
# +---------+--------------------------------+---------+
# |     433 | iv_access_dc                   | object  |
# +---------+--------------------------------+---------+
# |     434 | iv_access_periph_dc            | object  |
# +---------+--------------------------------+---------+
# |     435 | iv_access_mid_dc               | object  |
# +---------+--------------------------------+---------+
# |     436 | iv_access_cent_dc              | object  |
# +---------+--------------------------------+---------+
# |     437 | tx_none_dc                     | object  |
# +---------+--------------------------------+---------+
# |     438 | age_at_admit                   | float64 |
# +---------+--------------------------------+---------+
# |     439 | los                            | float64 |
# +---------+--------------------------------+---------+
# |     440 | ric                            | float64 |
# +---------+--------------------------------+---------+
# |     441 | cmg                            | float64 |
# +---------+--------------------------------+---------+
# |     442 | tier                           | object  |
# +---------+--------------------------------+---------+
# |     443 | shortstayexpired               | object  |
# +---------+--------------------------------+---------+
# |     444 | shortstaycmg                   | float64 |
# +---------+--------------------------------+---------+
# |     445 | transferpatient                | object  |
# +---------+--------------------------------+---------+
# |     446 | incompletestay                 | object  |
# +---------+--------------------------------+---------+
# |     447 | unplanned_discharge            | float64 |
# +---------+--------------------------------+---------+
# |     448 | selfcare_measure_adm           | float64 |
# +---------+--------------------------------+---------+
# |     449 | selfcare_measure_dc            | float64 |
# +---------+--------------------------------+---------+
# |     450 | mobility_measure_adm           | float64 |
# +---------+--------------------------------+---------+
# |     451 | mobility_measure_dc            | float64 |
# +---------+--------------------------------+---------+
# |     452 | selfcare_measure_delta         | float64 |
# +---------+--------------------------------+---------+
# |     453 | mobility_measure_delta         | float64 |
# +---------+--------------------------------+---------+
# |     454 | race                           | object  |
# +---------+--------------------------------+---------+

# %%
# save processed data with 6 extra columns

df.to_csv('./data/Cleaned files/Cogan_1_3.csv', index=True)

# %%
# save feature table & dtype dictionary
import pickle
import json

feature_table = {
    "categorical": list(categorical_feature_set),
    "numeric": list(numeric_feature_set),
    "ranked_int": list(ranked_int_feature_set),
    "binary": list(binary_feature_set),
}

with open("./data/Cleaned files/feature_table.pkl", 'wb') as f:
    pickle.dump(feature_table, f)

dtype_dict = {name: str(df[name].dtype) for name in df.columns}

with open('./data/Cleaned files/processed_feature_dtypes.json', 'w') as f:
    json.dump(dtype_dict, f)

# %% [markdown]
# ## 2 Selection, Imputation & One-Hot Expansion

# %% [markdown]
# ### 2.1 Feature Selection

# %%
# total # of features and a list of all feature names

import pandas as pd
import pickle
import numpy as np
from tabulate import tabulate
import json

def convert_dtypes(df, dtype_dict):
    for name in df.columns:
        dtype = dtype_dict[name]
        df[name] = df[name].astype(dtype)

# always start from loading the CSV file from previous section
df = pd.read_csv('./data/Cleaned files/Cogan_1_3.csv', low_memory=False, index_col='id')
with open("./data/Cleaned files/lookup_table.pkl", 'rb') as f:
    lookup_table = pickle.load(f)
with open("./data/Cleaned files/feature_table.pkl", 'rb') as f:
    feature_table = pickle.load(f)

# convert dtypes
with open('./data/Cleaned files/processed_feature_dtypes.json', 'r') as f:
    dtype_dict = json.load(f)
convert_dtypes(df, dtype_dict)

feature_names = [*df.head()]
feature_dtypes = df.dtypes
print("total # of features:", len(feature_names))

print(tabulate([(index, name, feature_dtypes[name]) for index, name in enumerate(feature_names)], headers=["Index", "Name", "Dtype"], tablefmt="grid"))
categorical_feature_set = feature_table["categorical"]
numeric_feature_set = feature_table["numeric"]
ranked_int_feature_set = feature_table["ranked_int"]
binary_feature_set = feature_table["binary"]
# Out:
# total # of features: 455
# +---------+--------------------------------+---------+
# |   Index | Name                           | Dtype   |
# +=========+================================+=========+
# |       0 | sex                            | object  |
# +---------+--------------------------------+---------+
# |       1 | marital_status                 | object  |
# +---------+--------------------------------+---------+
# |       2 | admityear                      | int64   |
# +---------+--------------------------------+---------+
# |       3 | admitclass                     | object  |
# +---------+--------------------------------+---------+
# |       4 | admit_from                     | object  |
# +---------+--------------------------------+---------+
# |       5 | prehospital_living             | object  |
# +---------+--------------------------------+---------+
# |       6 | prehospital_living_with        | object  |
# +---------+--------------------------------+---------+
# |       7 | payor_primary                  | object  |
# +---------+--------------------------------+---------+
# |       8 | payor_secondary                | object  |
# +---------+--------------------------------+---------+
# |       9 | impgroupadmit                  | float64 |
# +---------+--------------------------------+---------+
# |      10 | impgroupdisch                  | float64 |
# +---------+--------------------------------+---------+
# |      11 | diagnosis                      | object  |
# +---------+--------------------------------+---------+
# |      12 | diagnosis_b                    | object  |
# +---------+--------------------------------+---------+
# |      13 | diagnosis_c                    | object  |
# +---------+--------------------------------+---------+
# |      14 | comorbidity0                   | object  |
# +---------+--------------------------------+---------+
# |      15 | comorbidity1                   | object  |
# +---------+--------------------------------+---------+
# |      16 | comorbidity2                   | object  |
# +---------+--------------------------------+---------+
# |      17 | comorbidity3                   | object  |
# +---------+--------------------------------+---------+
# |      18 | comorbidity4                   | object  |
# +---------+--------------------------------+---------+
# |      19 | comorbidity5                   | object  |
# +---------+--------------------------------+---------+
# |      20 | comorbidity6                   | object  |
# +---------+--------------------------------+---------+
# |      21 | comorbidity7                   | object  |
# +---------+--------------------------------+---------+
# |      22 | comorbidity8                   | object  |
# +---------+--------------------------------+---------+
# |      23 | comorbidity9                   | object  |
# +---------+--------------------------------+---------+
# |      24 | comorbidity10                  | object  |
# +---------+--------------------------------+---------+
# |      25 | comorbidity11                  | object  |
# +---------+--------------------------------+---------+
# |      26 | comorbidity12                  | object  |
# +---------+--------------------------------+---------+
# |      27 | comorbidity13                  | object  |
# +---------+--------------------------------+---------+
# |      28 | comorbidity14                  | object  |
# +---------+--------------------------------+---------+
# |      29 | comorbidity15                  | object  |
# +---------+--------------------------------+---------+
# |      30 | comorbidity16                  | object  |
# +---------+--------------------------------+---------+
# |      31 | comorbidity17                  | object  |
# +---------+--------------------------------+---------+
# |      32 | comorbidity18                  | object  |
# +---------+--------------------------------+---------+
# |      33 | comorbidity19                  | object  |
# +---------+--------------------------------+---------+
# |      34 | comorbidity20                  | object  |
# +---------+--------------------------------+---------+
# |      35 | comorbidity21                  | object  |
# +---------+--------------------------------+---------+
# |      36 | comorbidity22                  | object  |
# +---------+--------------------------------+---------+
# |      37 | comorbidity23                  | object  |
# +---------+--------------------------------+---------+
# |      38 | comorbidity24                  | object  |
# +---------+--------------------------------+---------+
# |      39 | arthritis                      | object  |
# +---------+--------------------------------+---------+
# |      40 | heightinches                   | float64 |
# +---------+--------------------------------+---------+
# |      41 | weightpounds                   | float64 |
# +---------+--------------------------------+---------+
# |      42 | dischargeyear                  | float64 |
# +---------+--------------------------------+---------+
# |      43 | discharge_ama                  | object  |
# +---------+--------------------------------+---------+
# |      44 | interruptions                  | object  |
# +---------+--------------------------------+---------+
# |      45 | discharged_alive               | object  |
# +---------+--------------------------------+---------+
# |      46 | discharge_living               | object  |
# +---------+--------------------------------+---------+
# |      47 | discharge_living_with          | object  |
# +---------+--------------------------------+---------+
# |      48 | transferdiagnosis              | object  |
# +---------+--------------------------------+---------+
# |      49 | complication0                  | object  |
# +---------+--------------------------------+---------+
# |      50 | complication1                  | object  |
# +---------+--------------------------------+---------+
# |      51 | complication2                  | object  |
# +---------+--------------------------------+---------+
# |      52 | complication3                  | object  |
# +---------+--------------------------------+---------+
# |      53 | complication4                  | object  |
# +---------+--------------------------------+---------+
# |      54 | complication5                  | object  |
# +---------+--------------------------------+---------+
# |      55 | ptindweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      56 | ptconweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      57 | ptgrpweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      58 | ptcoweek1                      | float64 |
# +---------+--------------------------------+---------+
# |      59 | otindweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      60 | otconweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      61 | otgrpweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      62 | otcoweek1                      | float64 |
# +---------+--------------------------------+---------+
# |      63 | slpindweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      64 | slpconweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      65 | slpgrpweek1                    | float64 |
# +---------+--------------------------------+---------+
# |      66 | slpcoweek1                     | float64 |
# +---------+--------------------------------+---------+
# |      67 | ptindweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      68 | ptconweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      69 | ptgrpweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      70 | ptcoweek2                      | float64 |
# +---------+--------------------------------+---------+
# |      71 | otindweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      72 | otconweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      73 | otgrpweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      74 | otcoweek2                      | float64 |
# +---------+--------------------------------+---------+
# |      75 | slpindweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      76 | slpconweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      77 | slpgrpweek2                    | float64 |
# +---------+--------------------------------+---------+
# |      78 | slpcoweek2                     | float64 |
# +---------+--------------------------------+---------+
# |      79 | hispanic                       | object  |
# +---------+--------------------------------+---------+
# |      80 | hispanic_mexican               | object  |
# +---------+--------------------------------+---------+
# |      81 | hispanic_puertorican           | object  |
# +---------+--------------------------------+---------+
# |      82 | hispanic_cuban                 | object  |
# +---------+--------------------------------+---------+
# |      83 | hispanic_other                 | object  |
# +---------+--------------------------------+---------+
# |      84 | hispanic_unable                | object  |
# +---------+--------------------------------+---------+
# |      85 | hispanic_declined              | object  |
# +---------+--------------------------------+---------+
# |      86 | race_white                     | object  |
# +---------+--------------------------------+---------+
# |      87 | race_black                     | object  |
# +---------+--------------------------------+---------+
# |      88 | race_alaskan                   | object  |
# +---------+--------------------------------+---------+
# |      89 | race_asianindian               | object  |
# +---------+--------------------------------+---------+
# |      90 | race_chinese                   | object  |
# +---------+--------------------------------+---------+
# |      91 | race_filipino                  | object  |
# +---------+--------------------------------+---------+
# |      92 | race_japanese                  | object  |
# +---------+--------------------------------+---------+
# |      93 | race_korean                    | object  |
# +---------+--------------------------------+---------+
# |      94 | race_vietnamese                | object  |
# +---------+--------------------------------+---------+
# |      95 | race_asianother                | object  |
# +---------+--------------------------------+---------+
# |      96 | race_hawaiian                  | object  |
# +---------+--------------------------------+---------+
# |      97 | race_guam                      | object  |
# +---------+--------------------------------+---------+
# |      98 | race_samoan                    | object  |
# +---------+--------------------------------+---------+
# |      99 | race_pacificislander_other     | object  |
# +---------+--------------------------------+---------+
# |     100 | race_unable                    | object  |
# +---------+--------------------------------+---------+
# |     101 | race_declined                  | object  |
# +---------+--------------------------------+---------+
# |     102 | race_noneoftheabove            | object  |
# +---------+--------------------------------+---------+
# |     103 | language                       | object  |
# +---------+--------------------------------+---------+
# |     104 | interpreter                    | object  |
# +---------+--------------------------------+---------+
# |     105 | transport_lack_med             | int64   |
# +---------+--------------------------------+---------+
# |     106 | transport_lack_nonmed          | int64   |
# +---------+--------------------------------+---------+
# |     107 | transport_lack                 | object  |
# +---------+--------------------------------+---------+
# |     108 | transport_lack_unable          | object  |
# +---------+--------------------------------+---------+
# |     109 | transport_lack_declined        | object  |
# +---------+--------------------------------+---------+
# |     110 | hearing_adm                    | Int64   |
# +---------+--------------------------------+---------+
# |     111 | vision_adm                     | Int64   |
# +---------+--------------------------------+---------+
# |     112 | health_lit_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     113 | expression_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     114 | understand_verbal_adm          | Int64   |
# +---------+--------------------------------+---------+
# |     115 | conduct_bims                   | int64   |
# +---------+--------------------------------+---------+
# |     116 | bims_3words                    | Int64   |
# +---------+--------------------------------+---------+
# |     117 | bims_year                      | Int64   |
# +---------+--------------------------------+---------+
# |     118 | bims_month                     | Int64   |
# +---------+--------------------------------+---------+
# |     119 | bims_day                       | Int64   |
# +---------+--------------------------------+---------+
# |     120 | bims_recall_sock               | Int64   |
# +---------+--------------------------------+---------+
# |     121 | bims_recall_blue               | Int64   |
# +---------+--------------------------------+---------+
# |     122 | bims_recall_bed                | Int64   |
# +---------+--------------------------------+---------+
# |     123 | bims_total                     | Int64   |
# +---------+--------------------------------+---------+
# |     124 | conduct_sams                   | int64   |
# +---------+--------------------------------+---------+
# |     125 | sams_season                    | int64   |
# +---------+--------------------------------+---------+
# |     126 | sams_room                      | int64   |
# +---------+--------------------------------+---------+
# |     127 | sams_names                     | int64   |
# +---------+--------------------------------+---------+
# |     128 | sams_hosp                      | int64   |
# +---------+--------------------------------+---------+
# |     129 | sams_none_above                | int64   |
# +---------+--------------------------------+---------+
# |     130 | acute_mental_change            | int64   |
# +---------+--------------------------------+---------+
# |     131 | inattention_adm                | object  |
# +---------+--------------------------------+---------+
# |     132 | disorganized_adm               | object  |
# +---------+--------------------------------+---------+
# |     133 | altered_adm                    | object  |
# +---------+--------------------------------+---------+
# |     134 | low_interest_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     135 | low_interest_freq_adm          | Int64   |
# +---------+--------------------------------+---------+
# |     136 | depressed_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     137 | depressed_freq_adm             | Int64   |
# +---------+--------------------------------+---------+
# |     138 | sleep_trouble_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     139 | sleep_trouble_freq_adm         | Int64   |
# +---------+--------------------------------+---------+
# |     140 | tired_adm                      | Int64   |
# +---------+--------------------------------+---------+
# |     141 | tired_freq_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     142 | appetite_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     143 | appetite_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     144 | feel_bad_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     145 | feel_bad_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     146 | concentrate_adm                | Int64   |
# +---------+--------------------------------+---------+
# |     147 | concentrate_freq_adm           | Int64   |
# +---------+--------------------------------+---------+
# |     148 | slowfast_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     149 | slowfast_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     150 | selfharm_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     151 | selfharm_freq_adm              | Int64   |
# +---------+--------------------------------+---------+
# |     152 | mood_total_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     153 | socisolation_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     154 | selfcare_prior                 | Int64   |
# +---------+--------------------------------+---------+
# |     155 | mobility_prior                 | Int64   |
# +---------+--------------------------------+---------+
# |     156 | stairs_prior                   | Int64   |
# +---------+--------------------------------+---------+
# |     157 | func_cog_prior                 | Int64   |
# +---------+--------------------------------+---------+
# |     158 | wc_manual_prior                | int64   |
# +---------+--------------------------------+---------+
# |     159 | wc_motor_prior                 | int64   |
# +---------+--------------------------------+---------+
# |     160 | mechlift_prior                 | int64   |
# +---------+--------------------------------+---------+
# |     161 | walker_prior                   | int64   |
# +---------+--------------------------------+---------+
# |     162 | orth_pros_prior                | int64   |
# +---------+--------------------------------+---------+
# |     163 | no_device_prior                | int64   |
# +---------+--------------------------------+---------+
# |     164 | eating_adm                     | Int64   |
# +---------+--------------------------------+---------+
# |     165 | eating_goal                    | object  |
# +---------+--------------------------------+---------+
# |     166 | oral_adm                       | Int64   |
# +---------+--------------------------------+---------+
# |     167 | oral_goal                      | object  |
# +---------+--------------------------------+---------+
# |     168 | toileting_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     169 | toileting_goal                 | object  |
# +---------+--------------------------------+---------+
# |     170 | bathe_adm                      | Int64   |
# +---------+--------------------------------+---------+
# |     171 | bathe_goal                     | object  |
# +---------+--------------------------------+---------+
# |     172 | dress_upper_adm                | Int64   |
# +---------+--------------------------------+---------+
# |     173 | dress_upper_goal               | object  |
# +---------+--------------------------------+---------+
# |     174 | dress_lower_adm                | Int64   |
# +---------+--------------------------------+---------+
# |     175 | dress_lower_goal               | object  |
# +---------+--------------------------------+---------+
# |     176 | footwear_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     177 | footwear_goal                  | object  |
# +---------+--------------------------------+---------+
# |     178 | roll_lr_adm                    | Int64   |
# +---------+--------------------------------+---------+
# |     179 | roll_lr_goal                   | object  |
# +---------+--------------------------------+---------+
# |     180 | sit_lying_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     181 | sit_lying_goal                 | object  |
# +---------+--------------------------------+---------+
# |     182 | lying_sit_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     183 | lying_sit_goal                 | object  |
# +---------+--------------------------------+---------+
# |     184 | sit_stand_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     185 | sit_stand_goal                 | object  |
# +---------+--------------------------------+---------+
# |     186 | bed_chair_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     187 | bed_chair_goal                 | object  |
# +---------+--------------------------------+---------+
# |     188 | toilet_trans_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     189 | toilet_trans_goal              | object  |
# +---------+--------------------------------+---------+
# |     190 | car_trans_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     191 | car_trans_goal                 | object  |
# +---------+--------------------------------+---------+
# |     192 | walk10ft_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     193 | walk10ft_goal                  | object  |
# +---------+--------------------------------+---------+
# |     194 | walk50ft_adm                   | Int64   |
# +---------+--------------------------------+---------+
# |     195 | walk50ft_goal                  | object  |
# +---------+--------------------------------+---------+
# |     196 | walk150ft_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     197 | walk150ft_goal                 | object  |
# +---------+--------------------------------+---------+
# |     198 | walk10ft_uneven_adm            | Int64   |
# +---------+--------------------------------+---------+
# |     199 | walk10ft_uneven_goal           | object  |
# +---------+--------------------------------+---------+
# |     200 | walk1step_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     201 | walk1step_goal                 | object  |
# +---------+--------------------------------+---------+
# |     202 | walk4step_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     203 | walk4step_goal                 | object  |
# +---------+--------------------------------+---------+
# |     204 | walk12step_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     205 | walk12step_goal                | object  |
# +---------+--------------------------------+---------+
# |     206 | pickup_adm                     | Int64   |
# +---------+--------------------------------+---------+
# |     207 | pickup_goal                    | object  |
# +---------+--------------------------------+---------+
# |     208 | wc_user                        | int64   |
# +---------+--------------------------------+---------+
# |     209 | wheel50ft_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     210 | wheel50ft_goal                 | object  |
# +---------+--------------------------------+---------+
# |     211 | wc50_type                      | object  |
# +---------+--------------------------------+---------+
# |     212 | wheel150ft_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     213 | wheel150ft_goal                | object  |
# +---------+--------------------------------+---------+
# |     214 | wc150_type                     | object  |
# +---------+--------------------------------+---------+
# |     215 | bladder_incontinence           | Int64   |
# +---------+--------------------------------+---------+
# |     216 | bowel_incontinence             | Int64   |
# +---------+--------------------------------+---------+
# |     217 | pvd_comorbid                   | int64   |
# +---------+--------------------------------+---------+
# |     218 | diabetes_comorbid              | int64   |
# +---------+--------------------------------+---------+
# |     219 | no_comorbidities               | object  |
# +---------+--------------------------------+---------+
# |     220 | pain_sleep_adm                 | Int64   |
# +---------+--------------------------------+---------+
# |     221 | pain_therapy_adm               | Int64   |
# +---------+--------------------------------+---------+
# |     222 | pain_activities_adm            | Int64   |
# +---------+--------------------------------+---------+
# |     223 | falls_hx                       | object  |
# +---------+--------------------------------+---------+
# |     224 | prior_surgery                  | object  |
# +---------+--------------------------------+---------+
# |     225 | nutrition_parenteral_adm       | int64   |
# +---------+--------------------------------+---------+
# |     226 | nutrition_tube_adm             | int64   |
# +---------+--------------------------------+---------+
# |     227 | nutrition_mech_diet_adm        | int64   |
# +---------+--------------------------------+---------+
# |     228 | nutrition_ther_diet_adm        | int64   |
# +---------+--------------------------------+---------+
# |     229 | nutrition_none_adm             | object  |
# +---------+--------------------------------+---------+
# |     230 | pressure_ulcer_adm             | object  |
# +---------+--------------------------------+---------+
# |     231 | stage1_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     232 | stage2_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     233 | stage3_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     234 | stage4_pu_adm                  | Int64   |
# +---------+--------------------------------+---------+
# |     235 | unstageable_dressing_pu_adm    | Int64   |
# +---------+--------------------------------+---------+
# |     236 | unstageable_slough_pu_adm      | Int64   |
# +---------+--------------------------------+---------+
# |     237 | unstageable_deep_pu_adm        | Int64   |
# +---------+--------------------------------+---------+
# |     238 | antipsychotic_taking_adm       | int64   |
# +---------+--------------------------------+---------+
# |     239 | antipsychotic_ind_adm          | int64   |
# +---------+--------------------------------+---------+
# |     240 | anticoagulant_taking_adm       | int64   |
# +---------+--------------------------------+---------+
# |     241 | anticoagulant_ind_adm          | int64   |
# +---------+--------------------------------+---------+
# |     242 | antibiotic_taking_adm          | int64   |
# +---------+--------------------------------+---------+
# |     243 | antibiotic_ind_adm             | int64   |
# +---------+--------------------------------+---------+
# |     244 | opioid_taking_adm              | int64   |
# +---------+--------------------------------+---------+
# |     245 | opioid_ind_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     246 | antiplatelet_taking_adm        | int64   |
# +---------+--------------------------------+---------+
# |     247 | antiplatelet_ind_adm           | int64   |
# +---------+--------------------------------+---------+
# |     248 | hypoglycemic_taking_adm        | int64   |
# +---------+--------------------------------+---------+
# |     249 | hypoglycemic_ind_adm           | int64   |
# +---------+--------------------------------+---------+
# |     250 | med_highrisk_none              | object  |
# +---------+--------------------------------+---------+
# |     251 | drug_regimen_review            | object  |
# +---------+--------------------------------+---------+
# |     252 | med_follow_up                  | Int64   |
# +---------+--------------------------------+---------+
# |     253 | chemo_adm                      | int64   |
# +---------+--------------------------------+---------+
# |     254 | chemo_iv_adm                   | int64   |
# +---------+--------------------------------+---------+
# |     255 | chemo_oral_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     256 | chemo_other_adm                | int64   |
# +---------+--------------------------------+---------+
# |     257 | radiation_adm                  | int64   |
# +---------+--------------------------------+---------+
# |     258 | oxygen_adm                     | int64   |
# +---------+--------------------------------+---------+
# |     259 | oxygen_cont_adm                | int64   |
# +---------+--------------------------------+---------+
# |     260 | oxygen_int_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     261 | oxygen_high_adm                | int64   |
# +---------+--------------------------------+---------+
# |     262 | suctioning_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     263 | suctioning_sched_adm           | int64   |
# +---------+--------------------------------+---------+
# |     264 | suctioning_asneeded_adm        | int64   |
# +---------+--------------------------------+---------+
# |     265 | trach_adm                      | int64   |
# +---------+--------------------------------+---------+
# |     266 | vent_invasive_adm              | int64   |
# +---------+--------------------------------+---------+
# |     267 | vent_noninvasive_adm           | int64   |
# +---------+--------------------------------+---------+
# |     268 | vent_bipap_adm                 | int64   |
# +---------+--------------------------------+---------+
# |     269 | vent_cpap_adm                  | int64   |
# +---------+--------------------------------+---------+
# |     270 | meds_iv_adm                    | int64   |
# +---------+--------------------------------+---------+
# |     271 | meds_iv_vasoactive_adm         | int64   |
# +---------+--------------------------------+---------+
# |     272 | meds_iv_antibiotic_adm         | int64   |
# +---------+--------------------------------+---------+
# |     273 | meds_iv_anticoagulant_adm      | int64   |
# +---------+--------------------------------+---------+
# |     274 | meds_iv_other_adm              | int64   |
# +---------+--------------------------------+---------+
# |     275 | transfusions_adm               | int64   |
# +---------+--------------------------------+---------+
# |     276 | dialysis_adm                   | int64   |
# +---------+--------------------------------+---------+
# |     277 | hemodialysis_adm               | int64   |
# +---------+--------------------------------+---------+
# |     278 | peritoneal_dialysis_adm        | int64   |
# +---------+--------------------------------+---------+
# |     279 | iv_access_adm                  | int64   |
# +---------+--------------------------------+---------+
# |     280 | iv_access_periph_adm           | int64   |
# +---------+--------------------------------+---------+
# |     281 | iv_access_mid_adm              | int64   |
# +---------+--------------------------------+---------+
# |     282 | iv_access_cent_adm             | int64   |
# +---------+--------------------------------+---------+
# |     283 | tx_none_adm                    | object  |
# +---------+--------------------------------+---------+
# |     284 | transport_lack_med_dc          | object  |
# +---------+--------------------------------+---------+
# |     285 | transport_lack_nonmed_dc       | object  |
# +---------+--------------------------------+---------+
# |     286 | transport_lack_dc              | object  |
# +---------+--------------------------------+---------+
# |     287 | transport_lack_unable_dc       | object  |
# +---------+--------------------------------+---------+
# |     288 | transport_lack_declined_dc     | object  |
# +---------+--------------------------------+---------+
# |     289 | med_list_to_provider           | object  |
# +---------+--------------------------------+---------+
# |     290 | med_list_transmit_ehr          | object  |
# +---------+--------------------------------+---------+
# |     291 | med_list_transmit_hie          | object  |
# +---------+--------------------------------+---------+
# |     292 | med_list_transmit_verbal       | object  |
# +---------+--------------------------------+---------+
# |     293 | med_list_transmit_paper        | object  |
# +---------+--------------------------------+---------+
# |     294 | med_list_transmit_other        | object  |
# +---------+--------------------------------+---------+
# |     295 | med_list_to_patient            | object  |
# +---------+--------------------------------+---------+
# |     296 | med_list_pt_ehr                | object  |
# +---------+--------------------------------+---------+
# |     297 | med_list_pt_hie                | object  |
# +---------+--------------------------------+---------+
# |     298 | med_list_pt_verbal             | object  |
# +---------+--------------------------------+---------+
# |     299 | med_list_pt_paper              | object  |
# +---------+--------------------------------+---------+
# |     300 | med_list_pt_other              | object  |
# +---------+--------------------------------+---------+
# |     301 | health_lit_dc                  | object  |
# +---------+--------------------------------+---------+
# |     302 | conduct_bims_dc                | object  |
# +---------+--------------------------------+---------+
# |     303 | bims_3words_dc                 | object  |
# +---------+--------------------------------+---------+
# |     304 | bims_year_dc                   | object  |
# +---------+--------------------------------+---------+
# |     305 | bims_month_dc                  | object  |
# +---------+--------------------------------+---------+
# |     306 | bims_day_dc                    | object  |
# +---------+--------------------------------+---------+
# |     307 | bims_recall_sock_dc            | object  |
# +---------+--------------------------------+---------+
# |     308 | bims_recall_blue_dc            | object  |
# +---------+--------------------------------+---------+
# |     309 | bims_recall_bed_dc             | object  |
# +---------+--------------------------------+---------+
# |     310 | bims_total_dc                  | object  |
# +---------+--------------------------------+---------+
# |     311 | acute_mental_change_dc         | object  |
# +---------+--------------------------------+---------+
# |     312 | inattention_dc                 | object  |
# +---------+--------------------------------+---------+
# |     313 | disorganized_dc                | object  |
# +---------+--------------------------------+---------+
# |     314 | altered_dc                     | object  |
# +---------+--------------------------------+---------+
# |     315 | low_interest_dc                | object  |
# +---------+--------------------------------+---------+
# |     316 | low_interest_freq_dc           | object  |
# +---------+--------------------------------+---------+
# |     317 | depressed_dc                   | object  |
# +---------+--------------------------------+---------+
# |     318 | depressed_freq_dc              | object  |
# +---------+--------------------------------+---------+
# |     319 | sleep_trouble_dc               | object  |
# +---------+--------------------------------+---------+
# |     320 | sleep_trouble_freq_dc          | object  |
# +---------+--------------------------------+---------+
# |     321 | tired_dc                       | object  |
# +---------+--------------------------------+---------+
# |     322 | tired_freq_dc                  | object  |
# +---------+--------------------------------+---------+
# |     323 | appetite_dc                    | object  |
# +---------+--------------------------------+---------+
# |     324 | appetite_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     325 | feel_bad_dc                    | object  |
# +---------+--------------------------------+---------+
# |     326 | feel_bad_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     327 | concentrate_dc                 | object  |
# +---------+--------------------------------+---------+
# |     328 | concentrate_freq_dc            | object  |
# +---------+--------------------------------+---------+
# |     329 | slowfast_dc                    | object  |
# +---------+--------------------------------+---------+
# |     330 | slowfast_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     331 | selfharm_dc                    | object  |
# +---------+--------------------------------+---------+
# |     332 | selfharm_freq_dc               | object  |
# +---------+--------------------------------+---------+
# |     333 | mood_total_dc                  | object  |
# +---------+--------------------------------+---------+
# |     334 | socisolation_dc                | object  |
# +---------+--------------------------------+---------+
# |     335 | eating_dc                      | object  |
# +---------+--------------------------------+---------+
# |     336 | oral_dc                        | object  |
# +---------+--------------------------------+---------+
# |     337 | toileting_dc                   | object  |
# +---------+--------------------------------+---------+
# |     338 | bathe_dc                       | object  |
# +---------+--------------------------------+---------+
# |     339 | dress_upper_dc                 | object  |
# +---------+--------------------------------+---------+
# |     340 | dress_lower_dc                 | object  |
# +---------+--------------------------------+---------+
# |     341 | footwear_dc                    | object  |
# +---------+--------------------------------+---------+
# |     342 | roll_lr_dc                     | object  |
# +---------+--------------------------------+---------+
# |     343 | sit_lying_dc                   | object  |
# +---------+--------------------------------+---------+
# |     344 | lying_sit_dc                   | object  |
# +---------+--------------------------------+---------+
# |     345 | sit_stand_dc                   | object  |
# +---------+--------------------------------+---------+
# |     346 | bed_chair_dc                   | object  |
# +---------+--------------------------------+---------+
# |     347 | toilet_trans_dc                | object  |
# +---------+--------------------------------+---------+
# |     348 | car_trans_dc                   | object  |
# +---------+--------------------------------+---------+
# |     349 | walk10ft_dc                    | object  |
# +---------+--------------------------------+---------+
# |     350 | walk50ft_dc                    | object  |
# +---------+--------------------------------+---------+
# |     351 | walk150ft_dc                   | object  |
# +---------+--------------------------------+---------+
# |     352 | walk10ft_uneven_dc             | object  |
# +---------+--------------------------------+---------+
# |     353 | walk1step_dc                   | object  |
# +---------+--------------------------------+---------+
# |     354 | walk4step_dc                   | object  |
# +---------+--------------------------------+---------+
# |     355 | walk12step_dc                  | object  |
# +---------+--------------------------------+---------+
# |     356 | pickup_dc                      | object  |
# +---------+--------------------------------+---------+
# |     357 | wc_user_dc                     | object  |
# +---------+--------------------------------+---------+
# |     358 | wheel50ft_dc                   | object  |
# +---------+--------------------------------+---------+
# |     359 | wc50_type_dc                   | object  |
# +---------+--------------------------------+---------+
# |     360 | wheel150ft_dc                  | object  |
# +---------+--------------------------------+---------+
# |     361 | wc150_type_dc                  | object  |
# +---------+--------------------------------+---------+
# |     362 | pain_sleep_dc                  | object  |
# +---------+--------------------------------+---------+
# |     363 | pain_therapy_dc                | object  |
# +---------+--------------------------------+---------+
# |     364 | pain_activities_dc             | object  |
# +---------+--------------------------------+---------+
# |     365 | falls_since_adm                | object  |
# +---------+--------------------------------+---------+
# |     366 | falls_no_injury                | object  |
# +---------+--------------------------------+---------+
# |     367 | falls_minor_injury             | object  |
# +---------+--------------------------------+---------+
# |     368 | falls_major_injury             | object  |
# +---------+--------------------------------+---------+
# |     369 | nutrition_parenteral_last7days | object  |
# +---------+--------------------------------+---------+
# |     370 | nutrition_parenteral_dc        | object  |
# +---------+--------------------------------+---------+
# |     371 | nutrition_tube_last7days       | object  |
# +---------+--------------------------------+---------+
# |     372 | nutrition_tube_dc              | object  |
# +---------+--------------------------------+---------+
# |     373 | nutrition_mech_diet_last7days  | object  |
# +---------+--------------------------------+---------+
# |     374 | nutrition_mech_diet_dc         | object  |
# +---------+--------------------------------+---------+
# |     375 | nutrition_ther_diet_last7days  | object  |
# +---------+--------------------------------+---------+
# |     376 | nutrition_ther_diet_dc         | object  |
# +---------+--------------------------------+---------+
# |     377 | nutrition_none_last7days       | object  |
# +---------+--------------------------------+---------+
# |     378 | nutrition_none_dc              | object  |
# +---------+--------------------------------+---------+
# |     379 | pressure_ulcer_dc              | object  |
# +---------+--------------------------------+---------+
# |     380 | stage1_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     381 | stage2_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     382 | stage2_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     383 | stage3_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     384 | stage3_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     385 | stage4_pu_dc                   | float64 |
# +---------+--------------------------------+---------+
# |     386 | stage4_pu_remain               | float64 |
# +---------+--------------------------------+---------+
# |     387 | unstageable_dressing_pu_dc     | float64 |
# +---------+--------------------------------+---------+
# |     388 | unstageable_dressing_pu_remain | float64 |
# +---------+--------------------------------+---------+
# |     389 | unstageable_slough_pu_dc       | float64 |
# +---------+--------------------------------+---------+
# |     390 | unstageable_slough_pu_remain   | float64 |
# +---------+--------------------------------+---------+
# |     391 | unstageable_deep_pu_dc         | float64 |
# +---------+--------------------------------+---------+
# |     392 | unstageable_deep_pu_remain     | float64 |
# +---------+--------------------------------+---------+
# |     393 | antipsychotic_taking_dc        | object  |
# +---------+--------------------------------+---------+
# |     394 | antipsychotic_ind_dc           | object  |
# +---------+--------------------------------+---------+
# |     395 | anticoagulant_taking_dc        | object  |
# +---------+--------------------------------+---------+
# |     396 | anticoagulant_ind_dc           | object  |
# +---------+--------------------------------+---------+
# |     397 | antibiotic_taking_dc           | object  |
# +---------+--------------------------------+---------+
# |     398 | antibiotic_ind_dc              | object  |
# +---------+--------------------------------+---------+
# |     399 | opioid_taking_dc               | object  |
# +---------+--------------------------------+---------+
# |     400 | opioid_ind_dc                  | object  |
# +---------+--------------------------------+---------+
# |     401 | antiplatelet_taking_dc         | object  |
# +---------+--------------------------------+---------+
# |     402 | antiplatelet_ind_dc            | object  |
# +---------+--------------------------------+---------+
# |     403 | hypoglycemic_taking_dc         | object  |
# +---------+--------------------------------+---------+
# |     404 | hypoglycemic_ind_dc            | object  |
# +---------+--------------------------------+---------+
# |     405 | med_highrisk_none_dc           | object  |
# +---------+--------------------------------+---------+
# |     406 | med_intervention               | object  |
# +---------+--------------------------------+---------+
# |     407 | chemo_dc                       | object  |
# +---------+--------------------------------+---------+
# |     408 | chemo_iv_dc                    | object  |
# +---------+--------------------------------+---------+
# |     409 | chemo_oral_dc                  | object  |
# +---------+--------------------------------+---------+
# |     410 | chemo_other_dc                 | object  |
# +---------+--------------------------------+---------+
# |     411 | radiation_dc                   | object  |
# +---------+--------------------------------+---------+
# |     412 | oxygen_dc                      | object  |
# +---------+--------------------------------+---------+
# |     413 | oxygen_cont_dc                 | object  |
# +---------+--------------------------------+---------+
# |     414 | oxygen_int_dc                  | object  |
# +---------+--------------------------------+---------+
# |     415 | oxygen_high_dc                 | object  |
# +---------+--------------------------------+---------+
# |     416 | suctioning_dc                  | object  |
# +---------+--------------------------------+---------+
# |     417 | suctioning_sched_dc            | object  |
# +---------+--------------------------------+---------+
# |     418 | suctioning_asneeded_dc         | object  |
# +---------+--------------------------------+---------+
# |     419 | trach_dc                       | object  |
# +---------+--------------------------------+---------+
# |     420 | vent_invasive_dc               | object  |
# +---------+--------------------------------+---------+
# |     421 | vent_noninvasive_dc            | object  |
# +---------+--------------------------------+---------+
# |     422 | vent_bipap_dc                  | object  |
# +---------+--------------------------------+---------+
# |     423 | vent_cpap_dc                   | object  |
# +---------+--------------------------------+---------+
# |     424 | meds_iv_dc                     | object  |
# +---------+--------------------------------+---------+
# |     425 | meds_iv_vasoactive_dc          | object  |
# +---------+--------------------------------+---------+
# |     426 | meds_iv_antibiotic_dc          | object  |
# +---------+--------------------------------+---------+
# |     427 | meds_iv_anticoagulant_dc       | object  |
# +---------+--------------------------------+---------+
# |     428 | meds_iv_other_dc               | object  |
# +---------+--------------------------------+---------+
# |     429 | transfusions_dc                | object  |
# +---------+--------------------------------+---------+
# |     430 | dialysis_dc                    | object  |
# +---------+--------------------------------+---------+
# |     431 | hemodialysis_dc                | object  |
# +---------+--------------------------------+---------+
# |     432 | peritoneal_dialysis_dc         | object  |
# +---------+--------------------------------+---------+
# |     433 | iv_access_dc                   | object  |
# +---------+--------------------------------+---------+
# |     434 | iv_access_periph_dc            | object  |
# +---------+--------------------------------+---------+
# |     435 | iv_access_mid_dc               | object  |
# +---------+--------------------------------+---------+
# |     436 | iv_access_cent_dc              | object  |
# +---------+--------------------------------+---------+
# |     437 | tx_none_dc                     | object  |
# +---------+--------------------------------+---------+
# |     438 | age_at_admit                   | float64 |
# +---------+--------------------------------+---------+
# |     439 | los                            | float64 |
# +---------+--------------------------------+---------+
# |     440 | ric                            | float64 |
# +---------+--------------------------------+---------+
# |     441 | cmg                            | float64 |
# +---------+--------------------------------+---------+
# |     442 | tier                           | object  |
# +---------+--------------------------------+---------+
# |     443 | shortstayexpired               | object  |
# +---------+--------------------------------+---------+
# |     444 | shortstaycmg                   | float64 |
# +---------+--------------------------------+---------+
# |     445 | transferpatient                | object  |
# +---------+--------------------------------+---------+
# |     446 | incompletestay                 | object  |
# +---------+--------------------------------+---------+
# |     447 | unplanned_discharge            | float64 |
# +---------+--------------------------------+---------+
# |     448 | selfcare_measure_adm           | float64 |
# +---------+--------------------------------+---------+
# |     449 | selfcare_measure_dc            | float64 |
# +---------+--------------------------------+---------+
# |     450 | mobility_measure_adm           | float64 |
# +---------+--------------------------------+---------+
# |     451 | mobility_measure_dc            | float64 |
# +---------+--------------------------------+---------+
# |     452 | selfcare_measure_delta         | float64 |
# +---------+--------------------------------+---------+
# |     453 | mobility_measure_delta         | float64 |
# +---------+--------------------------------+---------+
# |     454 | race                           | object  |
# +---------+--------------------------------+---------+

# %%
# define predictors and outcomes
interested_predictors = [
    # >>> base info >>>
    "sex", # male / female
    "marital_status", # ['Married' 'Widowed' 'Unknown' 'Divorced' 'Separated' 'Never_married']
    "admitclass",
    "admit_from",
    "prehospital_living",
    "payor_primary",
    # "impgroupadmit", # what does this do?
    # "diagnosis", # need a pretrained LM for embedding
    "arthritis", 
    "heightinches",
    "weightpounds",
    # <<< base info <<<

    # >>> treatments >>>
    "ptindweek1",
    "ptconweek1",
    "ptgrpweek1",
    "ptcoweek1",
    "otindweek1",
    "otconweek1",
    "otgrpweek1",
    "otcoweek1",
    "slpindweek1",
    "slpconweek1",
    "slpgrpweek1",
    "slpcoweek1",
    "ptindweek2",
    "ptconweek2",
    "ptgrpweek2",
    "ptcoweek2",
    "otindweek2",
    "otconweek2",
    "otgrpweek2",
    "otcoweek2",
    "slpindweek2",
    "slpconweek2",
    "slpgrpweek2",
    "slpcoweek2",
    # <<< treatments <<<

    # >>> section A admission >>>
    "hispanic", # ethnicity, Yes or No
    "race", # integrated race categorical field
    "language", # integrated language categorical field: English or Non-English
    "transport_lack_med", # NACHC
    "transport_lack_nonmed", # NACHC
    # <<< section A admission <<<
    
    # >>> section B C admission >>>
    "hearing_adm",
    "vision_adm",
    "health_lit_adm",
    "expression_adm",
    "understand_verbal_adm",
    "conduct_bims", # bims: Brief Interview for Mental Status
    # "bims_3words",
    # "bims_year",
    # "bims_month",
    # "bims_day",
    # "bims_recall_sock",
    # "bims_recall_blue",
    # "bims_recall_bed",
    "bims_total",
    "conduct_sams", # only if "conduct_bims" is false, conduct Staff Assessment for Mental Status
    "sams_season",
    "sams_room",
    "sams_names",
    "sams_hosp",
    # "sams_none_above", # don't include this since it's inferable from others
    "acute_mental_change",
    "inattention_adm",
    "disorganized_adm",
    "altered_adm",
    # <<< section B C admission <<<
    
    # >>> section D admission >>>
    # "low_interest_adm",
    # "low_interest_freq_adm",
    # "depressed_adm",
    # "depressed_freq_adm",
    # "sleep_trouble_adm",
    # "sleep_trouble_freq_adm",
    # "tired_adm",
    # "tired_freq_adm",
    # "appetite_adm",
    # "appetite_freq_adm",
    # "feel_bad_adm",
    # "feel_bad_freq_adm",
    # "concentrate_adm",
    # "concentrate_freq_adm",
    # "slowfast_adm",
    # "slowfast_freq_adm",
    # "selfharm_adm",
    # "selfharm_freq_adm",
    "mood_total_adm", # total alone is enough to cover all above
    "socisolation_adm",
    # <<< section D admission <<<

    # >>> section GG admission >>>
    "selfcare_prior",
    "mobility_prior",
    "stairs_prior",
    "func_cog_prior",
    "wc_manual_prior",
    "wc_motor_prior",
    "mechlift_prior",
    "walker_prior",
    "orth_pros_prior",
    # "no_device_prior", # can be inferred
    # "eating_adm",
    # # "eating_goal",
    # "oral_adm",
    # # "oral_goal",
    # "toileting_adm",
    # # "toileting_goal",
    # "bathe_adm",
    # # "bathe_goal",
    # "dress_upper_adm",
    # # "dress_upper_goal",
    # "dress_lower_adm",
    # # "dress_lower_goal",
    # "footwear_adm",
    # # "footwear_goal",
    # "roll_lr_adm",
    # # "roll_lr_goal",
    # "sit_lying_adm",
    # # "sit_lying_goal",
    # "lying_sit_adm",
    # # "lying_sit_goal",
    # "sit_stand_adm",
    # # "sit_stand_goal",
    # "bed_chair_adm",
    # # "bed_chair_goal",
    # "toilet_trans_adm",
    # # "toilet_trans_goal",
    # "car_trans_adm",
    # # "car_trans_goal",
    # "walk10ft_adm",
    # # "walk10ft_goal",
    # "walk50ft_adm",
    # # "walk50ft_goal",
    # "walk150ft_adm",
    # # "walk150ft_goal",
    # "walk10ft_uneven_adm",
    # # "walk10ft_uneven_goal",
    # "walk1step_adm",
    # # "walk1step_goal",
    # "walk4step_adm",
    # # "walk4step_goal",
    # "walk12step_adm",
    # # "walk12step_goal",
    # "pickup_adm",
    # # "pickup_goal",
    "selfcare_measure_adm", # added in section 1.2
    "mobility_measure_adm", # added in section 1.2
    "wc_user", # inferable, but still preserved
    "wheel50ft_adm",
    # "wheel50ft_goal",
    "wc50_type",
    "wheel150ft_adm",
    # "wheel150ft_goal",
    "wc150_type",
    # <<< section GG admission <<<

    # >>> section H I J K M N O admission >>>
    "bladder_incontinence",
    "bowel_incontinence",
    "pvd_comorbid",
    "diabetes_comorbid",
    # "no_comorbidities", # inferable
    "pain_sleep_adm",
    "pain_therapy_adm",
    "pain_activities_adm",
    "falls_hx",
    "prior_surgery",
    "nutrition_parenteral_adm",
    "nutrition_tube_adm",
    "nutrition_mech_diet_adm",
    "nutrition_ther_diet_adm",
    # "nutrition_none_adm", # inferable
    # "pressure_ulcer_adm", #inferable
    "stage1_pu_adm",
    "stage2_pu_adm",
    "stage3_pu_adm",
    "stage4_pu_adm",
    "unstageable_dressing_pu_adm",
    "unstageable_slough_pu_adm",
    "unstageable_deep_pu_adm",
    "antipsychotic_taking_adm",
    "antipsychotic_ind_adm",
    "anticoagulant_taking_adm",
    "anticoagulant_ind_adm",
    "antibiotic_taking_adm",
    "antibiotic_ind_adm",
    "opioid_taking_adm",
    "opioid_ind_adm",
    "antiplatelet_taking_adm",
    "antiplatelet_ind_adm",
    "hypoglycemic_taking_adm",
    "hypoglycemic_ind_adm",
    # "med_highrisk_none", # inferable
    "drug_regimen_review",
    "med_follow_up",
    "chemo_adm",
    "chemo_iv_adm",
    "chemo_oral_adm",
    "chemo_other_adm",
    "radiation_adm",
    "oxygen_adm",
    "oxygen_cont_adm",
    "oxygen_int_adm",
    "oxygen_high_adm",
    "suctioning_adm",
    "suctioning_sched_adm",
    "suctioning_asneeded_adm",
    "trach_adm",
    "vent_invasive_adm",
    "vent_noninvasive_adm",
    "vent_bipap_adm",
    "vent_cpap_adm",
    "meds_iv_adm",
    "meds_iv_vasoactive_adm",
    "meds_iv_antibiotic_adm",
    "meds_iv_anticoagulant_adm",
    "meds_iv_other_adm",
    "transfusions_adm",
    "dialysis_adm",
    "hemodialysis_adm",
    "peritoneal_dialysis_adm",
    "iv_access_adm",
    "iv_access_periph_adm",
    "iv_access_mid_adm",
    "iv_access_cent_adm",
    # "tx_none_adm", # inferable
    # <<< section H I J K M N O admission <<<

    # >>> the rest >>>
    "age_at_admit",
    "los",
    "ric",
    "cmg",
    "tier",
    # "shortstayexpired",
    # "shortstaycmg",
    # "transferpatient",
    # "incompletestay",
    # <<< the rest <<<

]

interested_outcomes = [
    "selfcare_measure_delta", # added in section 1.2
    "mobility_measure_delta" # added in section 1.2
]

# %%
# cross-verify feature table

all_features_in_table = set()
for k in feature_table.keys():
    for name in feature_table[k]:
        all_features_in_table.add(name)
        if name not in interested_predictors+interested_outcomes:
            print(f"{name} is processed but not selected!")

for name in interested_predictors+interested_outcomes:
    if name not in all_features_in_table:
        print(f"{name} is interesting but not processed!")
# Out:
# depressed_adm is processed but not selected!
# sit_stand_adm is processed but not selected!
# depressed_freq_adm is processed but not selected!
# sit_lying_adm is processed but not selected!
# walk150ft_adm is processed but not selected!
# dress_upper_adm is processed but not selected!
# bed_chair_adm is processed but not selected!
# toileting_adm is processed but not selected!
# feel_bad_freq_adm is processed but not selected!
# walk10ft_adm is processed but not selected!
# admityear is processed but not selected!
# appetite_adm is processed but not selected!
# car_trans_adm is processed but not selected!
# slowfast_freq_adm is processed but not selected!
# bims_recall_bed is processed but not selected!
# appetite_freq_adm is processed but not selected!
# selfharm_freq_adm is processed but not selected!
# footwear_adm is processed but not selected!
# walk4step_adm is processed but not selected!
# pickup_adm is processed but not selected!
# sleep_trouble_freq_adm is processed but not selected!
# walk1step_adm is processed but not selected!
# walk12step_adm is processed but not selected!
# low_interest_freq_adm is processed but not selected!
# bathe_adm is processed but not selected!
# bims_3words is processed but not selected!
# concentrate_freq_adm is processed but not selected!
# feel_bad_adm is processed but not selected!
# roll_lr_adm is processed but not selected!
# dress_lower_adm is processed but not selected!
# walk10ft_uneven_adm is processed but not selected!
# bims_year is processed but not selected!
# sleep_trouble_adm is processed but not selected!
# bims_recall_sock is processed but not selected!
# bims_recall_blue is processed but not selected!
# toilet_trans_adm is processed but not selected!
# lying_sit_adm is processed but not selected!
# oral_adm is processed but not selected!
# eating_adm is processed but not selected!
# low_interest_adm is processed but not selected!
# bims_month is processed but not selected!
# slowfast_adm is processed but not selected!
# concentrate_adm is processed but not selected!
# walk50ft_adm is processed but not selected!
# selfharm_adm is processed but not selected!
# tired_adm is processed but not selected!
# bims_day is processed but not selected!
# tired_freq_adm is processed but not selected!
# sams_none_above is processed but not selected!
# no_device_prior is processed but not selected!
# selfcare_measure_delta is interesting but not processed!
# mobility_measure_delta is interesting but not processed!

# %%
# select subset of features
df = df[interested_outcomes+interested_predictors]

feature_names = [*df.head()]
feature_dtypes = df.dtypes
print("total # of features:", len(feature_names))
print(tabulate([(index, name, feature_dtypes[name]) for index, name in enumerate(feature_names)], headers=["Index", "Name", "Dtype"], tablefmt="grid"))
# Out:
# total # of features: 143
# +---------+-----------------------------+---------+
# |   Index | Name                        | Dtype   |
# +=========+=============================+=========+
# |       0 | selfcare_measure_delta      | float64 |
# +---------+-----------------------------+---------+
# |       1 | mobility_measure_delta      | float64 |
# +---------+-----------------------------+---------+
# |       2 | sex                         | object  |
# +---------+-----------------------------+---------+
# |       3 | marital_status              | object  |
# +---------+-----------------------------+---------+
# |       4 | admitclass                  | object  |
# +---------+-----------------------------+---------+
# |       5 | admit_from                  | object  |
# +---------+-----------------------------+---------+
# |       6 | prehospital_living          | object  |
# +---------+-----------------------------+---------+
# |       7 | payor_primary               | object  |
# +---------+-----------------------------+---------+
# |       8 | arthritis                   | object  |
# +---------+-----------------------------+---------+
# |       9 | heightinches                | float64 |
# +---------+-----------------------------+---------+
# |      10 | weightpounds                | float64 |
# +---------+-----------------------------+---------+
# |      11 | ptindweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      12 | ptconweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      13 | ptgrpweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      14 | ptcoweek1                   | float64 |
# +---------+-----------------------------+---------+
# |      15 | otindweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      16 | otconweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      17 | otgrpweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      18 | otcoweek1                   | float64 |
# +---------+-----------------------------+---------+
# |      19 | slpindweek1                 | float64 |
# +---------+-----------------------------+---------+
# |      20 | slpconweek1                 | float64 |
# +---------+-----------------------------+---------+
# |      21 | slpgrpweek1                 | float64 |
# +---------+-----------------------------+---------+
# |      22 | slpcoweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      23 | ptindweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      24 | ptconweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      25 | ptgrpweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      26 | ptcoweek2                   | float64 |
# +---------+-----------------------------+---------+
# |      27 | otindweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      28 | otconweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      29 | otgrpweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      30 | otcoweek2                   | float64 |
# +---------+-----------------------------+---------+
# |      31 | slpindweek2                 | float64 |
# +---------+-----------------------------+---------+
# |      32 | slpconweek2                 | float64 |
# +---------+-----------------------------+---------+
# |      33 | slpgrpweek2                 | float64 |
# +---------+-----------------------------+---------+
# |      34 | slpcoweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      35 | hispanic                    | object  |
# +---------+-----------------------------+---------+
# |      36 | race                        | object  |
# +---------+-----------------------------+---------+
# |      37 | language                    | object  |
# +---------+-----------------------------+---------+
# |      38 | transport_lack_med          | int64   |
# +---------+-----------------------------+---------+
# |      39 | transport_lack_nonmed       | int64   |
# +---------+-----------------------------+---------+
# |      40 | hearing_adm                 | Int64   |
# +---------+-----------------------------+---------+
# |      41 | vision_adm                  | Int64   |
# +---------+-----------------------------+---------+
# |      42 | health_lit_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      43 | expression_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      44 | understand_verbal_adm       | Int64   |
# +---------+-----------------------------+---------+
# |      45 | conduct_bims                | int64   |
# +---------+-----------------------------+---------+
# |      46 | bims_total                  | Int64   |
# +---------+-----------------------------+---------+
# |      47 | conduct_sams                | int64   |
# +---------+-----------------------------+---------+
# |      48 | sams_season                 | int64   |
# +---------+-----------------------------+---------+
# |      49 | sams_room                   | int64   |
# +---------+-----------------------------+---------+
# |      50 | sams_names                  | int64   |
# +---------+-----------------------------+---------+
# |      51 | sams_hosp                   | int64   |
# +---------+-----------------------------+---------+
# |      52 | acute_mental_change         | int64   |
# +---------+-----------------------------+---------+
# |      53 | inattention_adm             | object  |
# +---------+-----------------------------+---------+
# |      54 | disorganized_adm            | object  |
# +---------+-----------------------------+---------+
# |      55 | altered_adm                 | object  |
# +---------+-----------------------------+---------+
# |      56 | mood_total_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      57 | socisolation_adm            | Int64   |
# +---------+-----------------------------+---------+
# |      58 | selfcare_prior              | Int64   |
# +---------+-----------------------------+---------+
# |      59 | mobility_prior              | Int64   |
# +---------+-----------------------------+---------+
# |      60 | stairs_prior                | Int64   |
# +---------+-----------------------------+---------+
# |      61 | func_cog_prior              | Int64   |
# +---------+-----------------------------+---------+
# |      62 | wc_manual_prior             | int64   |
# +---------+-----------------------------+---------+
# |      63 | wc_motor_prior              | int64   |
# +---------+-----------------------------+---------+
# |      64 | mechlift_prior              | int64   |
# +---------+-----------------------------+---------+
# |      65 | walker_prior                | int64   |
# +---------+-----------------------------+---------+
# |      66 | orth_pros_prior             | int64   |
# +---------+-----------------------------+---------+
# |      67 | selfcare_measure_adm        | float64 |
# +---------+-----------------------------+---------+
# |      68 | mobility_measure_adm        | float64 |
# +---------+-----------------------------+---------+
# |      69 | wc_user                     | int64   |
# +---------+-----------------------------+---------+
# |      70 | wheel50ft_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      71 | wc50_type                   | object  |
# +---------+-----------------------------+---------+
# |      72 | wheel150ft_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      73 | wc150_type                  | object  |
# +---------+-----------------------------+---------+
# |      74 | bladder_incontinence        | Int64   |
# +---------+-----------------------------+---------+
# |      75 | bowel_incontinence          | Int64   |
# +---------+-----------------------------+---------+
# |      76 | pvd_comorbid                | int64   |
# +---------+-----------------------------+---------+
# |      77 | diabetes_comorbid           | int64   |
# +---------+-----------------------------+---------+
# |      78 | pain_sleep_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      79 | pain_therapy_adm            | Int64   |
# +---------+-----------------------------+---------+
# |      80 | pain_activities_adm         | Int64   |
# +---------+-----------------------------+---------+
# |      81 | falls_hx                    | object  |
# +---------+-----------------------------+---------+
# |      82 | prior_surgery               | object  |
# +---------+-----------------------------+---------+
# |      83 | nutrition_parenteral_adm    | int64   |
# +---------+-----------------------------+---------+
# |      84 | nutrition_tube_adm          | int64   |
# +---------+-----------------------------+---------+
# |      85 | nutrition_mech_diet_adm     | int64   |
# +---------+-----------------------------+---------+
# |      86 | nutrition_ther_diet_adm     | int64   |
# +---------+-----------------------------+---------+
# |      87 | stage1_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      88 | stage2_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      89 | stage3_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      90 | stage4_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      91 | unstageable_dressing_pu_adm | Int64   |
# +---------+-----------------------------+---------+
# |      92 | unstageable_slough_pu_adm   | Int64   |
# +---------+-----------------------------+---------+
# |      93 | unstageable_deep_pu_adm     | Int64   |
# +---------+-----------------------------+---------+
# |      94 | antipsychotic_taking_adm    | int64   |
# +---------+-----------------------------+---------+
# |      95 | antipsychotic_ind_adm       | int64   |
# +---------+-----------------------------+---------+
# |      96 | anticoagulant_taking_adm    | int64   |
# +---------+-----------------------------+---------+
# |      97 | anticoagulant_ind_adm       | int64   |
# +---------+-----------------------------+---------+
# |      98 | antibiotic_taking_adm       | int64   |
# +---------+-----------------------------+---------+
# |      99 | antibiotic_ind_adm          | int64   |
# +---------+-----------------------------+---------+
# |     100 | opioid_taking_adm           | int64   |
# +---------+-----------------------------+---------+
# |     101 | opioid_ind_adm              | int64   |
# +---------+-----------------------------+---------+
# |     102 | antiplatelet_taking_adm     | int64   |
# +---------+-----------------------------+---------+
# |     103 | antiplatelet_ind_adm        | int64   |
# +---------+-----------------------------+---------+
# |     104 | hypoglycemic_taking_adm     | int64   |
# +---------+-----------------------------+---------+
# |     105 | hypoglycemic_ind_adm        | int64   |
# +---------+-----------------------------+---------+
# |     106 | drug_regimen_review         | object  |
# +---------+-----------------------------+---------+
# |     107 | med_follow_up               | Int64   |
# +---------+-----------------------------+---------+
# |     108 | chemo_adm                   | int64   |
# +---------+-----------------------------+---------+
# |     109 | chemo_iv_adm                | int64   |
# +---------+-----------------------------+---------+
# |     110 | chemo_oral_adm              | int64   |
# +---------+-----------------------------+---------+
# |     111 | chemo_other_adm             | int64   |
# +---------+-----------------------------+---------+
# |     112 | radiation_adm               | int64   |
# +---------+-----------------------------+---------+
# |     113 | oxygen_adm                  | int64   |
# +---------+-----------------------------+---------+
# |     114 | oxygen_cont_adm             | int64   |
# +---------+-----------------------------+---------+
# |     115 | oxygen_int_adm              | int64   |
# +---------+-----------------------------+---------+
# |     116 | oxygen_high_adm             | int64   |
# +---------+-----------------------------+---------+
# |     117 | suctioning_adm              | int64   |
# +---------+-----------------------------+---------+
# |     118 | suctioning_sched_adm        | int64   |
# +---------+-----------------------------+---------+
# |     119 | suctioning_asneeded_adm     | int64   |
# +---------+-----------------------------+---------+
# |     120 | trach_adm                   | int64   |
# +---------+-----------------------------+---------+
# |     121 | vent_invasive_adm           | int64   |
# +---------+-----------------------------+---------+
# |     122 | vent_noninvasive_adm        | int64   |
# +---------+-----------------------------+---------+
# |     123 | vent_bipap_adm              | int64   |
# +---------+-----------------------------+---------+
# |     124 | vent_cpap_adm               | int64   |
# +---------+-----------------------------+---------+
# |     125 | meds_iv_adm                 | int64   |
# +---------+-----------------------------+---------+
# |     126 | meds_iv_vasoactive_adm      | int64   |
# +---------+-----------------------------+---------+
# |     127 | meds_iv_antibiotic_adm      | int64   |
# +---------+-----------------------------+---------+
# |     128 | meds_iv_anticoagulant_adm   | int64   |
# +---------+-----------------------------+---------+
# |     129 | meds_iv_other_adm           | int64   |
# +---------+-----------------------------+---------+
# |     130 | transfusions_adm            | int64   |
# +---------+-----------------------------+---------+
# |     131 | dialysis_adm                | int64   |
# +---------+-----------------------------+---------+
# |     132 | hemodialysis_adm            | int64   |
# +---------+-----------------------------+---------+
# |     133 | peritoneal_dialysis_adm     | int64   |
# +---------+-----------------------------+---------+
# |     134 | iv_access_adm               | int64   |
# +---------+-----------------------------+---------+
# |     135 | iv_access_periph_adm        | int64   |
# +---------+-----------------------------+---------+
# |     136 | iv_access_mid_adm           | int64   |
# +---------+-----------------------------+---------+
# |     137 | iv_access_cent_adm          | int64   |
# +---------+-----------------------------+---------+
# |     138 | age_at_admit                | float64 |
# +---------+-----------------------------+---------+
# |     139 | los                         | float64 |
# +---------+-----------------------------+---------+
# |     140 | ric                         | float64 |
# +---------+-----------------------------+---------+
# |     141 | cmg                         | float64 |
# +---------+-----------------------------+---------+
# |     142 | tier                        | object  |
# +---------+-----------------------------+---------+

# %%
# save
df.to_csv('./data/Cleaned files/Cogan_2_1.csv', index=True)

# %% [markdown]
# ### 2.2 Imputation

# %%
# total # of features and a list of all feature names

import pandas as pd
import pickle
import numpy as np
from tabulate import tabulate
import json

def convert_dtypes(df, dtype_dict):
    for name in df.columns:
        dtype = dtype_dict[name]
        df[name] = df[name].astype(dtype)

# always start from loading the CSV file from previous section
df = pd.read_csv('./data/Cleaned files/Cogan_2_1.csv', low_memory=False, index_col='id')
with open("./data/Cleaned files/lookup_table.pkl", 'rb') as f:
    lookup_table = pickle.load(f)
with open("./data/Cleaned files/feature_table.pkl", 'rb') as f:
    feature_table = pickle.load(f)

# convert dtypes
with open('./data/Cleaned files/processed_feature_dtypes.json', 'r') as f:
    dtype_dict = json.load(f)
convert_dtypes(df, dtype_dict)

feature_names = [*df.head()]
feature_dtypes = df.dtypes
print("total # of features:", len(feature_names))

print(tabulate([(index, name, feature_dtypes[name]) for index, name in enumerate(feature_names)], headers=["Index", "Name", "Dtype"], tablefmt="grid"))
categorical_feature_set = feature_table["categorical"]
numeric_feature_set = feature_table["numeric"]
ranked_int_feature_set = feature_table["ranked_int"]
binary_feature_set = feature_table["binary"]
outcomes = ["selfcare_measure_delta", "mobility_measure_delta"]
# Out:
# total # of features: 143
# +---------+-----------------------------+---------+
# |   Index | Name                        | Dtype   |
# +=========+=============================+=========+
# |       0 | selfcare_measure_delta      | float64 |
# +---------+-----------------------------+---------+
# |       1 | mobility_measure_delta      | float64 |
# +---------+-----------------------------+---------+
# |       2 | sex                         | object  |
# +---------+-----------------------------+---------+
# |       3 | marital_status              | object  |
# +---------+-----------------------------+---------+
# |       4 | admitclass                  | object  |
# +---------+-----------------------------+---------+
# |       5 | admit_from                  | object  |
# +---------+-----------------------------+---------+
# |       6 | prehospital_living          | object  |
# +---------+-----------------------------+---------+
# |       7 | payor_primary               | object  |
# +---------+-----------------------------+---------+
# |       8 | arthritis                   | object  |
# +---------+-----------------------------+---------+
# |       9 | heightinches                | float64 |
# +---------+-----------------------------+---------+
# |      10 | weightpounds                | float64 |
# +---------+-----------------------------+---------+
# |      11 | ptindweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      12 | ptconweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      13 | ptgrpweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      14 | ptcoweek1                   | float64 |
# +---------+-----------------------------+---------+
# |      15 | otindweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      16 | otconweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      17 | otgrpweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      18 | otcoweek1                   | float64 |
# +---------+-----------------------------+---------+
# |      19 | slpindweek1                 | float64 |
# +---------+-----------------------------+---------+
# |      20 | slpconweek1                 | float64 |
# +---------+-----------------------------+---------+
# |      21 | slpgrpweek1                 | float64 |
# +---------+-----------------------------+---------+
# |      22 | slpcoweek1                  | float64 |
# +---------+-----------------------------+---------+
# |      23 | ptindweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      24 | ptconweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      25 | ptgrpweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      26 | ptcoweek2                   | float64 |
# +---------+-----------------------------+---------+
# |      27 | otindweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      28 | otconweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      29 | otgrpweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      30 | otcoweek2                   | float64 |
# +---------+-----------------------------+---------+
# |      31 | slpindweek2                 | float64 |
# +---------+-----------------------------+---------+
# |      32 | slpconweek2                 | float64 |
# +---------+-----------------------------+---------+
# |      33 | slpgrpweek2                 | float64 |
# +---------+-----------------------------+---------+
# |      34 | slpcoweek2                  | float64 |
# +---------+-----------------------------+---------+
# |      35 | hispanic                    | object  |
# +---------+-----------------------------+---------+
# |      36 | race                        | object  |
# +---------+-----------------------------+---------+
# |      37 | language                    | object  |
# +---------+-----------------------------+---------+
# |      38 | transport_lack_med          | int64   |
# +---------+-----------------------------+---------+
# |      39 | transport_lack_nonmed       | int64   |
# +---------+-----------------------------+---------+
# |      40 | hearing_adm                 | Int64   |
# +---------+-----------------------------+---------+
# |      41 | vision_adm                  | Int64   |
# +---------+-----------------------------+---------+
# |      42 | health_lit_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      43 | expression_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      44 | understand_verbal_adm       | Int64   |
# +---------+-----------------------------+---------+
# |      45 | conduct_bims                | int64   |
# +---------+-----------------------------+---------+
# |      46 | bims_total                  | Int64   |
# +---------+-----------------------------+---------+
# |      47 | conduct_sams                | int64   |
# +---------+-----------------------------+---------+
# |      48 | sams_season                 | int64   |
# +---------+-----------------------------+---------+
# |      49 | sams_room                   | int64   |
# +---------+-----------------------------+---------+
# |      50 | sams_names                  | int64   |
# +---------+-----------------------------+---------+
# |      51 | sams_hosp                   | int64   |
# +---------+-----------------------------+---------+
# |      52 | acute_mental_change         | int64   |
# +---------+-----------------------------+---------+
# |      53 | inattention_adm             | object  |
# +---------+-----------------------------+---------+
# |      54 | disorganized_adm            | object  |
# +---------+-----------------------------+---------+
# |      55 | altered_adm                 | object  |
# +---------+-----------------------------+---------+
# |      56 | mood_total_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      57 | socisolation_adm            | Int64   |
# +---------+-----------------------------+---------+
# |      58 | selfcare_prior              | Int64   |
# +---------+-----------------------------+---------+
# |      59 | mobility_prior              | Int64   |
# +---------+-----------------------------+---------+
# |      60 | stairs_prior                | Int64   |
# +---------+-----------------------------+---------+
# |      61 | func_cog_prior              | Int64   |
# +---------+-----------------------------+---------+
# |      62 | wc_manual_prior             | int64   |
# +---------+-----------------------------+---------+
# |      63 | wc_motor_prior              | int64   |
# +---------+-----------------------------+---------+
# |      64 | mechlift_prior              | int64   |
# +---------+-----------------------------+---------+
# |      65 | walker_prior                | int64   |
# +---------+-----------------------------+---------+
# |      66 | orth_pros_prior             | int64   |
# +---------+-----------------------------+---------+
# |      67 | selfcare_measure_adm        | float64 |
# +---------+-----------------------------+---------+
# |      68 | mobility_measure_adm        | float64 |
# +---------+-----------------------------+---------+
# |      69 | wc_user                     | int64   |
# +---------+-----------------------------+---------+
# |      70 | wheel50ft_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      71 | wc50_type                   | object  |
# +---------+-----------------------------+---------+
# |      72 | wheel150ft_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      73 | wc150_type                  | object  |
# +---------+-----------------------------+---------+
# |      74 | bladder_incontinence        | Int64   |
# +---------+-----------------------------+---------+
# |      75 | bowel_incontinence          | Int64   |
# +---------+-----------------------------+---------+
# |      76 | pvd_comorbid                | int64   |
# +---------+-----------------------------+---------+
# |      77 | diabetes_comorbid           | int64   |
# +---------+-----------------------------+---------+
# |      78 | pain_sleep_adm              | Int64   |
# +---------+-----------------------------+---------+
# |      79 | pain_therapy_adm            | Int64   |
# +---------+-----------------------------+---------+
# |      80 | pain_activities_adm         | Int64   |
# +---------+-----------------------------+---------+
# |      81 | falls_hx                    | object  |
# +---------+-----------------------------+---------+
# |      82 | prior_surgery               | object  |
# +---------+-----------------------------+---------+
# |      83 | nutrition_parenteral_adm    | int64   |
# +---------+-----------------------------+---------+
# |      84 | nutrition_tube_adm          | int64   |
# +---------+-----------------------------+---------+
# |      85 | nutrition_mech_diet_adm     | int64   |
# +---------+-----------------------------+---------+
# |      86 | nutrition_ther_diet_adm     | int64   |
# +---------+-----------------------------+---------+
# |      87 | stage1_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      88 | stage2_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      89 | stage3_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      90 | stage4_pu_adm               | Int64   |
# +---------+-----------------------------+---------+
# |      91 | unstageable_dressing_pu_adm | Int64   |
# +---------+-----------------------------+---------+
# |      92 | unstageable_slough_pu_adm   | Int64   |
# +---------+-----------------------------+---------+
# |      93 | unstageable_deep_pu_adm     | Int64   |
# +---------+-----------------------------+---------+
# |      94 | antipsychotic_taking_adm    | int64   |
# +---------+-----------------------------+---------+
# |      95 | antipsychotic_ind_adm       | int64   |
# +---------+-----------------------------+---------+
# |      96 | anticoagulant_taking_adm    | int64   |
# +---------+-----------------------------+---------+
# |      97 | anticoagulant_ind_adm       | int64   |
# +---------+-----------------------------+---------+
# |      98 | antibiotic_taking_adm       | int64   |
# +---------+-----------------------------+---------+
# |      99 | antibiotic_ind_adm          | int64   |
# +---------+-----------------------------+---------+
# |     100 | opioid_taking_adm           | int64   |
# +---------+-----------------------------+---------+
# |     101 | opioid_ind_adm              | int64   |
# +---------+-----------------------------+---------+
# |     102 | antiplatelet_taking_adm     | int64   |
# +---------+-----------------------------+---------+
# |     103 | antiplatelet_ind_adm        | int64   |
# +---------+-----------------------------+---------+
# |     104 | hypoglycemic_taking_adm     | int64   |
# +---------+-----------------------------+---------+
# |     105 | hypoglycemic_ind_adm        | int64   |
# +---------+-----------------------------+---------+
# |     106 | drug_regimen_review         | object  |
# +---------+-----------------------------+---------+
# |     107 | med_follow_up               | Int64   |
# +---------+-----------------------------+---------+
# |     108 | chemo_adm                   | int64   |
# +---------+-----------------------------+---------+
# |     109 | chemo_iv_adm                | int64   |
# +---------+-----------------------------+---------+
# |     110 | chemo_oral_adm              | int64   |
# +---------+-----------------------------+---------+
# |     111 | chemo_other_adm             | int64   |
# +---------+-----------------------------+---------+
# |     112 | radiation_adm               | int64   |
# +---------+-----------------------------+---------+
# |     113 | oxygen_adm                  | int64   |
# +---------+-----------------------------+---------+
# |     114 | oxygen_cont_adm             | int64   |
# +---------+-----------------------------+---------+
# |     115 | oxygen_int_adm              | int64   |
# +---------+-----------------------------+---------+
# |     116 | oxygen_high_adm             | int64   |
# +---------+-----------------------------+---------+
# |     117 | suctioning_adm              | int64   |
# +---------+-----------------------------+---------+
# |     118 | suctioning_sched_adm        | int64   |
# +---------+-----------------------------+---------+
# |     119 | suctioning_asneeded_adm     | int64   |
# +---------+-----------------------------+---------+
# |     120 | trach_adm                   | int64   |
# +---------+-----------------------------+---------+
# |     121 | vent_invasive_adm           | int64   |
# +---------+-----------------------------+---------+
# |     122 | vent_noninvasive_adm        | int64   |
# +---------+-----------------------------+---------+
# |     123 | vent_bipap_adm              | int64   |
# +---------+-----------------------------+---------+
# |     124 | vent_cpap_adm               | int64   |
# +---------+-----------------------------+---------+
# |     125 | meds_iv_adm                 | int64   |
# +---------+-----------------------------+---------+
# |     126 | meds_iv_vasoactive_adm      | int64   |
# +---------+-----------------------------+---------+
# |     127 | meds_iv_antibiotic_adm      | int64   |
# +---------+-----------------------------+---------+
# |     128 | meds_iv_anticoagulant_adm   | int64   |
# +---------+-----------------------------+---------+
# |     129 | meds_iv_other_adm           | int64   |
# +---------+-----------------------------+---------+
# |     130 | transfusions_adm            | int64   |
# +---------+-----------------------------+---------+
# |     131 | dialysis_adm                | int64   |
# +---------+-----------------------------+---------+
# |     132 | hemodialysis_adm            | int64   |
# +---------+-----------------------------+---------+
# |     133 | peritoneal_dialysis_adm     | int64   |
# +---------+-----------------------------+---------+
# |     134 | iv_access_adm               | int64   |
# +---------+-----------------------------+---------+
# |     135 | iv_access_periph_adm        | int64   |
# +---------+-----------------------------+---------+
# |     136 | iv_access_mid_adm           | int64   |
# +---------+-----------------------------+---------+
# |     137 | iv_access_cent_adm          | int64   |
# +---------+-----------------------------+---------+
# |     138 | age_at_admit                | float64 |
# +---------+-----------------------------+---------+
# |     139 | los                         | float64 |
# +---------+-----------------------------+---------+
# |     140 | ric                         | float64 |
# +---------+-----------------------------+---------+
# |     141 | cmg                         | float64 |
# +---------+-----------------------------+---------+
# |     142 | tier                        | object  |
# +---------+-----------------------------+---------+

# %% [markdown]
# #### 2.2.1 Default Strategy

# %%
# safe buffer
last_df = df

# %%
# ranked int & categorical features: mode imputation

df = last_df.copy() # always work on a fresh copy of last step's output

# %% [markdown]
# ## The metric you're referring to is generally known as Feature Importance.
#
# There are several methods to calculate feature importance, and the specific method depends on the type of model you're using. Below are some common techniques for estimating feature importance:
#
# 1. Gini Importance (Mean Decrease in Impurity):
# Used in Decision Trees, Random Forests, and Gradient Boosting models.
# It measures the total reduction of the criterion (like Gini impurity or entropy in classification, or variance in regression) brought by that feature across all trees in the model.
# 2. Permutation Feature Importance:
# This is a model-agnostic approach.
# It involves randomly shuffling the values of each feature and observing how it impacts the model's performance. A feature is considered important if permuting its values significantly reduces the model's accuracy.
# 3. SHAP (SHapley Additive exPlanations):
# SHAP values are a game-theory-based method to explain the output of any machine learning model.
# It provides an individual score for each feature per instance that shows how much each feature contributes (positively or negatively) to the final prediction.
# 4. LIME (Local Interpretable Model-agnostic Explanations):
# Another model-agnostic technique that explains the prediction of individual instances by approximating the model locally with an interpretable one, such as a linear model, and extracting feature importance for that instance.
# 5. Coefficient Values in Linear Models:
# For models like Linear Regression or Logistic Regression, the feature importance can be directly interpreted from the magnitude of the model's coefficients. Larger absolute values of coefficients indicate higher importance.
# 6. Feature Gain (XGBoost):
# In XGBoost, feature importance can be measured using the gain (the average contribution of a feature to the model when it is used in trees).
# 7. Partial Dependence Plots (PDP):
# Although not a feature importance score per se, PDPs can be used to show the impact of a feature on the predicted outcome by averaging over all other features.
# Each of these methods provides a way to score the features in terms of their contribution to the model’s output, helping to interpret the importance of individual features in either classification or regression tasks.
